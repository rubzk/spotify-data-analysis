# %% [markdown]
# ### Inserting Libraries

# %%
import spotipy
import credentials
from tqdm import tqdm_notebook as tqdm
from spotipy.oauth2 import SpotifyClientCredentials, is_token_expired
import pandas as pd

# %% [markdown]
# ### Setting up API credentials

# %%
# You should create a credentials.py in your repo with credentials in it

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=credentials.client_id,client_secret=credentials.client_secret)

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Function that given a user_id returns all the data

# %%
def get_all_data(user_id):
    
    #get all the playlist id's
    
    track_list = []
    sname_list = []
    artist_list = []
    audio_ft = []
    
        
    for playlist in tqdm(sp.user_playlists(user_id)['items']):
            for idx,track in enumerate(sp.playlist_tracks(playlist['id'])['items']):
                if track['track']['id'] is not None:
                    
                    track_list.append(track['track']['id'])
                    sname_list.append(track['track']['name'])
                    artist_list.append(track['track']['album']['artists'][0])
                    #print(track['track']['id'])
                    audio_ft.append(sp.audio_features(track['track']['id'])[0])
    
    df = pd.DataFrame({'name': sname_list,
                       'artist': artist_list,
                       'id': track_list,
                       'audio_ft': audio_ft})
    
    return df

# %%
df = get_all_data('11101312700')
# Out:
# /home/tomas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # This is added back by InteractiveShellApp.init_path()
# HBox(children=(FloatProgress(value=0.0, max=28.0), HTML(value='')))

# %%
# Time to transform the data in order to be clean

# %%
def transform_data(df):
    
    df['artist'] = df['artist'].apply(pd.Series)['name']
    
    df = pd.concat([df,df['audio_ft'].apply(pd.Series)], axis=1)
    
    df = df.drop(labels=['time_signature','duration_ms','analysis_url','uri','track_href','type','audio_ft'], axis=1)
    
    return df

# %%
df = transform_data(df)

# %%
df.head()
# Out:
#                      name           artist                      id  \
# 0              Brokendate       Com Truise  2kmX8QNMLg72Vy9Ux6mdmi
# 1               Crimewave  Crystal Castles  3yQFmN8A5S8Kf1nUJuvb01
# 2                Vanished  Crystal Castles  0exOxvY3iHsmAnGHiJYAZq
# 3  Lady - Hear Me Tonight            Modjo  49X0LAl6faAusYq02PRAY6
# 4          Baby I'm Yours         Breakbot  0tZkVZ9DeAa0MNK2gY5NtV
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.526   0.544   11    -7.137     1       0.1690       0.25800
# 1         0.746   0.691    4    -7.533     0       0.0403       0.18400
# 2         0.713   0.868    0    -6.644     0       0.0305       0.00206
# 3         0.720   0.808    6    -5.627     1       0.0379       0.00793
# 4         0.829   0.792    2    -3.755     0       0.0668       0.72600
#
#    instrumentalness  liveness  valence    tempo                      id
# 0          0.640000    0.3770    0.544  170.370  2kmX8QNMLg72Vy9Ux6mdmi
# 1          0.025900    0.2050    0.888  119.982  3yQFmN8A5S8Kf1nUJuvb01
# 2          0.000092    0.2250    0.641  119.980  0exOxvY3iHsmAnGHiJYAZq
# 3          0.029300    0.0634    0.869  126.041  49X0LAl6faAusYq02PRAY6
# 4          0.000006    0.1220    0.758  118.050  0tZkVZ9DeAa0MNK2gY5NtV

# %% [markdown]
# Now we have all the songs of our playlist in a data frame with each audio feature, time to do some magic

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
features = ['danceability','energy','loudness','acousticness'
           ,'instrumentalness','valence']

# %%
scaler = MinMaxScaler()

scaled = pd.DataFrame(scaler.fit_transform(df[features]))
scaled.columns = features

# %%
def calculate_wcss(data):
    wcss = []
    for n in range(1, 15):
        kmeans = KMeans(n_clusters=n)
        kmeans.fit(X=data)
        wcss.append(kmeans.inertia_)

    return wcss

# %%
wcss = calculate_wcss(scaled)

# %%
len(wcss)
# Out:
# 14

# %%
sns.lineplot(x=range(1,15), y=wcss)

# %%
kmeans = KMeans(n_clusters=5).fit(scaled)

# %%
y_kmeans = kmeans.predict(scaled)

# %%
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[0.5496698 , 0.36237016, 0.55586297, 0.62573044, 0.81458333,
#         0.23432397],
#        [0.66473237, 0.74860897, 0.78545493, 0.13816253, 0.01691134,
#         0.71102244],
#        [0.53420605, 0.38400609, 0.60821013, 0.67862542, 0.02689699,
#         0.32974131],
#        [0.5249988 , 0.68712898, 0.77513609, 0.09991271, 0.02968767,
#         0.30465196],
#        [0.6406225 , 0.71030456, 0.73928583, 0.08554763, 0.79862939,
#         0.57907728]])

# %%
scaled = scaler.fit_transform(scaled)

# %%
from mpl_toolkits.mplot3d import Axes3D
# visualizing clusters
fig, ax = plt.subplots(figsize=(13,11))
ax = fig.add_subplot(111, projection='3d')
plt.scatter(scaled[y_kmeans == 0,0],scaled[y_kmeans == 0,1], s= 50, c= 'red',label= 'Cluster 1')
plt.scatter(scaled[y_kmeans == 1,0], scaled[y_kmeans == 1,1], s= 50, c= 'blue', label= 'Cluster 2')
plt.scatter(scaled[y_kmeans == 2,0], scaled[y_kmeans == 2,1], s= 50, c= 'green', label= 'Cluster 3')
plt.scatter(scaled[y_kmeans == 3,0], scaled[y_kmeans == 3,1], s= 50, c= 'cyan', label= 'Cluster 4')
plt.scatter(scaled[y_kmeans == 4,0], scaled[y_kmeans == 4,1], s= 50, c= 'magenta', label= 'Cluster 5')


# centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s= 300, c= 'yellow', label= 'Centroids')
plt.title('Clusters')
plt.legend()
plt.show()

# %%
kmeans_pred = pd.DataFrame(data=y_kmeans, dtype=int, columns=['k_cluster'])
kmeans_pred
# Out:
#      k_cluster
# 0            4
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 872          1
# 873          1
# 874          1
# 875          2
# 876          1
#
# [877 rows x 1 columns]

# %%
df_cluster = pd.concat([df, kmeans_pred], axis = 1)

# %%
cluster_0 = df_cluster[df_cluster.k_cluster == 0][features].mean()

# %%
labels = cluster_0.index
stats = cluster_0.values

# %%
cluster_stats = pd.DataFrame(columns=features)
for n in range(5):   
    cluster_stats = cluster_stats.append(df_cluster[df_cluster.k_cluster == n][features].mean(), ignore_index=True)
       
cluster_stats
# Out:
#    danceability    energy   loudness  acousticness  instrumentalness   valence
# 0      0.559694  0.377560 -12.696871      0.620726          0.782000  0.256206
# 1      0.662997  0.750357  -6.210898      0.137060          0.016235  0.706830
# 2      0.545810  0.398443 -11.218064      0.673197          0.025821  0.346404
# 3      0.537544  0.691017  -6.502405      0.099116          0.028500  0.322687
# 4      0.641351  0.713386  -7.515175      0.084866          0.766684  0.582102

# %%
from math import pi

# %%
def make_spider(df, row, color):
    
    categories=list(df)[0:]
    N = len(categories)

    
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
     
    plt.rc('figure', figsize=(7, 7))
 
    ax = plt.subplot(1,1,1, polar=True)
 
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
 
   
    plt.xticks(angles[:-1], categories, color='black', size=12)
    ax.tick_params(axis='x', rotation=5.5)
    
    ax.set_rlabel_position(0)
    plt.yticks([0.3,0.6,0.8,1], ["0.3","0.6","0.8","1"], color="black", size=10)
    plt.ylim(0,0.8)
 
    
    values=df.reset_index().loc[row].values.tolist()[1:]
    values += values[:1]
    ax.plot(angles, values, color = color, linewidth=1, linestyle='solid')
    ax.fill(angles, values, color = color, alpha = 0.5)
 
  
    title = "Cluster {}".format(row)
    plt.title(title, fontsize=20, x = 0.5, y = 1.1)

# %%
fills = ["#487eb0","#6a89cc", "#81cfe0","#00b5cc","#52b3d9"]
for row in range(0, len(cluster_stats.index)):
    plt.figure()
    make_spider( row=row, df = cluster_stats, color = fills[row])

# %%
df_cluster[df_cluster.k_cluster == 0]['id']
# Out:
#                          id                      id
# 1    3yQFmN8A5S8Kf1nUJuvb01  3yQFmN8A5S8Kf1nUJuvb01
# 3    49X0LAl6faAusYq02PRAY6  49X0LAl6faAusYq02PRAY6
# 5    25SJaCCPiosugnlY53VhRG  25SJaCCPiosugnlY53VhRG
# 8    5r5cp9IpziiIsR6b93vcnQ  5r5cp9IpziiIsR6b93vcnQ
# 9    6gV4xPbvYJz73lA1cr4NhH  6gV4xPbvYJz73lA1cr4NhH
# ..                      ...                     ...
# 868  6Ius4TC0L3cN74HT7ENE6e  6Ius4TC0L3cN74HT7ENE6e
# 869  33ZXjLCpiINn8eQIDYEPTD  33ZXjLCpiINn8eQIDYEPTD
# 872  7iXF2W9vKmDoGAhlHdpyIa  7iXF2W9vKmDoGAhlHdpyIa
# 873  7GkrhcYfflOImusWPIFrPN  7GkrhcYfflOImusWPIFrPN
# 874  3myrzRJNm3fOLWliErE7GF  3myrzRJNm3fOLWliErE7GF
#
# [225 rows x 2 columns]

# %%
df_cluster = df_cluster.loc[:,~df_cluster.columns.duplicated()]

# %%
df_cluster[df_cluster.k_cluster == 0]['id'].to_list()
# Out:
# ['3yQFmN8A5S8Kf1nUJuvb01',
#  '49X0LAl6faAusYq02PRAY6',
#  '25SJaCCPiosugnlY53VhRG',
#  '5r5cp9IpziiIsR6b93vcnQ',
#  '6gV4xPbvYJz73lA1cr4NhH',
#  '4DX82Vc8qAH4jJPvKxvwg6',
#  '0BgY6O6G7EtsneY6dAKZeI',
#  '6NiIHp4nhuHkcc4rZxctyF',
#  '1ueLYdeuGMAwUiaezLDObD',
#  '0d28khcov6AiegSCpG5TuT',
#  '0dcMqjeDpwqB2xhzMsld0p',
#  '69dXVFCMiz3SL1L7M24NdX',
#  '5r5cp9IpziiIsR6b93vcnQ',
#  '5ByAIlEEnxYdvpnezg7HTX',
#  '0D8Npw3PzW1srmITkELL3s',
#  '7GkrhcYfflOImusWPIFrPN',
#  '119c93MHjrDLJTApCVGpvx',
#  '2MQ51y5NhCyva4SgWmK2Me',
#  '4INDiWSKvqSKDEu7mh8HFz',
#  '5XLC8xoqyua4U7wJiZAWik',
#  '0zUaNkEcOiAE4cE0V5sA9u',
#  '4nH38LBCP7sCdIkv23jJwc',
#  '5hl9wX67vKKzT2nBO0B2BE',
#  '3EAbMbWQmh6f04u2Kh7wTH',
#  '0hI7haTwP7pek8WFQjDZoQ',
#  '4nGdVw9wXIeY4gOhsUNH1L',
#  '06b0Au6pvZiO03eKTCvgWh',
#  '7d5cCdTZavXBFao9lCScjo',
#  '7x4ClpwHSyNJgCsMUFRVU7',
#  '04eL7Mun5wCThY3P37onK4',
#  '7w7wTfCkR2ML44Z6Ingz9d',
#  '77E6BhaBLsIMmW5nAyXGTy',
#  '3tMNgcUfPEXTtG5vaaGi85',
#  '49rFA0vfmY9Eel2cInKmTk',
#  '7MCFjPDImfjQv7GynHgVrR',
#  '0qPbQWcqNDVrReSSvMoJxk',
#  '4shKoD4U0rsE6UDjyPEjyK',
#  '6MFRtRMQWObCVWE4TC1Pbu',
#  '63otWg6eWBt3ldXFtDJiXN',
#  '5kxVyCgEUND7E2QKG7JmoF',
#  '2BqfIlpahcebJPeu1IUTEo',
#  '3DQVgcqaP3iSMbaKsd57l5',
#  '64a5XZCVDWwvC7gwPPCsH6',
#  '3ZOEytgrvLwQaqXreDs2Jx',
#  '0uppYCG86ajpV2hSR3dJJ0',
#  '3ee8Jmje8o58CHK66QrVC2',
#  '54oMZ3blwWwuPN4wEoG5mk',
#  '3CA9pLiwRIGtUBiMjbZmRw',
#  '4RQN36VnkR0oNBRUClzpNm',
#  '2At3wa1XCMnEendDMO9qcM',
#  '5iUQMwxUPdJBFeGkePtM66',
#  '0uppYCG86ajpV2hSR3dJJ0',
#  '0d28khcov6AiegSCpG5TuT',
#  '0dcMqjeDpwqB2xhzMsld0p',
#  '1RKUoGiLEbcXN4GY4spQDx',
#  '5SLhbyOJgcKGTDNWaQN91M',
#  '7KA4W4McWYRpgf0fWsJZWB',
#  '7jYUaoOfdcYgUvkK8NnFfx',
#  '7ef4DlsgrMEH11cDZd32M6',
#  '54oMZ3blwWwuPN4wEoG5mk',
#  '1cTZMwcBJT0Ka3UJPXOeeN',
#  '5ByAIlEEnxYdvpnezg7HTX',
#  '4ewH8Cj4lXKIDvU9SpSyZy',
#  '3mFxRJau0dXGjFmA9Y4Yda',
#  '7BKLCZ1jbUBVqRi2FVlTVw',
#  '0B8B8cVRFIG1yznoQe7c9s',
#  '5aAx2yezTd8zXrkmtKl66Z',
#  '3a1lNhkSLSkpJE4MSHpDu9',
#  '0t2myRMEMCi2SRyg5TEFLp',
#  '2edETjnSyBm4Of0Amtxxbd',
#  '3A7qX2QjDlPnazUsRk5y0M',
#  '5nNmj1cLH3r4aA4XDJ2bgY',
#  '6eXovJdAhh26KFdpicZScW',
#  '3VtrOlNHCPdZnEk4e4bwVG',
#  '0293bTPojlkLvyr8ojc74y',
#  '2374M0fQpWi3dLnB54qaLX',
#  '0XIvZ82aDF7JiSi3ZE320u',
#  '2aoo2jlRnM3A0NyLQqMN2f',
#  '1aj4GXfmEYXfdVZohCpNKu',
#  '5eCgNATwXgRc4mZx9NymGJ',
#  '4BPCAXBOWWesYoLEMSqGWQ',
#  '2eAfYYSZZhbqLOxvMLETov',
#  '4Nj8IGoBiZe2yvluDByMec',
#  '2eDvflMCe9ssOkUJrxqikB',
#  '14WWzenpaEgQZlqPq2nk4v',
#  '7vfWgVGiLgnGbInU5lvSQg',
#  '4a5LSK0ueUzqMWEn2M9GGH',
#  '3Gkto4gxntr92WysrZTZAv',
#  '1CoqkJekooHsTF39BsfpGa',
#  '1Q5tfzvk1Yx6ZRYKFGsaz9',
#  '2QqAVlaV6Y45ebsXxfS5i8',
#  '6ge7nx3phqsFdrQVT3K5QX',
#  '2DOTzHc75WY2sdvpS0Lhe4',
#  '1hxKQ0rLEk4beQjIz7QmnT',
#  '5Z35oI2Mdqjb1IZBWZn3J4',
#  '4x4H4v9c4PeLAfupAxU7ii',
#  '29nYmmi4ZJYTqnqc8kxXIY',
#  '4uQl8Awoej527xRa5lOI15',
#  '12CsvOE6ssStQoNooXzYkY',
#  '2lA9L8c4l601mHvPHFgAGZ',
#  '41TbWoKRIRt2ObglA4Ei5s',
#  '6vdh99TP7Vc7s10ccgJM8a',
#  '0XuWLpllnwmIBxdHLoRKm1',
#  '1QQfbfMfyzNZhT5fg3RpuS',
#  '3N0Y24SsFAW9wNpuS8LmxL',
#  '58qEQujDJy5ma0cWRnB6dh',
#  '6Vy8uPRN1rRj3JY6Kulzb3',
#  '58KaBE2fnHA8R0iesCbe8o',
#  '0yWSrApKh3AgJ5rzbIwtRG',
#  '5fRgvfgF4TM947Gi6qOlcF',
#  '62zDAToKxvvwgsfdRAwLHN',
#  '0Nj3EM5QMCIdTbWM3wzJGR',
#  '7vxlM6ouhpJy5WMEZqU7vV',
#  '2H4tDOlvFr36XKsYHPFTRT',
#  '2rgqPSIRAfaO2MGo9smdSX',
#  '3c7vquF4xacCmFrxztLUVH',
#  '7FFl1IHSsPWsfUCladsCl9',
#  '0bXgHANh87ATv5ReOdxVCX',
#  '1EzrEOXmMH3G43AXT1y7pA',
#  '5CMjjywI0eZMixPeqNd75R',
#  '55h7vJchibLdUkxdlX3fK7',
#  '18zrqdHev7Niaz2MK6P0Rp',
#  '3w3y8KPTfNeOKPiqUTakBh',
#  '386RUes7n1uM1yfzgeUuwp',
#  '3CVPyuuD6HxWXgPbbGqbg6',
#  '0TVV2gFROJaB3kIZyCUvIY',
#  '5lyCpekspXmDCvBxFuXhDM',
#  '0qOnSQQF0yzuPWsXrQ9paz',
#  '5GCz9BOkt17aI6ZOR3EiUl',
#  '13P5rwmk2EsoFRIz9UCeh9',
#  '6N9ZOtguCnnrvwH7zD82WJ',
#  '69uxyAqqPIsUyTO8txoP2M',
#  '6DNtNfH8hXkqOX1sjqmI7p',
#  '7IJC1qatyg2t8SZiwJRvID',
#  '3lwqmx0JEyTpzas79003Zy',
#  '4tuglqeo4UhMhbTDeryvHc',
#  '0gUVS9HnATk5vbCJuHyluS',
#  '0PlYvTIRkIZ0oVYVoxrfmP',
#  '0IRKtJVUuUmb9ZsVOrp3V4',
#  '4ruj5Lkiud0366Mte7vjC9',
#  '7be5IEj6GYti0jauRKODoG',
#  '5P29BFj3HVX4iEsK7lCa0t',
#  '7r4LndpzoSgtsaBZ8fSu5H',
#  '0pQWEByUsh3sbhfRYVFnAs',
#  '4lyjk0OeoXmtc3GHrpws1T',
#  '062v4DO700DVl0rAB43EzW',
#  '4yrc7uKE6zbLa545LX21re',
#  '4p3CyipHDyS8oXIP7jNqjF',
#  '75dqA2rQHnUtP7XjvkmKh2',
#  '3AjSUbPd7siXGOSlmXm9Nr',
#  '4wS9c2d5eYax6pMg6xfN8A',
#  '75UFuLYzDexDLZIiUe5gg1',
#  '6lSypaQOcC6JtzfwpINLGW',
#  '5VFiq9gQwdUvgSx1wCta6a',
#  '4I2YdD5ECOwmjVzxgq7bKE',
#  '6uxhO71BgJz1JlZcTMtUbX',
#  '1hRa373L1NxacnE6HdEVSF',
#  '1xGab7yPXELlr7bGE3m0L4',
#  '4D5nVZMNE9vjWtIYzYIKaR',
#  '2taFTIOpdZLRG68HAqGoVN',
#  '7kMCBDqYVquVWRKoLNtitj',
#  '18dflRgJaUyIdQisfKgkFa',
#  '17eJyYLIlMNlOqcwHYJ9F2',
#  '4MdTXdZFzWk0QPdrWnWocy',
#  '6biFGCUsZW9eDUcavVhEA6',
#  '4zJOvPywNnXOWdIFIWgfzn',
#  '07JBuNqqO998jP1Zt0gp0l',
#  '2fMlhPq7qE0TnKylJHynpn',
#  '1F2WXi5pDUjSa4WPeZRc2f',
#  '49orJI7kOzRe8rv44gLPEd',
#  '0S7zL7ae0KpOSPKeFQpHo8',
#  '7Jzsc04YpkRwB1zeyM39wE',
#  '3lQHHqVMXtnOGxN2BKWXBs',
#  '2DDYniif4CDJ2W8SGVmvGk',
#  '3odPjdX1SjxxjIr0EZjEht',
#  '52MW2hwNmLa0KdsZZk8360',
#  '7bmQq7In6J04u3XX4QLUS8',
#  '4RU7rnJBOXCzWmsLDqUaFC',
#  '3SoDB59Y7dSZLSDBiNJ6o2',
#  '0xAjq4KAQdJvUyCM7fFZ9K',
#  '3ZOEytgrvLwQaqXreDs2Jx',
#  '3GfOAdcoc3X5GPiiXmpBjK',
#  '09wH7EKmwE5K7XU790cymf',
#  '2aGI6026jt9do6XgCd7YED',
#  '0VLdJcQUsqHBBwqPp4CIKJ',
#  '26ocLzyIX0dkfDgAerzFzs',
#  '3f0Sb02YQctClGaoFusRSm',
#  '3ntrdR24dLkKrzSGRv1FlH',
#  '4PyGxrPiBzShvuxaHab0lu',
#  '15049rGLXHwrWtE4euUb5C',
#  '3e0McEmoNU05YD0dBT5afU',
#  '74EV0g12ihUoOUXMprFpZB',
#  '56NkIxSZZiMpFP5ZNSxtnT',
#  '2cgqvO5jXaLoAHLNCVT3Vz',
#  '67nAU2VBR1i9eBrVLuvajz',
#  '7dtuGiBwn2vgvDPVNyWlck',
#  '6UaRii9AH6Zss9xNMEQ2M9',
#  '3pAnZV3mgNKCABheAUatc3',
#  '1WGUqMaTj8MN7QYZErtsVv',
#  '2vbWpgFRbqbVZFybdCgm6M',
#  '1vSBBTF9m6k0LZCP4Q8DeJ',
#  '3Lt558KSXrSTLBr3EJ3BAe',
#  '6qa6a2fsCbLMkSIoZEfvTJ',
#  '4ZQyCb1wKXCpTxSGDuWKga',
#  '2jhtODLY04Z9bFzFgt5CvI',
#  '2MQ51y5NhCyva4SgWmK2Me',
#  '3Cd5BE3carDNzPaN4Iu0qs',
#  '546jptkBtmJ076SnwEg3fn',
#  '5U8hKxSaDXB8cVeLFQjvwx',
#  '3lPAHV0b53zgRRm9LBgnTY',
#  '7vwkKw2Xd7Pks1X712Au0T',
#  '5DD9jE8Z3LvpVn2TxknJyX',
#  '5GCz9BOkt17aI6ZOR3EiUl',
#  '0mwXfPCm4AMaz9J0Cn7FXJ',
#  '0KGBU6sYZ1WC5UXrdvIxtC',
#  '119c93MHjrDLJTApCVGpvx',
#  '5pBvNeOAJ54zgd5lEOmM3b',
#  '48HUDhfl4ssbc5xuIrZ6UD',
#  '62vpWI1CHwFy7tMIcSStl8',
#  '3a1lNhkSLSkpJE4MSHpDu9',
#  '6Ius4TC0L3cN74HT7ENE6e',
#  '33ZXjLCpiINn8eQIDYEPTD',
#  '7iXF2W9vKmDoGAhlHdpyIa',
#  '7GkrhcYfflOImusWPIFrPN',
#  '3myrzRJNm3fOLWliErE7GF']

# %%
def create_cluster_playlist(df):
    
    for num in range()

# %%
for num in range(0,len(df_cluster['k_cluster'].value_counts().index)):
    sp.user_playlist_create(user,name='Cluster{}'.format(num), public=True,
                           description="Playlist generated by KMeans Algorithm")
    sp.user_playlist_add_tracks()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
df_cluster[df_cluster.k_cluster == 4]['name'].to_list()
# Out:
# ['Shooting Stars',
#  'Como se siente',
#  'Maquiavélico',
#  'Heartless',
#  'Avoid',
#  'Dear Mama',
#  'Changes',
#  'Kawasaki',
#  'Nadie',
#  'Shorty',
#  "Sam's Town",
#  'When You Were Young',
#  'Uncle Jonny',
#  'Do I Wanna Know?',
#  'The View From The Afternoon',
#  'From The Ritz To The Rubble',
#  'Californication',
#  'In My Feelings',
#  'U Said',
#  'Beamer Boy',
#  'Monophobia',
#  'Survival',
#  'Better Now',
#  'Slide Away - Remastered',
#  'The Final Countdown',
#  'On & On',
#  'Lucid Dreams',
#  'Ghost Town',
#  'Perdóname',
#  'U Said',
#  'Cinderella (feat. Ty Dolla $ign)',
#  'Ladders',
#  'Somebody',
#  'STOP TRYING TO BE GOD',
#  'In My Feelings',
#  'Magnolia',
#  'Better Now',
#  'Guerra',
#  'Beamer Boy',
#  'Insane',
#  'You & Me - Flume Remix',
#  'Will I Ever Care',
#  'Midnight',
#  'There for You',
#  'Breeze',
#  'Disappear',
#  'Breathe Again',
#  'Hurt',
#  'Kaleidoscope Kickback',
#  'American Dream',
#  'Shoulda Coulda',
#  'lockdown',
#  'Sorry',
#  'Flurry',
#  'Forever',
#  'Close to Me',
#  'Chasing California',
#  'In the Name of Love',
#  'Something Just Like This',
#  "Don't Let Me Down (feat. Daya)",
#  'New York City',
#  'Reminder',
#  'XO TOUR Llif3',
#  'Passionfruit',
#  'There for You',
#  'LOYALTY. FEAT. RIHANNA.',
#  'Swang',
#  'The Sound of Silence',
#  'The Final Countdown',
#  'Voodoo Child (Slight Return)',
#  'Paradise City',
#  'No More Tears',
#  'Stole the Show',
#  'Firestone (feat. Conrad Sewell)',
#  'Cut Your Teeth - Kygo Remix',
#  'Often - Kygo Remix',
#  'Lean On (feat. MØ & DJ Snake)',
#  'Wanna Do (feat. Emil)',
#  'California',
#  'Look For Me - Radio Edit',
#  'Hundred Miles',
#  'Headlights (feat. Ilsey)',
#  'Fade Into You',
#  'Faded',
#  'One',
#  'In The Night',
#  'Middle',
#  'Wait a Minute',
#  'Loving You',
#  'So Far To Go',
#  'Sunday',
#  'Satisfy My Soul',
#  'The Past Recedes',
#  'Away & Anywhere',
#  'Kids',
#  'Civilization',
#  'West Coast',
#  'The Only Exception',
#  'High',
#  'Midnight City',
#  'Viva La Vida',
#  'Yellow',
#  'Simple Song',
#  'Ordinary Love',
#  'A Sky Full of Stars',
#  'Heroes (we could be)',
#  'Between Two Points (feat. Swan)',
#  'Radioactive',
#  'God Only Knows - Remastered',
#  'How to Save a Life',
#  'Let Me Love You',
#  'Capsize',
#  'Ants',
#  'Ltlp',
#  'We Own The Sky',
#  'Reunion',
#  'Comfortably Numb - 2011 Remastered Version',
#  'Sorrow - 2001 Remastered Version',
#  'Un Pacto - Live In Buenos Aires / 2001',
#  'Murguita Del Sur - Live In Buenos Aires / 2001',
#  'Lo Frágil De La Locura',
#  'Antes Y Después',
#  'Ropa Sucia',
#  'El Viento Trae Una Copla / Siempre Triunfará El Amor',
#  'Luna de Miel en la Mano',
#  'Bajan',
#  'Una Piba Con la Remera de Greenpeace',
#  'La Parabellum del Buen Psicópata',
#  'Signos - Remasterizado 2007',
#  'Vivo',
#  'Raiz',
#  'Puente',
#  'El Anillo del Capitán Beto',
#  'Chance',
#  'Heroína',
#  'Preso en Mi Ciudad',
#  'Divorcio',
#  'No Me Arrepiento de Este Amor',
#  'Arco',
#  'Los Mocosos',
#  'Learn to Fly',
#  'The Pretender',
#  'Live Forever',
#  'The Masterplan',
#  'Stadium Arcadium',
#  'I Could Die for You',
#  'Dosed',
#  'Creep',
#  'Comfortably Numb - 2011 Remastered Version',
#  'In The Flesh? - 2011 Remastered Version',
#  'I Miss You',
#  'Lost in You',
#  'Flick of The Finger',
#  'When The Sun Goes Down',
#  'The View From The Afternoon',
#  'Somewhere Only We Know',
#  'A Certain Romance',
#  'Away & Anywhere',
#  'Song to Say Goodbye',
#  'Dust in the Wind',
#  'You Know My Name - From "Casino Royale" Soundtrack',
#  "I'm Outta Time",
#  "She's Electric - Remastered",
#  'Take Me Out',
#  'The Show Must Go On - 2011 Mix',
#  'Under Cover of Darkness',
#  'Like Toy Soldiers',
#  'Sing For The Moment',
#  'Rock Bottom',
#  'No Apologies',
#  "When I'm Gone",
#  'Changes',
#  'See You Again (feat. Charlie Puth)',
#  'Take A Look Around',
#  'Bad and Boujee (feat. Lil Uzi Vert)',
#  'Stronger',
#  'BDE Bonus']
