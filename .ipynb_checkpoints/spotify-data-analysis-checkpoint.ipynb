# %% [markdown]
# # Spotify Data Analysis

# %% [markdown]
# ### Auth

# %% [markdown]
# First, we need to save our credentials (client_id and client_secret) into a credentials.py in the same folder

# %%
import spotipy
import credentials

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=credentials.client_id,client_secret=credentials.client_secret)

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Gathering the data

# %% [markdown]
# Next, using the spotify API we need to gather the data about the artist we want to analyze

# %% [markdown]
# The following function returns all of the tracks of a list of artists

# %%
def get_artist_tracks(artists):
    tracks = []
    
    for artist in artists:
        
        # Get the artist URI (a unique ID)
        artist_uri = sp.search(artist)['tracks']['items'][0]['artists'][0]['uri']

        # Spotify has a lot of duplicate albums, but we'll cross-reference them with this list to avoid extra loops
        album_checker = []
        
        # The starting point of our loop of albums for those artists with more than 50
        n = 0
        
        # Note the album_type = 'album'. This discounts singles, compilations and collaborations
        while len(sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']) > 0:
            
            # Avoid overloading Spotify with requests by assigning the list of album dictionaries to a variable
            dict_list = sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']
            
            for i, album in list(enumerate(dict_list)):

                # Add the featured artists for the album in question to the checklist
                check_this_album = [j['name'] for j in dict_list[i]['artists']]
                # And the album name
                check_this_album.append(dict_list[i]['name'])
                # And its date
                check_this_album.append(dict_list[i]['release_date'])

                # Only continue looping if that album isn't in the checklist
                if check_this_album not in album_checker:
                    
                    # Add this album to the checker
                    album_checker.append(check_this_album)
                    # For every song on the album, get its descriptors and features in a list and add to the tracklist
                    tracks.extend([[artist, album['name'], album['uri'], song['name'],

                      album['release_date']] + list(sp.audio_features(song['uri'])[0].values()) 
                                   for song in sp.album_tracks(album['uri'])['items']])
            
            # Go through the next 50 albums (otherwise we'll get an infinite while loop)
            n += 50

    return tracks

# %% [markdown]
# So now we need to set our list of artists

# %% [markdown]
# We are going to use the Top Global Charts Playlist from spotify to extract the top 50 artists

# %%
top_50_global_chart = sp.playlist_tracks('37i9dQZEVXbMDoHDwVN2tF',market='AR')

# %%
list_top50 = list(top_50_global_chart['items'])

# %%
list_top50[0]['track']['artists'][0]['name']
# Out:
# 'Roddy Ricch'

# %%
top_artists = []
for artist in list_top50:
    print(artist['track']['artists'][0]['name'])
    top_artists.append(artist['track']['artists'][0]['name'])
# Out:
# Roddy Ricch
# Tones and I
# The Weeknd
# Dua Lipa
# KAROL G
# Trevor Daniel
# Justin Bieber
# Future
# Arizona Zervas
# Justin Bieber
# Billie Eilish
# Eminem
# Post Malone
# Maroon 5
# Lewis Capaldi
# The Black Eyed Peas
# Billie Eilish
# Shawn Mendes
# Harry Styles
# Halsey
# Lewis Capaldi
# Camila Cabello
# Dua Lipa
# Doja Cat
# Dimelo Flow
# Selena Gomez
# Roddy Ricch
# MEDUZA
# YNW Melly
# SAINt JHN
# Jonas Brothers
# Regard
# Bad Bunny
# Khalid
# Anuel AA
# Dalex
# Ali Gatie
# Selena Gomez
# J Balvin
# DaBaby
# BROCKHAMPTON
# Ed Sheeran
# Rauw Alejandro
# Post Malone
# Lil Mosey
# Joji
# blackbear
# Nicky Jam
# Billie Eilish
# Mustard

# %% [markdown]
# Now that we got our artist we are going to use the function prevously defined

# %%
tracks = get_artist_tracks(top_artists)

# %%
tracks
# Out:
# [['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Intro',
#   '2019-12-06',
#   0.738,
#   0.657,
#   3,
#   -8.737,
#   0,
#   0.109,
#   0.164,
#   0,
#   0.163,
#   0.716,
#   159.01,
#   'audio_features',
#   '7AOtINPzQ4N4JVXk7ygZZz',
#   'spotify:track:7AOtINPzQ4N4JVXk7ygZZz',
#   'https://api.spotify.com/v1/tracks/7AOtINPzQ4N4JVXk7ygZZz',
#   'https://api.spotify.com/v1/audio-analysis/7AOtINPzQ4N4JVXk7ygZZz',
#   135849,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'The Box',
#   '2019-12-06',
#   0.896,
#   0.586,
#   10,
#   -6.687,
#   0,
#   0.0559,
#   0.104,
#   0,
#   0.79,
#   0.642,
#   116.971,
#   'audio_features',
#   '0nbXyq5TXYPCO7pr3N8S4I',
#   'spotify:track:0nbXyq5TXYPCO7pr3N8S4I',
#   'https://api.spotify.com/v1/tracks/0nbXyq5TXYPCO7pr3N8S4I',
#   'https://api.spotify.com/v1/audio-analysis/0nbXyq5TXYPCO7pr3N8S4I',
#   196653,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Start Wit Me (feat. Gunna)',
#   '2019-12-06',
#   0.886,
#   0.479,
#   4,
#   -8.054,
#   0,
#   0.334,
#   0.077,
#   0,
#   0.135,
#   0.408,
#   130.029,
#   'audio_features',
#   '7A20WnLkjtZU2d7hIB6Ziu',
#   'spotify:track:7A20WnLkjtZU2d7hIB6Ziu',
#   'https://api.spotify.com/v1/tracks/7A20WnLkjtZU2d7hIB6Ziu',
#   'https://api.spotify.com/v1/audio-analysis/7A20WnLkjtZU2d7hIB6Ziu',
#   158692,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Perfect Time',
#   '2019-12-06',
#   0.577,
#   0.734,
#   8,
#   -8.484,
#   0,
#   0.432,
#   0.171,
#   0,
#   0.12,
#   0.254,
#   94.122,
#   'audio_features',
#   '6kiIVIbmwEw6JvIZc7UG0E',
#   'spotify:track:6kiIVIbmwEw6JvIZc7UG0E',
#   'https://api.spotify.com/v1/tracks/6kiIVIbmwEw6JvIZc7UG0E',
#   'https://api.spotify.com/v1/audio-analysis/6kiIVIbmwEw6JvIZc7UG0E',
#   142710,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Moonwalkin (feat. Lil Durk)',
#   '2019-12-06',
#   0.779,
#   0.58,
#   1,
#   -7.594,
#   0,
#   0.284,
#   0.0178,
#   0,
#   0.15,
#   0.299,
#   160.243,
#   'audio_features',
#   '33NoCir8q4WA4HNmyrD3fu',
#   'spotify:track:33NoCir8q4WA4HNmyrD3fu',
#   'https://api.spotify.com/v1/tracks/33NoCir8q4WA4HNmyrD3fu',
#   'https://api.spotify.com/v1/audio-analysis/33NoCir8q4WA4HNmyrD3fu',
#   167851,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Big Stepper',
#   '2019-12-06',
#   0.753,
#   0.597,
#   8,
#   -8.469,
#   1,
#   0.292,
#   0.0477,
#   0,
#   0.197,
#   0.616,
#   76.997,
#   'audio_features',
#   '6x0QNM6f0C2JEjK0hFF8Ca',
#   'spotify:track:6x0QNM6f0C2JEjK0hFF8Ca',
#   'https://api.spotify.com/v1/tracks/6x0QNM6f0C2JEjK0hFF8Ca',
#   'https://api.spotify.com/v1/audio-analysis/6x0QNM6f0C2JEjK0hFF8Ca',
#   175170,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Gods Eyes',
#   '2019-12-06',
#   0.865,
#   0.649,
#   2,
#   -8.05,
#   0,
#   0.349,
#   0.145,
#   0,
#   0.104,
#   0.22,
#   113.245,
#   'audio_features',
#   '7KK4d7xfH6WjUuK1kPL8E2',
#   'spotify:track:7KK4d7xfH6WjUuK1kPL8E2',
#   'https://api.spotify.com/v1/tracks/7KK4d7xfH6WjUuK1kPL8E2',
#   'https://api.spotify.com/v1/audio-analysis/7KK4d7xfH6WjUuK1kPL8E2',
#   135516,
#   5],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Peta (feat. Meek Mill)',
#   '2019-12-06',
#   0.778,
#   0.573,
#   10,
#   -7.339,
#   0,
#   0.251,
#   0.015,
#   0,
#   0.464,
#   0.269,
#   140.114,
#   'audio_features',
#   '4bl1HBZliBuYpFZjWgefE4',
#   'spotify:track:4bl1HBZliBuYpFZjWgefE4',
#   'https://api.spotify.com/v1/tracks/4bl1HBZliBuYpFZjWgefE4',
#   'https://api.spotify.com/v1/audio-analysis/4bl1HBZliBuYpFZjWgefE4',
#   198849,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Boom Boom Room',
#   '2019-12-06',
#   0.828,
#   0.543,
#   2,
#   -7.678,
#   0,
#   0.0865,
#   0.452,
#   0,
#   0.15,
#   0.231,
#   125.989,
#   'audio_features',
#   '3aBL75wBGHJnskegE9jyhb',
#   'spotify:track:3aBL75wBGHJnskegE9jyhb',
#   'https://api.spotify.com/v1/tracks/3aBL75wBGHJnskegE9jyhb',
#   'https://api.spotify.com/v1/audio-analysis/3aBL75wBGHJnskegE9jyhb',
#   167558,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   "Elyse's Skit",
#   '2019-12-06',
#   0.803,
#   0.242,
#   9,
#   -16.513,
#   0,
#   0.925,
#   0.965,
#   0,
#   0.628,
#   0.956,
#   53.297,
#   'audio_features',
#   '7y6xHDylozEzDBIHpcRBn4',
#   'spotify:track:7y6xHDylozEzDBIHpcRBn4',
#   'https://api.spotify.com/v1/tracks/7y6xHDylozEzDBIHpcRBn4',
#   'https://api.spotify.com/v1/audio-analysis/7y6xHDylozEzDBIHpcRBn4',
#   23883,
#   5],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'High Fashion (feat. Mustard)',
#   '2019-12-06',
#   0.831,
#   0.499,
#   11,
#   -8.442,
#   0,
#   0.114,
#   0.269,
#   0,
#   0.3,
#   0.511,
#   97.956,
#   'audio_features',
#   '07KXEDMj78x68D884wgVEm',
#   'spotify:track:07KXEDMj78x68D884wgVEm',
#   'https://api.spotify.com/v1/tracks/07KXEDMj78x68D884wgVEm',
#   'https://api.spotify.com/v1/audio-analysis/07KXEDMj78x68D884wgVEm',
#   220487,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Bacc Seat (feat. Ty Dolla $ign)',
#   '2019-12-06',
#   0.783,
#   0.524,
#   1,
#   -6.828,
#   1,
#   0.115,
#   0.0404,
#   0,
#   0.087,
#   0.153,
#   144.989,
#   'audio_features',
#   '6In6SkveIw26thdYRhHTVX',
#   'spotify:track:6In6SkveIw26thdYRhHTVX',
#   'https://api.spotify.com/v1/tracks/6In6SkveIw26thdYRhHTVX',
#   'https://api.spotify.com/v1/audio-analysis/6In6SkveIw26thdYRhHTVX',
#   172320,
#   4],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Roll Dice',
#   '2019-12-06',
#   0.876,
#   0.443,
#   2,
#   -8.995,
#   1,
#   0.178,
#   0.279,
#   0,
#   0.105,
#   0.496,
#   153.029,
#   'audio_features',
#   '47FhiQXgLU47HDBYUDlHsd',
#   'spotify:track:47FhiQXgLU47HDBYUDlHsd',
#   'https://api.spotify.com/v1/tracks/47FhiQXgLU47HDBYUDlHsd',
#   'https://api.spotify.com/v1/audio-analysis/47FhiQXgLU47HDBYUDlHsd',
#   170995,
#   3],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Prayers To The Trap God',
#   '2019-12-06',
#   0.852,
#   0.554,
#   11,
#   -8.254,
#   1,
#   0.389,
#   0.0815,
#   0,
#   0.118,
#   0.33,
#   155.961,
#   'audio_features',
#   '0uIFsRx5caF13RunwkgLYt',
#   'spotify:track:0uIFsRx5caF13RunwkgLYt',
#   'https://api.spotify.com/v1/tracks/0uIFsRx5caF13RunwkgLYt',
#   'https://api.spotify.com/v1/audio-analysis/0uIFsRx5caF13RunwkgLYt',
#   160059,
#   3],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'Tip Toe (feat. A Boogie Wit da Hoodie)',
#   '2019-12-06',
#   0.757,
#   0.673,
#   1,
#   -8.513,
#   1,
#   0.141,
#   0.095,
#   0,
#   0.338,
#   0.574,
#   92.958,
#   'audio_features',
#   '6ztvsy3C6hPjVg9j4x1XKJ',
#   'spotify:track:6ztvsy3C6hPjVg9j4x1XKJ',
#   'https://api.spotify.com/v1/tracks/6ztvsy3C6hPjVg9j4x1XKJ',
#   'https://api.spotify.com/v1/audio-analysis/6ztvsy3C6hPjVg9j4x1XKJ',
#   185806,
#   3],
#  ['Roddy Ricch',
#   'Please Excuse Me For Being Antisocial',
#   'spotify:album:52u4anZbHd6UInnmHRFzba',
#   'War Baby',
#   '2019-12-06',
#   0.663,
#   0.706,
#   5,
#   -6.97,
#   0,
#   0.329,
#   0.337,
#   0,
#   0.113,
#   0.244,
#   74.836,
#   'audio_features',
#   '78X9D3v7OarDPNdTPUV4CQ',
#   'spotify:track:78X9D3v7OarDPNdTPUV4CQ',
#   'https://api.spotify.com/v1/tracks/78X9D3v7OarDPNdTPUV4CQ',
#   'https://api.spotify.com/v1/audio-analysis/78X9D3v7OarDPNdTPUV4CQ',
#   195668,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Feed Tha Streets 2 (Intro)',
#   '2018-11-02',
#   0.971,
#   0.614,
#   10,
#   -5.844,
#   0,
#   0.113,
#   0.0767,
#   0,
#   0.236,
#   0.27,
#   112.994,
#   'audio_features',
#   '3kgQ1kJC1WkuYVJuNJHPGA',
#   'spotify:track:3kgQ1kJC1WkuYVJuNJHPGA',
#   'https://api.spotify.com/v1/tracks/3kgQ1kJC1WkuYVJuNJHPGA',
#   'https://api.spotify.com/v1/audio-analysis/3kgQ1kJC1WkuYVJuNJHPGA',
#   169887,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Faces',
#   '2018-11-02',
#   0.674,
#   0.637,
#   5,
#   -6.816,
#   1,
#   0.085,
#   0.00671,
#   0,
#   0.0867,
#   0.132,
#   157.706,
#   'audio_features',
#   '3E1VoxJZ1JO8xhlxite5bn',
#   'spotify:track:3E1VoxJZ1JO8xhlxite5bn',
#   'https://api.spotify.com/v1/tracks/3E1VoxJZ1JO8xhlxite5bn',
#   'https://api.spotify.com/v1/audio-analysis/3E1VoxJZ1JO8xhlxite5bn',
#   109750,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Nascar',
#   '2018-11-02',
#   0.817,
#   0.743,
#   9,
#   -4.793,
#   1,
#   0.166,
#   0.0244,
#   1.04e-06,
#   0.102,
#   0.374,
#   172.962,
#   'audio_features',
#   '4F60iJFwx0G7x3SNjYWiZP',
#   'spotify:track:4F60iJFwx0G7x3SNjYWiZP',
#   'https://api.spotify.com/v1/tracks/4F60iJFwx0G7x3SNjYWiZP',
#   'https://api.spotify.com/v1/audio-analysis/4F60iJFwx0G7x3SNjYWiZP',
#   179059,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Die Young',
#   '2018-11-02',
#   0.688,
#   0.656,
#   4,
#   -5.541,
#   0,
#   0.276,
#   0.218,
#   0,
#   0.115,
#   0.365,
#   160.414,
#   'audio_features',
#   '3wLtYwtqvKK2ewelSVPeDK',
#   'spotify:track:3wLtYwtqvKK2ewelSVPeDK',
#   'https://api.spotify.com/v1/tracks/3wLtYwtqvKK2ewelSVPeDK',
#   'https://api.spotify.com/v1/audio-analysis/3wLtYwtqvKK2ewelSVPeDK',
#   157657,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Cream',
#   '2018-11-02',
#   0.894,
#   0.625,
#   8,
#   -6.703,
#   1,
#   0.302,
#   0.158,
#   0,
#   0.171,
#   0.428,
#   150.026,
#   'audio_features',
#   '2wz3OO7ndJQj15z3drwKkf',
#   'spotify:track:2wz3OO7ndJQj15z3drwKkf',
#   'https://api.spotify.com/v1/tracks/2wz3OO7ndJQj15z3drwKkf',
#   'https://api.spotify.com/v1/audio-analysis/2wz3OO7ndJQj15z3drwKkf',
#   168160,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   "Can't Express",
#   '2018-11-02',
#   0.601,
#   0.635,
#   10,
#   -5.534,
#   0,
#   0.364,
#   0.0162,
#   0,
#   0.164,
#   0.325,
#   161.759,
#   'audio_features',
#   '1Nch1dTOPyrA2MCcQtlxb8',
#   'spotify:track:1Nch1dTOPyrA2MCcQtlxb8',
#   'https://api.spotify.com/v1/tracks/1Nch1dTOPyrA2MCcQtlxb8',
#   'https://api.spotify.com/v1/audio-analysis/1Nch1dTOPyrA2MCcQtlxb8',
#   168552,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Area Codes',
#   '2018-11-02',
#   0.859,
#   0.647,
#   2,
#   -6.902,
#   1,
#   0.336,
#   0.00726,
#   0,
#   0.108,
#   0.169,
#   152.917,
#   'audio_features',
#   '3ULjPcUKiHNJJo4Znq8wjo',
#   'spotify:track:3ULjPcUKiHNJJo4Znq8wjo',
#   'https://api.spotify.com/v1/tracks/3ULjPcUKiHNJJo4Znq8wjo',
#   'https://api.spotify.com/v1/audio-analysis/3ULjPcUKiHNJJo4Znq8wjo',
#   175701,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Brand New',
#   '2018-11-02',
#   0.893,
#   0.545,
#   5,
#   -6.823,
#   0,
#   0.2,
#   0.00825,
#   0,
#   0.0888,
#   0.603,
#   148.055,
#   'audio_features',
#   '7KgCjoyL1lNA2YZoEJhD8x',
#   'spotify:track:7KgCjoyL1lNA2YZoEJhD8x',
#   'https://api.spotify.com/v1/tracks/7KgCjoyL1lNA2YZoEJhD8x',
#   'https://api.spotify.com/v1/audio-analysis/7KgCjoyL1lNA2YZoEJhD8x',
#   175308,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Down For Real',
#   '2018-11-02',
#   0.775,
#   0.551,
#   10,
#   -9.87,
#   0,
#   0.201,
#   0.00153,
#   0,
#   0.348,
#   0.514,
#   77.537,
#   'audio_features',
#   '5AL4chhuQBsENEAS1YtV38',
#   'spotify:track:5AL4chhuQBsENEAS1YtV38',
#   'https://api.spotify.com/v1/tracks/5AL4chhuQBsENEAS1YtV38',
#   'https://api.spotify.com/v1/audio-analysis/5AL4chhuQBsENEAS1YtV38',
#   198229,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Every Season',
#   '2018-11-02',
#   0.936,
#   0.704,
#   5,
#   -5.47,
#   0,
#   0.457,
#   0.0632,
#   0,
#   0.104,
#   0.566,
#   130.022,
#   'audio_features',
#   '1ttPzkTSpQUFcEGx8bjerL',
#   'spotify:track:1ttPzkTSpQUFcEGx8bjerL',
#   'https://api.spotify.com/v1/tracks/1ttPzkTSpQUFcEGx8bjerL',
#   'https://api.spotify.com/v1/audio-analysis/1ttPzkTSpQUFcEGx8bjerL',
#   214376,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Down Below',
#   '2018-11-02',
#   0.926,
#   0.454,
#   6,
#   -9.932,
#   1,
#   0.0732,
#   0.036,
#   0.000422,
#   0.0896,
#   0.34,
#   119.969,
#   'audio_features',
#   '4SWWe2OYC4mqf40Gc2RSdl',
#   'spotify:track:4SWWe2OYC4mqf40Gc2RSdl',
#   'https://api.spotify.com/v1/tracks/4SWWe2OYC4mqf40Gc2RSdl',
#   'https://api.spotify.com/v1/audio-analysis/4SWWe2OYC4mqf40Gc2RSdl',
#   224002,
#   4],
#  ['Roddy Ricch',
#   'Feed Tha Streets II',
#   'spotify:album:1jlIU9p7PChTK3AeqNpnsX',
#   'Day One (Outro)',
#   '2018-11-02',
#   0.693,
#   0.236,
#   1,
#   -10.393,
#   1,
#   0.337,
#   0.192,
#   0,
#   0.185,
#   0.102,
#   143.898,
#   'audio_features',
#   '3uIdxn5bUjOLOKN4QELnhb',
#   'spotify:track:3uIdxn5bUjOLOKN4QELnhb',
#   'https://api.spotify.com/v1/tracks/3uIdxn5bUjOLOKN4QELnhb',
#   'https://api.spotify.com/v1/audio-analysis/3uIdxn5bUjOLOKN4QELnhb',
#   161527,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Fucc It Up',
#   '2017-11-22',
#   0.8,
#   0.474,
#   1,
#   -9.304,
#   1,
#   0.238,
#   0.0466,
#   0,
#   0.0933,
#   0.348,
#   141.989,
#   'audio_features',
#   '67Qg38TcnAQnW0ne6uJXlK',
#   'spotify:track:67Qg38TcnAQnW0ne6uJXlK',
#   'https://api.spotify.com/v1/tracks/67Qg38TcnAQnW0ne6uJXlK',
#   'https://api.spotify.com/v1/audio-analysis/67Qg38TcnAQnW0ne6uJXlK',
#   202789,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Position',
#   '2017-11-22',
#   0.738,
#   0.557,
#   11,
#   -9.64,
#   0,
#   0.0633,
#   0.0578,
#   0,
#   0.0787,
#   0.391,
#   154.956,
#   'audio_features',
#   '4dubTxOHUboV9TWAQHVuxV',
#   'spotify:track:4dubTxOHUboV9TWAQHVuxV',
#   'https://api.spotify.com/v1/tracks/4dubTxOHUboV9TWAQHVuxV',
#   'https://api.spotify.com/v1/audio-analysis/4dubTxOHUboV9TWAQHVuxV',
#   198635,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Sak Passe',
#   '2017-11-22',
#   0.637,
#   0.501,
#   0,
#   -10.634,
#   1,
#   0.475,
#   0.0257,
#   0,
#   0.111,
#   0.304,
#   139.484,
#   'audio_features',
#   '3gqBMSwiu2QMjl3a63g7bV',
#   'spotify:track:3gqBMSwiu2QMjl3a63g7bV',
#   'https://api.spotify.com/v1/tracks/3gqBMSwiu2QMjl3a63g7bV',
#   'https://api.spotify.com/v1/audio-analysis/3gqBMSwiu2QMjl3a63g7bV',
#   164624,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Plottin (feat. GoGetta Kb)',
#   '2017-11-22',
#   0.888,
#   0.644,
#   0,
#   -8.32,
#   1,
#   0.155,
#   0.0762,
#   0,
#   0.0646,
#   0.32,
#   100.021,
#   'audio_features',
#   '3Qh0nx7wjVPC4aB8m6i6QT',
#   'spotify:track:3Qh0nx7wjVPC4aB8m6i6QT',
#   'https://api.spotify.com/v1/tracks/3Qh0nx7wjVPC4aB8m6i6QT',
#   'https://api.spotify.com/v1/audio-analysis/3Qh0nx7wjVPC4aB8m6i6QT',
#   172800,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Ricch Vibes',
#   '2017-11-22',
#   0.511,
#   0.387,
#   1,
#   -11.803,
#   1,
#   0.313,
#   0.0293,
#   0,
#   0.0819,
#   0.244,
#   150.337,
#   'audio_features',
#   '09hCDXRYJcJhjgEBlppMnN',
#   'spotify:track:09hCDXRYJcJhjgEBlppMnN',
#   'https://api.spotify.com/v1/tracks/09hCDXRYJcJhjgEBlppMnN',
#   'https://api.spotify.com/v1/audio-analysis/09hCDXRYJcJhjgEBlppMnN',
#   218958,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Money',
#   '2017-11-22',
#   0.796,
#   0.571,
#   8,
#   -7.851,
#   1,
#   0.068,
#   0.000853,
#   3.9e-05,
#   0.103,
#   0.531,
#   98.002,
#   'audio_features',
#   '7JLPydrZNIWzLPkIVwDBBn',
#   'spotify:track:7JLPydrZNIWzLPkIVwDBBn',
#   'https://api.spotify.com/v1/tracks/7JLPydrZNIWzLPkIVwDBBn',
#   'https://api.spotify.com/v1/audio-analysis/7JLPydrZNIWzLPkIVwDBBn',
#   199944,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Blue Streak',
#   '2017-11-22',
#   0.839,
#   0.527,
#   10,
#   -8.961,
#   0,
#   0.232,
#   0.0238,
#   0,
#   0.0609,
#   0.357,
#   139.97,
#   'audio_features',
#   '1D1TaCIWUtko86inlBE50K',
#   'spotify:track:1D1TaCIWUtko86inlBE50K',
#   'https://api.spotify.com/v1/tracks/1D1TaCIWUtko86inlBE50K',
#   'https://api.spotify.com/v1/audio-analysis/1D1TaCIWUtko86inlBE50K',
#   181786,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Feed tha Streets',
#   '2017-11-22',
#   0.604,
#   0.406,
#   8,
#   -11.838,
#   1,
#   0.673,
#   0.00912,
#   0,
#   0.115,
#   0.172,
#   152.661,
#   'audio_features',
#   '2WS4s26VptzjPqOy1uB0Nu',
#   'spotify:track:2WS4s26VptzjPqOy1uB0Nu',
#   'https://api.spotify.com/v1/tracks/2WS4s26VptzjPqOy1uB0Nu',
#   'https://api.spotify.com/v1/audio-analysis/2WS4s26VptzjPqOy1uB0Nu',
#   146664,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Poppin',
#   '2017-11-22',
#   0.84,
#   0.407,
#   5,
#   -11.574,
#   0,
#   0.0542,
#   0.00243,
#   3.79e-05,
#   0.181,
#   0.105,
#   127.956,
#   'audio_features',
#   '6kLdkhi4nl3E0ddyKP4ytr',
#   'spotify:track:6kLdkhi4nl3E0ddyKP4ytr',
#   'https://api.spotify.com/v1/tracks/6kLdkhi4nl3E0ddyKP4ytr',
#   'https://api.spotify.com/v1/audio-analysis/6kLdkhi4nl3E0ddyKP4ytr',
#   211944,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Chase tha Bag',
#   '2017-11-22',
#   0.829,
#   0.574,
#   6,
#   -8.879,
#   1,
#   0.32,
#   0.127,
#   0,
#   0.108,
#   0.358,
#   136.091,
#   'audio_features',
#   '0qVmQnartRlT7Pm3m2U6dJ',
#   'spotify:track:0qVmQnartRlT7Pm3m2U6dJ',
#   'https://api.spotify.com/v1/tracks/0qVmQnartRlT7Pm3m2U6dJ',
#   'https://api.spotify.com/v1/audio-analysis/0qVmQnartRlT7Pm3m2U6dJ',
#   212793,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Quality',
#   '2017-11-22',
#   0.82,
#   0.578,
#   2,
#   -5.541,
#   1,
#   0.171,
#   0.00399,
#   0,
#   0.108,
#   0.427,
#   139.969,
#   'audio_features',
#   '0wSzbPtA2LqmXuuvnGpOmx',
#   'spotify:track:0wSzbPtA2LqmXuuvnGpOmx',
#   'https://api.spotify.com/v1/tracks/0wSzbPtA2LqmXuuvnGpOmx',
#   'https://api.spotify.com/v1/audio-analysis/0wSzbPtA2LqmXuuvnGpOmx',
#   193392,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'HoodRicch',
#   '2017-11-22',
#   0.681,
#   0.585,
#   4,
#   -7.097,
#   0,
#   0.0836,
#   0.258,
#   0,
#   0.138,
#   0.173,
#   91.006,
#   'audio_features',
#   '4IGXwrHeY8lrHUUGQCeKEs',
#   'spotify:track:4IGXwrHeY8lrHUUGQCeKEs',
#   'https://api.spotify.com/v1/tracks/4IGXwrHeY8lrHUUGQCeKEs',
#   'https://api.spotify.com/v1/audio-analysis/4IGXwrHeY8lrHUUGQCeKEs',
#   179435,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Baby Boy (Struggle)',
#   '2017-11-22',
#   0.725,
#   0.4,
#   7,
#   -11.193,
#   1,
#   0.086,
#   0.13,
#   0,
#   0.106,
#   0.0784,
#   129.924,
#   'audio_features',
#   '1vMBVUkktVSiO3QDMmsST3',
#   'spotify:track:1vMBVUkktVSiO3QDMmsST3',
#   'https://api.spotify.com/v1/tracks/1vMBVUkktVSiO3QDMmsST3',
#   'https://api.spotify.com/v1/audio-analysis/1vMBVUkktVSiO3QDMmsST3',
#   250176,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Ricch Nigga (feat. P1)',
#   '2017-11-22',
#   0.612,
#   0.448,
#   1,
#   -13.445,
#   0,
#   0.193,
#   0.0444,
#   0,
#   0.178,
#   0.352,
#   160.028,
#   'audio_features',
#   '6WHnwsOWqFwsOCyfMH39LQ',
#   'spotify:track:6WHnwsOWqFwsOCyfMH39LQ',
#   'https://api.spotify.com/v1/tracks/6WHnwsOWqFwsOCyfMH39LQ',
#   'https://api.spotify.com/v1/audio-analysis/6WHnwsOWqFwsOCyfMH39LQ',
#   228075,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'I Might',
#   '2017-11-22',
#   0.838,
#   0.485,
#   3,
#   -6.292,
#   0,
#   0.182,
#   0.0226,
#   0,
#   0.131,
#   0.405,
#   144.084,
#   'audio_features',
#   '7cUK2RdQaQvM2gUc4acF5T',
#   'spotify:track:7cUK2RdQaQvM2gUc4acF5T',
#   'https://api.spotify.com/v1/tracks/7cUK2RdQaQvM2gUc4acF5T',
#   'https://api.spotify.com/v1/audio-analysis/7cUK2RdQaQvM2gUc4acF5T',
#   183384,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Uber',
#   '2017-11-22',
#   0.81,
#   0.385,
#   8,
#   -10.864,
#   1,
#   0.132,
#   0.0372,
#   0,
#   0.094,
#   0.175,
#   135.008,
#   'audio_features',
#   '7a1QuofsdZkW6JLjnZS1aA',
#   'spotify:track:7a1QuofsdZkW6JLjnZS1aA',
#   'https://api.spotify.com/v1/tracks/7a1QuofsdZkW6JLjnZS1aA',
#   'https://api.spotify.com/v1/audio-analysis/7a1QuofsdZkW6JLjnZS1aA',
#   170736,
#   4],
#  ['Roddy Ricch',
#   'Feed tha Streets',
#   'spotify:album:16QcQUMX0F1OnW06scl1us',
#   'Free Game',
#   '2017-11-22',
#   0.73,
#   0.562,
#   2,
#   -7.532,
#   1,
#   0.175,
#   0.0136,
#   0,
#   0.651,
#   0.156,
#   144.066,
#   'audio_features',
#   '4lJA7RDazKo3cLwhIL99en',
#   'spotify:track:4lJA7RDazKo3cLwhIL99en',
#   'https://api.spotify.com/v1/tracks/4lJA7RDazKo3cLwhIL99en',
#   'https://api.spotify.com/v1/audio-analysis/4lJA7RDazKo3cLwhIL99en',
#   173401,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Call Out My Name',
#   '2018-03-30',
#   0.461,
#   0.593,
#   1,
#   -4.954,
#   1,
#   0.0356,
#   0.17,
#   0,
#   0.307,
#   0.175,
#   134.17,
#   'audio_features',
#   '09mEdoA6zrmBPgTEN5qXmN',
#   'spotify:track:09mEdoA6zrmBPgTEN5qXmN',
#   'https://api.spotify.com/v1/tracks/09mEdoA6zrmBPgTEN5qXmN',
#   'https://api.spotify.com/v1/audio-analysis/09mEdoA6zrmBPgTEN5qXmN',
#   228373,
#   3],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Try Me',
#   '2018-03-30',
#   0.456,
#   0.679,
#   8,
#   -5.778,
#   0,
#   0.064,
#   0.596,
#   0.000573,
#   0.129,
#   0.107,
#   92.026,
#   'audio_features',
#   '4ppTAJUbNXELZcoUaL90wo',
#   'spotify:track:4ppTAJUbNXELZcoUaL90wo',
#   'https://api.spotify.com/v1/tracks/4ppTAJUbNXELZcoUaL90wo',
#   'https://api.spotify.com/v1/audio-analysis/4ppTAJUbNXELZcoUaL90wo',
#   221107,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Wasted Times',
#   '2018-03-30',
#   0.56,
#   0.678,
#   10,
#   -6.167,
#   0,
#   0.0581,
#   0.61,
#   1.42e-05,
#   0.111,
#   0.29,
#   122.585,
#   'audio_features',
#   '7DKS0rX27cCEPsK0R6tFWS',
#   'spotify:track:7DKS0rX27cCEPsK0R6tFWS',
#   'https://api.spotify.com/v1/tracks/7DKS0rX27cCEPsK0R6tFWS',
#   'https://api.spotify.com/v1/audio-analysis/7DKS0rX27cCEPsK0R6tFWS',
#   220293,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'I Was Never There',
#   '2018-03-30',
#   0.323,
#   0.737,
#   10,
#   -4.008,
#   1,
#   0.0338,
#   0.142,
#   0.000162,
#   0.163,
#   0.155,
#   113.26,
#   'audio_features',
#   '1cKHdTo9u0ZymJdPGSh6nq',
#   'spotify:track:1cKHdTo9u0ZymJdPGSh6nq',
#   'https://api.spotify.com/v1/tracks/1cKHdTo9u0ZymJdPGSh6nq',
#   'https://api.spotify.com/v1/audio-analysis/1cKHdTo9u0ZymJdPGSh6nq',
#   241067,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Hurt You',
#   '2018-03-30',
#   0.476,
#   0.718,
#   5,
#   -7.227,
#   0,
#   0.149,
#   0.263,
#   0.00261,
#   0.109,
#   0.361,
#   183.932,
#   'audio_features',
#   '6QdnKD1zwEgyOWtkrdzlOF',
#   'spotify:track:6QdnKD1zwEgyOWtkrdzlOF',
#   'https://api.spotify.com/v1/tracks/6QdnKD1zwEgyOWtkrdzlOF',
#   'https://api.spotify.com/v1/audio-analysis/6QdnKD1zwEgyOWtkrdzlOF',
#   230027,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Privilege',
#   '2018-03-30',
#   0.404,
#   0.564,
#   11,
#   -7.013,
#   0,
#   0.0344,
#   0.915,
#   0.00252,
#   0.134,
#   0.371,
#   93.631,
#   'audio_features',
#   '0Nwar8rweBUyfyuoyjjUvk',
#   'spotify:track:0Nwar8rweBUyfyuoyjjUvk',
#   'https://api.spotify.com/v1/tracks/0Nwar8rweBUyfyuoyjjUvk',
#   'https://api.spotify.com/v1/audio-analysis/0Nwar8rweBUyfyuoyjjUvk',
#   170573,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Call Out My Name - A Cappella',
#   '2018-03-30',
#   0.397,
#   0.339,
#   1,
#   -6.688,
#   1,
#   0.0361,
#   0.887,
#   0,
#   0.306,
#   0.459,
#   135.089,
#   'audio_features',
#   '5PTfZsGlsDDPH8i3PdQnXJ',
#   'spotify:track:5PTfZsGlsDDPH8i3PdQnXJ',
#   'https://api.spotify.com/v1/tracks/5PTfZsGlsDDPH8i3PdQnXJ',
#   'https://api.spotify.com/v1/audio-analysis/5PTfZsGlsDDPH8i3PdQnXJ',
#   224747,
#   3],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Starboy',
#   '2016-11-25',
#   0.678,
#   0.588,
#   7,
#   -7.015,
#   1,
#   0.276,
#   0.141,
#   6.35e-06,
#   0.137,
#   0.486,
#   186.005,
#   'audio_features',
#   '7MXVkk9YMctZqd1Srtv4MB',
#   'spotify:track:7MXVkk9YMctZqd1Srtv4MB',
#   'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#   'https://api.spotify.com/v1/audio-analysis/7MXVkk9YMctZqd1Srtv4MB',
#   230453,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Party Monster',
#   '2016-11-25',
#   0.572,
#   0.631,
#   1,
#   -8.389,
#   1,
#   0.104,
#   0.188,
#   2.31e-05,
#   0.259,
#   0.219,
#   77.519,
#   'audio_features',
#   '4F7A0DXBrmUAkp32uenhZt',
#   'spotify:track:4F7A0DXBrmUAkp32uenhZt',
#   'https://api.spotify.com/v1/tracks/4F7A0DXBrmUAkp32uenhZt',
#   'https://api.spotify.com/v1/audio-analysis/4F7A0DXBrmUAkp32uenhZt',
#   249213,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'False Alarm',
#   '2016-11-25',
#   0.518,
#   0.676,
#   8,
#   -6.373,
#   0,
#   0.0744,
#   0.0324,
#   3.62e-05,
#   0.189,
#   0.197,
#   173.998,
#   'audio_features',
#   '4oeaIftdpT3JuZLcCkKmVE',
#   'spotify:track:4oeaIftdpT3JuZLcCkKmVE',
#   'https://api.spotify.com/v1/tracks/4oeaIftdpT3JuZLcCkKmVE',
#   'https://api.spotify.com/v1/audio-analysis/4oeaIftdpT3JuZLcCkKmVE',
#   220307,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Reminder',
#   '2016-11-25',
#   0.705,
#   0.505,
#   8,
#   -6.923,
#   1,
#   0.192,
#   0.142,
#   0,
#   0.164,
#   0.391,
#   160.043,
#   'audio_features',
#   '37F0uwRSrdzkBiuj0D5UHI',
#   'spotify:track:37F0uwRSrdzkBiuj0D5UHI',
#   'https://api.spotify.com/v1/tracks/37F0uwRSrdzkBiuj0D5UHI',
#   'https://api.spotify.com/v1/audio-analysis/37F0uwRSrdzkBiuj0D5UHI',
#   218880,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Rockin’',
#   '2016-11-25',
#   0.737,
#   0.885,
#   9,
#   -5.547,
#   0,
#   0.206,
#   0.0132,
#   0,
#   0.0821,
#   0.752,
#   112.877,
#   'audio_features',
#   '36YCdzT57us0LhDmCYtrNE',
#   'spotify:track:36YCdzT57us0LhDmCYtrNE',
#   'https://api.spotify.com/v1/tracks/36YCdzT57us0LhDmCYtrNE',
#   'https://api.spotify.com/v1/audio-analysis/36YCdzT57us0LhDmCYtrNE',
#   232880,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Secrets',
#   '2016-11-25',
#   0.665,
#   0.771,
#   0,
#   -5.779,
#   1,
#   0.0533,
#   0.0155,
#   9.6e-06,
#   0.46,
#   0.764,
#   109.945,
#   'audio_features',
#   '00NAQYOP4AmWR549nnYJZu',
#   'spotify:track:00NAQYOP4AmWR549nnYJZu',
#   'https://api.spotify.com/v1/tracks/00NAQYOP4AmWR549nnYJZu',
#   'https://api.spotify.com/v1/audio-analysis/00NAQYOP4AmWR549nnYJZu',
#   265600,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'True Colors',
#   '2016-11-25',
#   0.624,
#   0.424,
#   1,
#   -8.237,
#   1,
#   0.24,
#   0.284,
#   0,
#   0.173,
#   0.584,
#   76.669,
#   'audio_features',
#   '1oGdVdYjeQvojGKDddxLQQ',
#   'spotify:track:1oGdVdYjeQvojGKDddxLQQ',
#   'https://api.spotify.com/v1/tracks/1oGdVdYjeQvojGKDddxLQQ',
#   'https://api.spotify.com/v1/audio-analysis/1oGdVdYjeQvojGKDddxLQQ',
#   206013,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Stargirl Interlude',
#   '2016-11-25',
#   0.638,
#   0.47,
#   5,
#   -12.697,
#   0,
#   0.132,
#   0.344,
#   0.193,
#   0.105,
#   0.442,
#   179.818,
#   'audio_features',
#   '4EDijkJdHBZZ0GwJ12iTAj',
#   'spotify:track:4EDijkJdHBZZ0GwJ12iTAj',
#   'https://api.spotify.com/v1/tracks/4EDijkJdHBZZ0GwJ12iTAj',
#   'https://api.spotify.com/v1/audio-analysis/4EDijkJdHBZZ0GwJ12iTAj',
#   111640,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Sidewalks',
#   '2016-11-25',
#   0.542,
#   0.721,
#   1,
#   -5.136,
#   0,
#   0.0625,
#   0.147,
#   0,
#   0.348,
#   0.623,
#   149.831,
#   'audio_features',
#   '4h90qkbnW1Qq6pBhoPvwko',
#   'spotify:track:4h90qkbnW1Qq6pBhoPvwko',
#   'https://api.spotify.com/v1/tracks/4h90qkbnW1Qq6pBhoPvwko',
#   'https://api.spotify.com/v1/audio-analysis/4h90qkbnW1Qq6pBhoPvwko',
#   231360,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Six Feet Under',
#   '2016-11-25',
#   0.772,
#   0.504,
#   6,
#   -8.219,
#   0,
#   0.0761,
#   0.129,
#   0,
#   0.125,
#   0.244,
#   140.035,
#   'audio_features',
#   '4mU5iXHeLgbR94siF7p1sY',
#   'spotify:track:4mU5iXHeLgbR94siF7p1sY',
#   'https://api.spotify.com/v1/tracks/4mU5iXHeLgbR94siF7p1sY',
#   'https://api.spotify.com/v1/audio-analysis/4mU5iXHeLgbR94siF7p1sY',
#   237573,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Love To Lay',
#   '2016-11-25',
#   0.711,
#   0.807,
#   7,
#   -5.053,
#   0,
#   0.0608,
#   0.0519,
#   0,
#   0.214,
#   0.699,
#   116.971,
#   'audio_features',
#   '27BgDmciSjoxTG0almHTpZ',
#   'spotify:track:27BgDmciSjoxTG0almHTpZ',
#   'https://api.spotify.com/v1/tracks/27BgDmciSjoxTG0almHTpZ',
#   'https://api.spotify.com/v1/audio-analysis/27BgDmciSjoxTG0almHTpZ',
#   223293,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'A Lonely Night',
#   '2016-11-25',
#   0.853,
#   0.663,
#   7,
#   -6.955,
#   0,
#   0.0755,
#   0.0431,
#   8.65e-06,
#   0.0891,
#   0.864,
#   113.999,
#   'audio_features',
#   '0ifooM33X1iBxVYyOkSbXW',
#   'spotify:track:0ifooM33X1iBxVYyOkSbXW',
#   'https://api.spotify.com/v1/tracks/0ifooM33X1iBxVYyOkSbXW',
#   'https://api.spotify.com/v1/audio-analysis/0ifooM33X1iBxVYyOkSbXW',
#   220173,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Attention',
#   '2016-11-25',
#   0.671,
#   0.428,
#   4,
#   -7.054,
#   0,
#   0.124,
#   0.682,
#   0.0002,
#   0.121,
#   0.36,
#   148.041,
#   'audio_features',
#   '6pDVjCUA3B1vg9waKutAsv',
#   'spotify:track:6pDVjCUA3B1vg9waKutAsv',
#   'https://api.spotify.com/v1/tracks/6pDVjCUA3B1vg9waKutAsv',
#   'https://api.spotify.com/v1/audio-analysis/6pDVjCUA3B1vg9waKutAsv',
#   197653,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Ordinary Life',
#   '2016-11-25',
#   0.544,
#   0.586,
#   7,
#   -7.486,
#   0,
#   0.0794,
#   0.0276,
#   0,
#   0.0961,
#   0.361,
#   149.882,
#   'audio_features',
#   '15k2nBQJ0teDmPZHrOXL2N',
#   'spotify:track:15k2nBQJ0teDmPZHrOXL2N',
#   'https://api.spotify.com/v1/tracks/15k2nBQJ0teDmPZHrOXL2N',
#   'https://api.spotify.com/v1/audio-analysis/15k2nBQJ0teDmPZHrOXL2N',
#   221920,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Nothing Without You',
#   '2016-11-25',
#   0.599,
#   0.635,
#   1,
#   -8.101,
#   1,
#   0.0679,
#   0.064,
#   0,
#   0.0878,
#   0.194,
#   109.919,
#   'audio_features',
#   '57qiTKh8bVX0VtfUNTQqhw',
#   'spotify:track:57qiTKh8bVX0VtfUNTQqhw',
#   'https://api.spotify.com/v1/tracks/57qiTKh8bVX0VtfUNTQqhw',
#   'https://api.spotify.com/v1/audio-analysis/57qiTKh8bVX0VtfUNTQqhw',
#   198653,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'All I Know',
#   '2016-11-25',
#   0.469,
#   0.417,
#   8,
#   -10.614,
#   0,
#   0.0704,
#   0.418,
#   0.000189,
#   0.102,
#   0.175,
#   120.012,
#   'audio_features',
#   '0NWqNXBJTpXbkI5rPWNy3p',
#   'spotify:track:0NWqNXBJTpXbkI5rPWNy3p',
#   'https://api.spotify.com/v1/tracks/0NWqNXBJTpXbkI5rPWNy3p',
#   'https://api.spotify.com/v1/audio-analysis/0NWqNXBJTpXbkI5rPWNy3p',
#   321027,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Die For You',
#   '2016-11-25',
#   0.586,
#   0.525,
#   1,
#   -7.163,
#   0,
#   0.0615,
#   0.111,
#   0,
#   0.134,
#   0.508,
#   133.629,
#   'audio_features',
#   '2Ch7LmS7r2Gy2kc64wv3Bz',
#   'spotify:track:2Ch7LmS7r2Gy2kc64wv3Bz',
#   'https://api.spotify.com/v1/tracks/2Ch7LmS7r2Gy2kc64wv3Bz',
#   'https://api.spotify.com/v1/audio-analysis/2Ch7LmS7r2Gy2kc64wv3Bz',
#   260253,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'I Feel It Coming',
#   '2016-11-25',
#   0.773,
#   0.819,
#   0,
#   -5.946,
#   0,
#   0.118,
#   0.426,
#   0,
#   0.0679,
#   0.585,
#   92.99,
#   'audio_features',
#   '3dhjNA0jGA8vHBQ1VdD6vV',
#   'spotify:track:3dhjNA0jGA8vHBQ1VdD6vV',
#   'https://api.spotify.com/v1/tracks/3dhjNA0jGA8vHBQ1VdD6vV',
#   'https://api.spotify.com/v1/audio-analysis/3dhjNA0jGA8vHBQ1VdD6vV',
#   269187,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Starboy',
#   '2016-11-24',
#   0.677,
#   0.592,
#   7,
#   -7.108,
#   1,
#   0.281,
#   0.134,
#   3.86e-06,
#   0.175,
#   0.528,
#   186.038,
#   'audio_features',
#   '7HtPBwBoCBDy1tpstag7HL',
#   'spotify:track:7HtPBwBoCBDy1tpstag7HL',
#   'https://api.spotify.com/v1/tracks/7HtPBwBoCBDy1tpstag7HL',
#   'https://api.spotify.com/v1/audio-analysis/7HtPBwBoCBDy1tpstag7HL',
#   230453,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Party Monster',
#   '2016-11-24',
#   0.588,
#   0.635,
#   1,
#   -8.417,
#   1,
#   0.0531,
#   0.191,
#   1.24e-05,
#   0.259,
#   0.208,
#   77.486,
#   'audio_features',
#   '2dNVHgOx99fv4oSVF9GN1Y',
#   'spotify:track:2dNVHgOx99fv4oSVF9GN1Y',
#   'https://api.spotify.com/v1/tracks/2dNVHgOx99fv4oSVF9GN1Y',
#   'https://api.spotify.com/v1/audio-analysis/2dNVHgOx99fv4oSVF9GN1Y',
#   249213,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'False Alarm',
#   '2016-11-24',
#   0.518,
#   0.676,
#   8,
#   -6.373,
#   0,
#   0.0744,
#   0.0324,
#   3.62e-05,
#   0.189,
#   0.197,
#   173.998,
#   'audio_features',
#   '32lgtADX2cB9I4KFs1Y1py',
#   'spotify:track:32lgtADX2cB9I4KFs1Y1py',
#   'https://api.spotify.com/v1/tracks/32lgtADX2cB9I4KFs1Y1py',
#   'https://api.spotify.com/v1/audio-analysis/32lgtADX2cB9I4KFs1Y1py',
#   220307,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Reminder',
#   '2016-11-24',
#   0.744,
#   0.496,
#   8,
#   -6.931,
#   1,
#   0.0804,
#   0.16,
#   1.72e-06,
#   0.164,
#   0.446,
#   80.031,
#   'audio_features',
#   '31F83eeeh5Sz6g616t13DW',
#   'spotify:track:31F83eeeh5Sz6g616t13DW',
#   'https://api.spotify.com/v1/tracks/31F83eeeh5Sz6g616t13DW',
#   'https://api.spotify.com/v1/audio-analysis/31F83eeeh5Sz6g616t13DW',
#   218880,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Rockin’',
#   '2016-11-24',
#   0.736,
#   0.883,
#   9,
#   -5.595,
#   0,
#   0.214,
#   0.0117,
#   0,
#   0.0734,
#   0.797,
#   112.92,
#   'audio_features',
#   '02V0fopGouDF5GbDHftv4S',
#   'spotify:track:02V0fopGouDF5GbDHftv4S',
#   'https://api.spotify.com/v1/tracks/02V0fopGouDF5GbDHftv4S',
#   'https://api.spotify.com/v1/audio-analysis/02V0fopGouDF5GbDHftv4S',
#   232880,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Secrets',
#   '2016-11-24',
#   0.665,
#   0.771,
#   0,
#   -5.779,
#   1,
#   0.0533,
#   0.0155,
#   9.6e-06,
#   0.46,
#   0.764,
#   109.948,
#   'audio_features',
#   '3DX4Y0egvc0slLcLl31h2p',
#   'spotify:track:3DX4Y0egvc0slLcLl31h2p',
#   'https://api.spotify.com/v1/tracks/3DX4Y0egvc0slLcLl31h2p',
#   'https://api.spotify.com/v1/audio-analysis/3DX4Y0egvc0slLcLl31h2p',
#   265600,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'True Colors',
#   '2016-11-24',
#   0.616,
#   0.424,
#   1,
#   -8.237,
#   1,
#   0.251,
#   0.284,
#   0,
#   0.173,
#   0.582,
#   76.676,
#   'audio_features',
#   '6i759FCuKx713ZnYjtpQGU',
#   'spotify:track:6i759FCuKx713ZnYjtpQGU',
#   'https://api.spotify.com/v1/tracks/6i759FCuKx713ZnYjtpQGU',
#   'https://api.spotify.com/v1/audio-analysis/6i759FCuKx713ZnYjtpQGU',
#   206027,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Stargirl Interlude',
#   '2016-11-24',
#   0.715,
#   0.47,
#   5,
#   -12.638,
#   0,
#   0.0772,
#   0.353,
#   0.0923,
#   0.104,
#   0.426,
#   89.965,
#   'audio_features',
#   '5gDWsRxpJ2lZAffh5p7K0w',
#   'spotify:track:5gDWsRxpJ2lZAffh5p7K0w',
#   'https://api.spotify.com/v1/tracks/5gDWsRxpJ2lZAffh5p7K0w',
#   'https://api.spotify.com/v1/audio-analysis/5gDWsRxpJ2lZAffh5p7K0w',
#   111627,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Sidewalks',
#   '2016-11-24',
#   0.536,
#   0.721,
#   1,
#   -5.144,
#   0,
#   0.0649,
#   0.15,
#   0,
#   0.348,
#   0.612,
#   149.839,
#   'audio_features',
#   '2Eomvb6YHo8lhfleLufuca',
#   'spotify:track:2Eomvb6YHo8lhfleLufuca',
#   'https://api.spotify.com/v1/tracks/2Eomvb6YHo8lhfleLufuca',
#   'https://api.spotify.com/v1/audio-analysis/2Eomvb6YHo8lhfleLufuca',
#   231360,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Six Feet Under',
#   '2016-11-24',
#   0.776,
#   0.483,
#   6,
#   -8.262,
#   0,
#   0.0784,
#   0.121,
#   0,
#   0.118,
#   0.24,
#   140.005,
#   'audio_features',
#   '2QErvFddvI9I4QokOsQXdC',
#   'spotify:track:2QErvFddvI9I4QokOsQXdC',
#   'https://api.spotify.com/v1/tracks/2QErvFddvI9I4QokOsQXdC',
#   'https://api.spotify.com/v1/audio-analysis/2QErvFddvI9I4QokOsQXdC',
#   237573,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Love To Lay',
#   '2016-11-24',
#   0.711,
#   0.807,
#   7,
#   -5.053,
#   0,
#   0.0608,
#   0.0519,
#   0,
#   0.214,
#   0.699,
#   116.971,
#   'audio_features',
#   '1E43TJhKcM8hXgM958ROQ1',
#   'spotify:track:1E43TJhKcM8hXgM958ROQ1',
#   'https://api.spotify.com/v1/tracks/1E43TJhKcM8hXgM958ROQ1',
#   'https://api.spotify.com/v1/audio-analysis/1E43TJhKcM8hXgM958ROQ1',
#   223293,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'A Lonely Night',
#   '2016-11-24',
#   0.853,
#   0.663,
#   7,
#   -6.955,
#   0,
#   0.0755,
#   0.0431,
#   8.65e-06,
#   0.0891,
#   0.864,
#   113.999,
#   'audio_features',
#   '4UknpXoLjlB7Mao4UWcJ2o',
#   'spotify:track:4UknpXoLjlB7Mao4UWcJ2o',
#   'https://api.spotify.com/v1/tracks/4UknpXoLjlB7Mao4UWcJ2o',
#   'https://api.spotify.com/v1/audio-analysis/4UknpXoLjlB7Mao4UWcJ2o',
#   220173,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Attention',
#   '2016-11-24',
#   0.668,
#   0.435,
#   4,
#   -7.115,
#   0,
#   0.117,
#   0.726,
#   8.17e-05,
#   0.117,
#   0.361,
#   148.069,
#   'audio_features',
#   '0HlIziU2FZ7BjiQDt8Zost',
#   'spotify:track:0HlIziU2FZ7BjiQDt8Zost',
#   'https://api.spotify.com/v1/tracks/0HlIziU2FZ7BjiQDt8Zost',
#   'https://api.spotify.com/v1/audio-analysis/0HlIziU2FZ7BjiQDt8Zost',
#   197653,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Ordinary Life',
#   '2016-11-24',
#   0.544,
#   0.586,
#   7,
#   -7.486,
#   0,
#   0.0794,
#   0.0276,
#   0,
#   0.0962,
#   0.361,
#   149.882,
#   'audio_features',
#   '7lsYGc5H5DHktxO7gbB8bN',
#   'spotify:track:7lsYGc5H5DHktxO7gbB8bN',
#   'https://api.spotify.com/v1/tracks/7lsYGc5H5DHktxO7gbB8bN',
#   'https://api.spotify.com/v1/audio-analysis/7lsYGc5H5DHktxO7gbB8bN',
#   221920,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Nothing Without You',
#   '2016-11-24',
#   0.599,
#   0.635,
#   1,
#   -8.101,
#   1,
#   0.0679,
#   0.064,
#   0,
#   0.0878,
#   0.194,
#   109.919,
#   'audio_features',
#   '3Te3gG6MPEDNqLGzWrjKC3',
#   'spotify:track:3Te3gG6MPEDNqLGzWrjKC3',
#   'https://api.spotify.com/v1/tracks/3Te3gG6MPEDNqLGzWrjKC3',
#   'https://api.spotify.com/v1/audio-analysis/3Te3gG6MPEDNqLGzWrjKC3',
#   198653,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'All I Know',
#   '2016-11-24',
#   0.636,
#   0.402,
#   8,
#   -10.746,
#   0,
#   0.0559,
#   0.461,
#   0.00112,
#   0.101,
#   0.194,
#   120.02,
#   'audio_features',
#   '4MBGysmc3qsFY3jYEgYfHe',
#   'spotify:track:4MBGysmc3qsFY3jYEgYfHe',
#   'https://api.spotify.com/v1/tracks/4MBGysmc3qsFY3jYEgYfHe',
#   'https://api.spotify.com/v1/audio-analysis/4MBGysmc3qsFY3jYEgYfHe',
#   321027,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Die For You',
#   '2016-11-24',
#   0.586,
#   0.525,
#   1,
#   -7.163,
#   0,
#   0.0615,
#   0.111,
#   0,
#   0.134,
#   0.508,
#   133.629,
#   'audio_features',
#   '2LBqCSwhJGcFQeTHMVGwy3',
#   'spotify:track:2LBqCSwhJGcFQeTHMVGwy3',
#   'https://api.spotify.com/v1/tracks/2LBqCSwhJGcFQeTHMVGwy3',
#   'https://api.spotify.com/v1/audio-analysis/2LBqCSwhJGcFQeTHMVGwy3',
#   260253,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'I Feel It Coming',
#   '2016-11-24',
#   0.773,
#   0.819,
#   0,
#   -5.946,
#   0,
#   0.118,
#   0.426,
#   0,
#   0.0679,
#   0.585,
#   92.99,
#   'audio_features',
#   '5GXAXm5YOmYT0kL5jHvYBt',
#   'spotify:track:5GXAXm5YOmYT0kL5jHvYBt',
#   'https://api.spotify.com/v1/tracks/5GXAXm5YOmYT0kL5jHvYBt',
#   'https://api.spotify.com/v1/audio-analysis/5GXAXm5YOmYT0kL5jHvYBt',
#   269187,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Real Life',
#   '2016-03-16',
#   0.58,
#   0.653,
#   11,
#   -5.04,
#   0,
#   0.0506,
#   0.438,
#   0,
#   0.351,
#   0.346,
#   90.726,
#   'audio_features',
#   '60jW6P7AGw2FozTaqctJ4i',
#   'spotify:track:60jW6P7AGw2FozTaqctJ4i',
#   'https://api.spotify.com/v1/tracks/60jW6P7AGw2FozTaqctJ4i',
#   'https://api.spotify.com/v1/audio-analysis/60jW6P7AGw2FozTaqctJ4i',
#   223347,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Losers',
#   '2016-03-16',
#   0.661,
#   0.483,
#   0,
#   -9.793,
#   0,
#   0.0496,
#   0.0309,
#   0.000801,
#   0.507,
#   0.296,
#   90.994,
#   'audio_features',
#   '2bWO9puW3hXQcZZsehDRCo',
#   'spotify:track:2bWO9puW3hXQcZZsehDRCo',
#   'https://api.spotify.com/v1/tracks/2bWO9puW3hXQcZZsehDRCo',
#   'https://api.spotify.com/v1/audio-analysis/2bWO9puW3hXQcZZsehDRCo',
#   281173,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Tell Your Friends',
#   '2016-03-16',
#   0.565,
#   0.454,
#   1,
#   -11.091,
#   0,
#   0.0461,
#   0.265,
#   0,
#   0.181,
#   0.312,
#   74.809,
#   'audio_features',
#   '4cgDltqQz6YKPotLNbfGDn',
#   'spotify:track:4cgDltqQz6YKPotLNbfGDn',
#   'https://api.spotify.com/v1/tracks/4cgDltqQz6YKPotLNbfGDn',
#   'https://api.spotify.com/v1/audio-analysis/4cgDltqQz6YKPotLNbfGDn',
#   334200,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Often',
#   '2016-03-16',
#   0.567,
#   0.622,
#   7,
#   -9.821,
#   0,
#   0.046,
#   0.248,
#   0,
#   0.139,
#   0.0751,
#   133.984,
#   'audio_features',
#   '3Hf7SsKqVeZ0uW164edrJl',
#   'spotify:track:3Hf7SsKqVeZ0uW164edrJl',
#   'https://api.spotify.com/v1/tracks/3Hf7SsKqVeZ0uW164edrJl',
#   'https://api.spotify.com/v1/audio-analysis/3Hf7SsKqVeZ0uW164edrJl',
#   249107,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'The Hills',
#   '2016-03-16',
#   0.374,
#   0.55,
#   0,
#   -7.007,
#   0,
#   0.0848,
#   0.0841,
#   0,
#   0.139,
#   0.124,
#   112.912,
#   'audio_features',
#   '7H5EBs3aGqRPZaGEvU6y6F',
#   'spotify:track:7H5EBs3aGqRPZaGEvU6y6F',
#   'https://api.spotify.com/v1/tracks/7H5EBs3aGqRPZaGEvU6y6F',
#   'https://api.spotify.com/v1/audio-analysis/7H5EBs3aGqRPZaGEvU6y6F',
#   242280,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Acquainted',
#   '2016-03-16',
#   0.485,
#   0.481,
#   7,
#   -9.858,
#   0,
#   0.051,
#   0.437,
#   0,
#   0.0861,
#   0.233,
#   105.934,
#   'audio_features',
#   '5OejsjQoFVXniKLsXYs7G4',
#   'spotify:track:5OejsjQoFVXniKLsXYs7G4',
#   'https://api.spotify.com/v1/tracks/5OejsjQoFVXniKLsXYs7G4',
#   'https://api.spotify.com/v1/audio-analysis/5OejsjQoFVXniKLsXYs7G4',
#   348893,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   "Can't Feel My Face",
#   '2016-03-16',
#   0.705,
#   0.769,
#   9,
#   -5.526,
#   0,
#   0.0426,
#   0.112,
#   0,
#   0.105,
#   0.59,
#   107.939,
#   'audio_features',
#   '64bYIchESwtANfBlwJoK1e',
#   'spotify:track:64bYIchESwtANfBlwJoK1e',
#   'https://api.spotify.com/v1/tracks/64bYIchESwtANfBlwJoK1e',
#   'https://api.spotify.com/v1/audio-analysis/64bYIchESwtANfBlwJoK1e',
#   213520,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Shameless',
#   '2016-03-16',
#   0.603,
#   0.562,
#   6,
#   -8.311,
#   1,
#   0.0267,
#   0.146,
#   0,
#   0.109,
#   0.244,
#   100.038,
#   'audio_features',
#   '7MMQME7nvRBZ1ru82bJ9of',
#   'spotify:track:7MMQME7nvRBZ1ru82bJ9of',
#   'https://api.spotify.com/v1/tracks/7MMQME7nvRBZ1ru82bJ9of',
#   'https://api.spotify.com/v1/audio-analysis/7MMQME7nvRBZ1ru82bJ9of',
#   253507,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Earned It (Fifty Shades Of Grey)',
#   '2016-03-16',
#   0.647,
#   0.291,
#   2,
#   -8.275,
#   0,
#   0.0363,
#   0.408,
#   0,
#   0.0772,
#   0.4,
#   119.839,
#   'audio_features',
#   '7ID2dydg1QFuWObmdhwzfm',
#   'spotify:track:7ID2dydg1QFuWObmdhwzfm',
#   'https://api.spotify.com/v1/tracks/7ID2dydg1QFuWObmdhwzfm',
#   'https://api.spotify.com/v1/audio-analysis/7ID2dydg1QFuWObmdhwzfm',
#   277707,
#   3],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'In The Night',
#   '2016-03-16',
#   0.4,
#   0.673,
#   7,
#   -4.967,
#   1,
#   0.125,
#   0.0803,
#   0,
#   0.0484,
#   0.508,
#   112.122,
#   'audio_features',
#   '17ghHlAfjnAIEpYGTlX4GL',
#   'spotify:track:17ghHlAfjnAIEpYGTlX4GL',
#   'https://api.spotify.com/v1/tracks/17ghHlAfjnAIEpYGTlX4GL',
#   'https://api.spotify.com/v1/audio-analysis/17ghHlAfjnAIEpYGTlX4GL',
#   235627,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'As You Are',
#   '2016-03-16',
#   0.371,
#   0.329,
#   0,
#   -9.667,
#   0,
#   0.0574,
#   0.131,
#   0.00625,
#   0.279,
#   0.0539,
#   173.661,
#   'audio_features',
#   '2d1ogCmohNk5jsRTk0eCNs',
#   'spotify:track:2d1ogCmohNk5jsRTk0eCNs',
#   'https://api.spotify.com/v1/tracks/2d1ogCmohNk5jsRTk0eCNs',
#   'https://api.spotify.com/v1/audio-analysis/2d1ogCmohNk5jsRTk0eCNs',
#   340493,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Dark Times',
#   '2016-03-16',
#   0.501,
#   0.403,
#   9,
#   -9.607,
#   0,
#   0.0752,
#   0.114,
#   1.1e-05,
#   0.124,
#   0.27,
#   132.608,
#   'audio_features',
#   '3JOh1LxSDVjTLF5DAB8R5M',
#   'spotify:track:3JOh1LxSDVjTLF5DAB8R5M',
#   'https://api.spotify.com/v1/tracks/3JOh1LxSDVjTLF5DAB8R5M',
#   'https://api.spotify.com/v1/audio-analysis/3JOh1LxSDVjTLF5DAB8R5M',
#   260640,
#   3],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Prisoner',
#   '2016-03-16',
#   0.55,
#   0.404,
#   0,
#   -12.755,
#   0,
#   0.0398,
#   0.441,
#   0.00022,
#   0.11,
#   0.329,
#   135.016,
#   'audio_features',
#   '3q3INoUz56tAaKXZSkONon',
#   'spotify:track:3q3INoUz56tAaKXZSkONon',
#   'https://api.spotify.com/v1/tracks/3q3INoUz56tAaKXZSkONon',
#   'https://api.spotify.com/v1/audio-analysis/3q3INoUz56tAaKXZSkONon',
#   274960,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Angel',
#   '2016-03-16',
#   0.626,
#   0.583,
#   10,
#   -7.574,
#   0,
#   0.0435,
#   0.105,
#   0,
#   0.115,
#   0.335,
#   127.956,
#   'audio_features',
#   '2qHMUxqGht8K1wNjXG40wH',
#   'spotify:track:2qHMUxqGht8K1wNjXG40wH',
#   'https://api.spotify.com/v1/tracks/2qHMUxqGht8K1wNjXG40wH',
#   'https://api.spotify.com/v1/audio-analysis/2qHMUxqGht8K1wNjXG40wH',
#   377627,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   "Can't Feel My Face - Martin Garrix Remix",
#   '2016-03-16',
#   0.605,
#   0.714,
#   9,
#   -5.432,
#   0,
#   0.101,
#   0.0104,
#   2.35e-05,
#   0.324,
#   0.136,
#   128.025,
#   'audio_features',
#   '5KIfOGEy5DM2TaT0ph5nYM',
#   'spotify:track:5KIfOGEy5DM2TaT0ph5nYM',
#   'https://api.spotify.com/v1/tracks/5KIfOGEy5DM2TaT0ph5nYM',
#   'https://api.spotify.com/v1/audio-analysis/5KIfOGEy5DM2TaT0ph5nYM',
#   253933,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'The Hills - Remix',
#   '2016-03-16',
#   0.65,
#   0.632,
#   0,
#   -6.672,
#   0,
#   0.184,
#   0.0681,
#   0,
#   0.0875,
#   0.33,
#   112.927,
#   'audio_features',
#   '2jpBr2dJrIgrpkqorINSAa',
#   'spotify:track:2jpBr2dJrIgrpkqorINSAa',
#   'https://api.spotify.com/v1/tracks/2jpBr2dJrIgrpkqorINSAa',
#   'https://api.spotify.com/v1/audio-analysis/2jpBr2dJrIgrpkqorINSAa',
#   263960,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'The Hills - Remix',
#   '2016-03-16',
#   0.409,
#   0.602,
#   0,
#   -7.025,
#   0,
#   0.108,
#   0.0974,
#   0,
#   0.107,
#   0.186,
#   110.463,
#   'audio_features',
#   '019FM2BxcPE2vyGWeOWhvS',
#   'spotify:track:019FM2BxcPE2vyGWeOWhvS',
#   'https://api.spotify.com/v1/tracks/019FM2BxcPE2vyGWeOWhvS',
#   'https://api.spotify.com/v1/audio-analysis/019FM2BxcPE2vyGWeOWhvS',
#   243493,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Real Life',
#   '2015-08-28',
#   0.581,
#   0.653,
#   11,
#   -5.04,
#   0,
#   0.0506,
#   0.438,
#   0,
#   0.351,
#   0.346,
#   90.726,
#   'audio_features',
#   '03j354P848KtNU2FVSwkDG',
#   'spotify:track:03j354P848KtNU2FVSwkDG',
#   'https://api.spotify.com/v1/tracks/03j354P848KtNU2FVSwkDG',
#   'https://api.spotify.com/v1/audio-analysis/03j354P848KtNU2FVSwkDG',
#   223373,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Losers',
#   '2015-08-28',
#   0.666,
#   0.485,
#   0,
#   -9.85,
#   0,
#   0.0527,
#   0.0355,
#   0.000603,
#   0.504,
#   0.288,
#   91.009,
#   'audio_features',
#   '1bAvtmTl0F9loyz9AwPwp7',
#   'spotify:track:1bAvtmTl0F9loyz9AwPwp7',
#   'https://api.spotify.com/v1/tracks/1bAvtmTl0F9loyz9AwPwp7',
#   'https://api.spotify.com/v1/audio-analysis/1bAvtmTl0F9loyz9AwPwp7',
#   281147,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
# ...
#   'https://api.spotify.com/v1/tracks/18opVAkzdk9ZsFS5i5hzGW',
#   'https://api.spotify.com/v1/audio-analysis/18opVAkzdk9ZsFS5i5hzGW',
#   325272,
#   4],
#  ['Future',
#   'Future',
#   'spotify:album:7J79msvl9CoRrMTyfDjNms',
#   'Fell In Luv (feat. Doe Boy & Mexico Rann)',
#   '2013-12-03',
#   0.532,
#   0.381,
#   2,
#   -8.583,
#   1,
#   0.304,
#   0.126,
#   0,
#   0.266,
#   0.104,
#   139.9,
#   'audio_features',
#   '0fx9skeXHe0wOq8KFiWVBj',
#   'spotify:track:0fx9skeXHe0wOq8KFiWVBj',
#   'https://api.spotify.com/v1/tracks/0fx9skeXHe0wOq8KFiWVBj',
#   'https://api.spotify.com/v1/audio-analysis/0fx9skeXHe0wOq8KFiWVBj',
#   179587,
#   4],
#  ['Future',
#   'Future',
#   'spotify:album:7J79msvl9CoRrMTyfDjNms',
#   'What You Mean (feat. Soulja Boy)',
#   '2013-12-03',
#   0.77,
#   0.776,
#   9,
#   -1.122,
#   1,
#   0.0366,
#   0.539,
#   0,
#   0.0835,
#   0.217,
#   128.054,
#   'audio_features',
#   '4gwc5ay4Oy6wuQjWPB1yfh',
#   'spotify:track:4gwc5ay4Oy6wuQjWPB1yfh',
#   'https://api.spotify.com/v1/tracks/4gwc5ay4Oy6wuQjWPB1yfh',
#   'https://api.spotify.com/v1/audio-analysis/4gwc5ay4Oy6wuQjWPB1yfh',
#   287769,
#   4],
#  ['Future',
#   'Future',
#   'spotify:album:7J79msvl9CoRrMTyfDjNms',
#   'Long Time (feat. Fat Joe)',
#   '2013-12-03',
#   0.607,
#   0.683,
#   5,
#   -6.069,
#   0,
#   0.0407,
#   0.0103,
#   0,
#   0.384,
#   0.163,
#   133.971,
#   'audio_features',
#   '3dHCdLyOBYX0ZGS1pAYifV',
#   'spotify:track:3dHCdLyOBYX0ZGS1pAYifV',
#   'https://api.spotify.com/v1/tracks/3dHCdLyOBYX0ZGS1pAYifV',
#   'https://api.spotify.com/v1/audio-analysis/3dHCdLyOBYX0ZGS1pAYifV',
#   245078,
#   4],
#  ['Future',
#   'Future',
#   'spotify:album:7J79msvl9CoRrMTyfDjNms',
#   "Way I'm Ballin (feat. Lil Wayne, Mack Maine, Birdman)",
#   '2013-12-03',
#   0.648,
#   0.683,
#   9,
#   -6.836,
#   1,
#   0.325,
#   0.0292,
#   0,
#   0.105,
#   0.51,
#   140.074,
#   'audio_features',
#   '3ObiADfpKA79aHiZj8C6Ou',
#   'spotify:track:3ObiADfpKA79aHiZj8C6Ou',
#   'https://api.spotify.com/v1/tracks/3ObiADfpKA79aHiZj8C6Ou',
#   'https://api.spotify.com/v1/audio-analysis/3ObiADfpKA79aHiZj8C6Ou',
#   229927,
#   4],
#  ['Future',
#   'Future',
#   'spotify:album:7J79msvl9CoRrMTyfDjNms',
#   'These Eyes (feat. Bin Bank Black)',
#   '2013-12-03',
#   0.733,
#   0.751,
#   4,
#   -5.731,
#   1,
#   0.166,
#   0.111,
#   0,
#   0.341,
#   0.352,
#   132.922,
#   'audio_features',
#   '2A7GQf9p27acAtsz3yQErM',
#   'spotify:track:2A7GQf9p27acAtsz3yQErM',
#   'https://api.spotify.com/v1/tracks/2A7GQf9p27acAtsz3yQErM',
#   'https://api.spotify.com/v1/audio-analysis/2A7GQf9p27acAtsz3yQErM',
#   171509,
#   4],
#  ['Future',
#   'Future',
#   'spotify:album:7J79msvl9CoRrMTyfDjNms',
#   'Twilight Zone (feat. Trey Songz & Sean Garrett)',
#   '2013-12-03',
#   0.7,
#   0.63,
#   1,
#   -8.498,
#   1,
#   0.122,
#   0.163,
#   8.68e-05,
#   0.203,
#   0.62,
#   139.9,
#   'audio_features',
#   '7xOD2ygnkZJGMs7yg99nbL',
#   'spotify:track:7xOD2ygnkZJGMs7yg99nbL',
#   'https://api.spotify.com/v1/tracks/7xOD2ygnkZJGMs7yg99nbL',
#   'https://api.spotify.com/v1/audio-analysis/7xOD2ygnkZJGMs7yg99nbL',
#   252625,
#   4],
#  ['Future',
#   'Future',
#   'spotify:album:7J79msvl9CoRrMTyfDjNms',
#   'Get That Money (feat. Drumma Boy & Young Dolph)',
#   '2013-12-03',
#   0.634,
#   0.712,
#   11,
#   -7.626,
#   0,
#   0.0378,
#   0.0813,
#   0,
#   0.107,
#   0.0793,
#   140.003,
#   'audio_features',
#   '5RNl5P8UoGFS71QfiIQjFv',
#   'spotify:track:5RNl5P8UoGFS71QfiIQjFv',
#   'https://api.spotify.com/v1/tracks/5RNl5P8UoGFS71QfiIQjFv',
#   'https://api.spotify.com/v1/audio-analysis/5RNl5P8UoGFS71QfiIQjFv',
#   273230,
#   3],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'Any Many Miny Mo',
#   '2013-05-30',
#   0.611,
#   0.661,
#   11,
#   -5.972,
#   1,
#   0.158,
#   0.249,
#   0,
#   0.594,
#   0.574,
#   142.124,
#   'audio_features',
#   '6P2EHwsZgUbCAilwalaF0i',
#   'spotify:track:6P2EHwsZgUbCAilwalaF0i',
#   'https://api.spotify.com/v1/tracks/6P2EHwsZgUbCAilwalaF0i',
#   'https://api.spotify.com/v1/audio-analysis/6P2EHwsZgUbCAilwalaF0i',
#   193533,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'Hos Go Crazy',
#   '2013-05-30',
#   0.814,
#   0.516,
#   8,
#   -6.937,
#   1,
#   0.104,
#   0.0846,
#   0,
#   0.368,
#   0.238,
#   134.902,
#   'audio_features',
#   '1WSA2pq3xfg9lRoIjXsLv2',
#   'spotify:track:1WSA2pq3xfg9lRoIjXsLv2',
#   'https://api.spotify.com/v1/tracks/1WSA2pq3xfg9lRoIjXsLv2',
#   'https://api.spotify.com/v1/audio-analysis/1WSA2pq3xfg9lRoIjXsLv2',
#   116657,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'Fo Real',
#   '2013-05-30',
#   0.496,
#   0.645,
#   7,
#   -6.369,
#   1,
#   0.196,
#   0.282,
#   0,
#   0.135,
#   0.764,
#   144.707,
#   'audio_features',
#   '2SIsCEBQC4DwYEJC2zbZPn',
#   'spotify:track:2SIsCEBQC4DwYEJC2zbZPn',
#   'https://api.spotify.com/v1/tracks/2SIsCEBQC4DwYEJC2zbZPn',
#   'https://api.spotify.com/v1/audio-analysis/2SIsCEBQC4DwYEJC2zbZPn',
#   245773,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'U.O.E.N.O - Remix',
#   '2013-05-30',
#   0.444,
#   0.747,
#   6,
#   -4.797,
#   1,
#   0.25,
#   0.304,
#   0,
#   0.54,
#   0.721,
#   126.064,
#   'audio_features',
#   '1IqonRMPLudRgJb1TaJks9',
#   'spotify:track:1IqonRMPLudRgJb1TaJks9',
#   'https://api.spotify.com/v1/tracks/1IqonRMPLudRgJb1TaJks9',
#   'https://api.spotify.com/v1/audio-analysis/1IqonRMPLudRgJb1TaJks9',
#   262876,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'No Love',
#   '2013-05-30',
#   0.59,
#   0.727,
#   8,
#   -6.603,
#   0,
#   0.124,
#   0.154,
#   0,
#   0.244,
#   0.711,
#   133.16,
#   'audio_features',
#   '3cHGHht3C5g7zVpV4z0kwg',
#   'spotify:track:3cHGHht3C5g7zVpV4z0kwg',
#   'https://api.spotify.com/v1/tracks/3cHGHht3C5g7zVpV4z0kwg',
#   'https://api.spotify.com/v1/audio-analysis/3cHGHht3C5g7zVpV4z0kwg',
#   222852,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'Mark McGwire',
#   '2013-05-30',
#   0.501,
#   0.728,
#   2,
#   -5.158,
#   1,
#   0.0333,
#   0.0975,
#   0,
#   0.158,
#   0.191,
#   143.176,
#   'audio_features',
#   '1KfQRrot5NXLPkXp1QedUM',
#   'spotify:track:1KfQRrot5NXLPkXp1QedUM',
#   'https://api.spotify.com/v1/tracks/1KfQRrot5NXLPkXp1QedUM',
#   'https://api.spotify.com/v1/audio-analysis/1KfQRrot5NXLPkXp1QedUM',
#   190240,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'I Remember - Remix',
#   '2013-05-30',
#   0.556,
#   0.596,
#   1,
#   -5.732,
#   1,
#   0.0776,
#   0.322,
#   0,
#   0.127,
#   0.0763,
#   138.154,
#   'audio_features',
#   '14RWlavbRF1OxZihxvp4G3',
#   'spotify:track:14RWlavbRF1OxZihxvp4G3',
#   'https://api.spotify.com/v1/tracks/14RWlavbRF1OxZihxvp4G3',
#   'https://api.spotify.com/v1/audio-analysis/14RWlavbRF1OxZihxvp4G3',
#   278404,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'Jugg Season',
#   '2013-05-30',
#   0.603,
#   0.721,
#   4,
#   -7.461,
#   0,
#   0.196,
#   0.108,
#   0,
#   0.654,
#   0.372,
#   149.984,
#   'audio_features',
#   '4ZYlYMJK2nDHxwACnRhIqf',
#   'spotify:track:4ZYlYMJK2nDHxwACnRhIqf',
#   'https://api.spotify.com/v1/tracks/4ZYlYMJK2nDHxwACnRhIqf',
#   'https://api.spotify.com/v1/audio-analysis/4ZYlYMJK2nDHxwACnRhIqf',
#   172121,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'Usual',
#   '2013-05-30',
#   0.753,
#   0.631,
#   9,
#   -6.873,
#   1,
#   0.118,
#   0.178,
#   0,
#   0.268,
#   0.258,
#   128.475,
#   'audio_features',
#   '4l2nG5CmIZX3RzCFLlAgnd',
#   'spotify:track:4l2nG5CmIZX3RzCFLlAgnd',
#   'https://api.spotify.com/v1/tracks/4l2nG5CmIZX3RzCFLlAgnd',
#   'https://api.spotify.com/v1/audio-analysis/4l2nG5CmIZX3RzCFLlAgnd',
#   225361,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'Sorry - Remix',
#   '2013-05-30',
#   0.536,
#   0.884,
#   5,
#   -5.076,
#   0,
#   0.18,
#   0.0305,
#   0,
#   0.0816,
#   0.636,
#   126.794,
#   'audio_features',
#   '16DaDcfzp2fe9m1lby7DlO',
#   'spotify:track:16DaDcfzp2fe9m1lby7DlO',
#   'https://api.spotify.com/v1/tracks/16DaDcfzp2fe9m1lby7DlO',
#   'https://api.spotify.com/v1/audio-analysis/16DaDcfzp2fe9m1lby7DlO',
#   217193,
#   4],
#  ['Future',
#   'Notice Me',
#   'spotify:album:4anheXx4ephOE9hk1P1eCS',
#   'Yayo',
#   '2013-05-30',
#   0.637,
#   0.683,
#   2,
#   -4.668,
#   1,
#   0.0414,
#   0.262,
#   0,
#   0.0626,
#   0.627,
#   129.999,
#   'audio_features',
#   '6YZn1HT5wC67I2PgUoU0cU',
#   'spotify:track:6YZn1HT5wC67I2PgUoU0cU',
#   'https://api.spotify.com/v1/tracks/6YZn1HT5wC67I2PgUoU0cU',
#   'https://api.spotify.com/v1/audio-analysis/6YZn1HT5wC67I2PgUoU0cU',
#   192444,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Blow 2.0',
#   '2013-03-04',
#   0.807,
#   0.711,
#   10,
#   -5.139,
#   0,
#   0.0398,
#   0.122,
#   0,
#   0.305,
#   0.434,
#   136.098,
#   'audio_features',
#   '1kcDEgIVjkkjt1oVTsDg1B',
#   'spotify:track:1kcDEgIVjkkjt1oVTsDg1B',
#   'https://api.spotify.com/v1/tracks/1kcDEgIVjkkjt1oVTsDg1B',
#   'https://api.spotify.com/v1/audio-analysis/1kcDEgIVjkkjt1oVTsDg1B',
#   263001,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Yayo',
#   '2013-03-04',
#   0.65,
#   0.682,
#   2,
#   -4.745,
#   1,
#   0.0392,
#   0.261,
#   0,
#   0.0638,
#   0.619,
#   130.012,
#   'audio_features',
#   '7ljD1RFAdZFfC4ws5wS2ih',
#   'spotify:track:7ljD1RFAdZFfC4ws5wS2ih',
#   'https://api.spotify.com/v1/tracks/7ljD1RFAdZFfC4ws5wS2ih',
#   'https://api.spotify.com/v1/audio-analysis/7ljD1RFAdZFfC4ws5wS2ih',
#   192444,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'First Class Flights',
#   '2013-03-04',
#   0.501,
#   0.804,
#   8,
#   -5.606,
#   1,
#   0.0499,
#   0.0115,
#   0,
#   0.0764,
#   0.226,
#   145.083,
#   'audio_features',
#   '3M4VhNVYAIEfhwzHgqSFje',
#   'spotify:track:3M4VhNVYAIEfhwzHgqSFje',
#   'https://api.spotify.com/v1/tracks/3M4VhNVYAIEfhwzHgqSFje',
#   'https://api.spotify.com/v1/audio-analysis/3M4VhNVYAIEfhwzHgqSFje',
#   214570,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Jealous',
#   '2013-03-04',
#   0.579,
#   0.557,
#   6,
#   -8.443,
#   0,
#   0.0694,
#   0.247,
#   0,
#   0.175,
#   0.229,
#   144.125,
#   'audio_features',
#   '3kg4k7ulzCp61MzZ20JNfR',
#   'spotify:track:3kg4k7ulzCp61MzZ20JNfR',
#   'https://api.spotify.com/v1/tracks/3kg4k7ulzCp61MzZ20JNfR',
#   'https://api.spotify.com/v1/audio-analysis/3kg4k7ulzCp61MzZ20JNfR',
#   229782,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'My',
#   '2013-03-04',
#   0.554,
#   0.684,
#   1,
#   -5.128,
#   1,
#   0.225,
#   0.0629,
#   0,
#   0.277,
#   0.295,
#   137.393,
#   'audio_features',
#   '4XX9yXkXQrD5oSbTHqtC1P',
#   'spotify:track:4XX9yXkXQrD5oSbTHqtC1P',
#   'https://api.spotify.com/v1/tracks/4XX9yXkXQrD5oSbTHqtC1P',
#   'https://api.spotify.com/v1/audio-analysis/4XX9yXkXQrD5oSbTHqtC1P',
#   184118,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'I Remember - Remix',
#   '2013-03-04',
#   0.605,
#   0.649,
#   1,
#   -7.782,
#   1,
#   0.334,
#   0.238,
#   0,
#   0.351,
#   0.244,
#   146.04,
#   'audio_features',
#   '3l5SQcbUitTjnO1CtTBOh1',
#   'spotify:track:3l5SQcbUitTjnO1CtTBOh1',
#   'https://api.spotify.com/v1/tracks/3l5SQcbUitTjnO1CtTBOh1',
#   'https://api.spotify.com/v1/audio-analysis/3l5SQcbUitTjnO1CtTBOh1',
#   282448,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Dolla Signs',
#   '2013-03-04',
#   0.765,
#   0.509,
#   10,
#   -8.119,
#   1,
#   0.108,
#   0.0791,
#   0,
#   0.0828,
#   0.564,
#   126.087,
#   'audio_features',
#   '3eQqO9JJjDnP07EmCmrXXP',
#   'spotify:track:3eQqO9JJjDnP07EmCmrXXP',
#   'https://api.spotify.com/v1/tracks/3eQqO9JJjDnP07EmCmrXXP',
#   'https://api.spotify.com/v1/audio-analysis/3eQqO9JJjDnP07EmCmrXXP',
#   235343,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Karate Chop',
#   '2013-03-04',
#   0.656,
#   0.661,
#   8,
#   -6.661,
#   0,
#   0.0347,
#   0.0189,
#   0,
#   0.117,
#   0.523,
#   135.01,
#   'audio_features',
#   '1u1pr7RcKuS0LpDxNxcAQC',
#   'spotify:track:1u1pr7RcKuS0LpDxNxcAQC',
#   'https://api.spotify.com/v1/tracks/1u1pr7RcKuS0LpDxNxcAQC',
#   'https://api.spotify.com/v1/audio-analysis/1u1pr7RcKuS0LpDxNxcAQC',
#   262193,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Drug Money',
#   '2013-03-04',
#   0.633,
#   0.67,
#   1,
#   -7.307,
#   0,
#   0.0683,
#   0.0115,
#   0,
#   0.0799,
#   0.896,
#   130.037,
#   'audio_features',
#   '4rWwU4lA9xjBIixKW5bzCq',
#   'spotify:track:4rWwU4lA9xjBIixKW5bzCq',
#   'https://api.spotify.com/v1/tracks/4rWwU4lA9xjBIixKW5bzCq',
#   'https://api.spotify.com/v1/audio-analysis/4rWwU4lA9xjBIixKW5bzCq',
#   203154,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Mind Blown',
#   '2013-03-04',
#   0.682,
#   0.904,
#   11,
#   -2.065,
#   1,
#   0.13,
#   0.0848,
#   0,
#   0.0631,
#   0.844,
#   139.938,
#   'audio_features',
#   '1LCE37pEMN7WORg8bnO4Er',
#   'spotify:track:1LCE37pEMN7WORg8bnO4Er',
#   'https://api.spotify.com/v1/tracks/1LCE37pEMN7WORg8bnO4Er',
#   'https://api.spotify.com/v1/audio-analysis/1LCE37pEMN7WORg8bnO4Er',
#   257141,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Big Bank Roll',
#   '2013-03-04',
#   0.526,
#   0.85,
#   9,
#   -3.779,
#   0,
#   0.14,
#   0.00166,
#   0,
#   0.104,
#   0.56,
#   145.082,
#   'audio_features',
#   '7rJGZvVCmdSWkC72dDf6j8',
#   'spotify:track:7rJGZvVCmdSWkC72dDf6j8',
#   'https://api.spotify.com/v1/tracks/7rJGZvVCmdSWkC72dDf6j8',
#   'https://api.spotify.com/v1/audio-analysis/7rJGZvVCmdSWkC72dDf6j8',
#   248197,
#   4],
#  ['Future',
#   'First Class Flights',
#   'spotify:album:76T6VyS7a1I1EwnjUujaA9',
#   'Pain',
#   '2013-03-04',
#   0.428,
#   0.686,
#   10,
#   -9.067,
#   0,
#   0.097,
#   0.433,
#   3.57e-05,
#   0.296,
#   0.429,
#   90.694,
#   'audio_features',
#   '4XxQnILe17Y6yNUXaCzUFZ',
#   'spotify:track:4XxQnILe17Y6yNUXaCzUFZ',
#   'https://api.spotify.com/v1/tracks/4XxQnILe17Y6yNUXaCzUFZ',
#   'https://api.spotify.com/v1/audio-analysis/4XxQnILe17Y6yNUXaCzUFZ',
#   249841,
#   4],
#  ['Future',
#   'Pluto 3D',
#   'spotify:album:1MJ0UQh7nta4JGuFYW4gCg',
#   'The Future Is Now',
#   '2012-11-27',
#   0.51,
#   0.48,
#   2,
#   -12.667,
#   0,
#   0.342,
#   0.193,
#   0,
#   0.603,
#   0.709,
#   122.07,
#   'audio_features',
#   '70kWKRcoxx4UGJrC9f9kov',
#   'spotify:track:70kWKRcoxx4UGJrC9f9kov',
#   'https://api.spotify.com/v1/tracks/70kWKRcoxx4UGJrC9f9kov',
#   'https://api.spotify.com/v1/audio-analysis/70kWKRcoxx4UGJrC9f9kov',
#   63347,
#   5],
#  ['Future',
#   'Pluto 3D',
#   'spotify:album:1MJ0UQh7nta4JGuFYW4gCg',
#   'You Deserve It',
#   '2012-11-27',
#   0.713,
#   0.848,
#   8,
#   -6.038,
#   1,
#   0.131,
#   0.018,
#   0,
#   0.26,
#   0.735,
#   131.047,
#   'audio_features',
#   '3uJPwQDK7FmVba9HUlEO1Z',
#   'spotify:track:3uJPwQDK7FmVba9HUlEO1Z',
#   'https://api.spotify.com/v1/tracks/3uJPwQDK7FmVba9HUlEO1Z',
#   'https://api.spotify.com/v1/audio-analysis/3uJPwQDK7FmVba9HUlEO1Z',
#   214293,
#   4],
#  ['Future',
#   'Pluto 3D',
#   'spotify:album:1MJ0UQh7nta4JGuFYW4gCg',
#   'First Class Flights',
#   '2012-11-27',
#   0.581,
#   0.746,
#   8,
#   -5.201,
#   1,
#   0.0616,
#   0.0183,
#   0,
#   0.0955,
#   0.147,
#   145.01,
#   'audio_features',
#   '7zT2JYK8S20SnR9DiJfh5g',
#   'spotify:track:7zT2JYK8S20SnR9DiJfh5g',
#   'https://api.spotify.com/v1/tracks/7zT2JYK8S20SnR9DiJfh5g',
#   'https://api.spotify.com/v1/audio-analysis/7zT2JYK8S20SnR9DiJfh5g',
#   214760,
#   4],
#  ['Future',
#   'Pluto 3D',
#   'spotify:album:1MJ0UQh7nta4JGuFYW4gCg',
#   'Jealous',
#   '2012-11-27',
#   0.574,
#   0.531,
#   7,
#   -7.932,
#   0,
#   0.0884,
#   0.287,
#   0,
#   0.276,
#   0.146,
#   150.173,
#   'audio_features',
#   '7sNatosfFgOx1HUSAH1LAW',
#   'spotify:track:7sNatosfFgOx1HUSAH1LAW',
#   'https://api.spotify.com/v1/tracks/7sNatosfFgOx1HUSAH1LAW',
#   'https://api.spotify.com/v1/audio-analysis/7sNatosfFgOx1HUSAH1LAW',
#   221280,
#   4],
#  ['Future',
#   'Pluto 3D',
#   'spotify:album:1MJ0UQh7nta4JGuFYW4gCg',
#   'Turn On The Lights',
#   '2012-11-27',
#   0.596,
#   0.574,
#   6,
#   -9.373,
#   0,
#   0.212,
#   0.0409,
#   0,
#   0.147,
#   0.439,
#   131.075,
#   'audio_features',
#   '4U8hMes3PqpsLJBeMXD71p',
#   'spotify:track:4U8hMes3PqpsLJBeMXD71p',
#   'https://api.spotify.com/v1/tracks/4U8hMes3PqpsLJBeMXD71p',
#   'https://api.spotify.com/v1/audio-analysis/4U8hMes3PqpsLJBeMXD71p',
#   248360,
#   4],
#  ['Future',
#   'Pluto 3D',
#   'spotify:album:1MJ0UQh7nta4JGuFYW4gCg',
#   'Straight Up',
#   '2012-11-27',
#   0.557,
#   0.826,
#   11,
#   -4.126,
#   1,
#   0.187,
#   0.00127,
#   0,
#   0.648,
#   0.711,
#   147.258,
#   'audio_features',
#   '0l1DHb1XtJROCYpJYfM3rQ',
#   'spotify:track:0l1DHb1XtJROCYpJYfM3rQ',
#   'https://api.spotify.com/v1/tracks/0l1DHb1XtJROCYpJYfM3rQ',
#   'https://api.spotify.com/v1/audio-analysis/0l1DHb1XtJROCYpJYfM3rQ',
#   177440,
#   4],
#  ...]

# %%
len(tracks)
# Out:
# 5105

# %%
audio_ft = list(sp.audio_features('7tr2za8SQg2CI8EDgrdtNl')[0].keys())

# %%
df_columns = ['artist','album_name','album_uri','track','release_date'] + audio_ft

df_columns
# Out:
# ['artist',
#  'album_name',
#  'album_uri',
#  'track',
#  'release_date',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature']

# %%
import pandas as pd

df = pd.DataFrame(tracks, columns=df_columns)

# %%
df
# Out:
#            artist                             album_name  \
# 0     Roddy Ricch  Please Excuse Me For Being Antisocial
# 1     Roddy Ricch  Please Excuse Me For Being Antisocial
# 2     Roddy Ricch  Please Excuse Me For Being Antisocial
# 3     Roddy Ricch  Please Excuse Me For Being Antisocial
# 4     Roddy Ricch  Please Excuse Me For Being Antisocial
# ...           ...                                    ...
# 5100      Mustard                             10 Summers
# 5101      Mustard                             10 Summers
# 5102      Mustard                             10 Summers
# 5103      Mustard                             10 Summers
# 5104      Mustard                             10 Summers
#
#                                  album_uri                        track  \
# 0     spotify:album:52u4anZbHd6UInnmHRFzba                        Intro
# 1     spotify:album:52u4anZbHd6UInnmHRFzba                      The Box
# 2     spotify:album:52u4anZbHd6UInnmHRFzba   Start Wit Me (feat. Gunna)
# 3     spotify:album:52u4anZbHd6UInnmHRFzba                 Perfect Time
# 4     spotify:album:52u4anZbHd6UInnmHRFzba  Moonwalkin (feat. Lil Durk)
# ...                                    ...                          ...
# 5100  spotify:album:5RnrEPrcCnCbicoDYUaqgA                Can’t Tell Me
# 5101  spotify:album:5RnrEPrcCnCbicoDYUaqgA            Tinashe Checks In
# 5102  spotify:album:5RnrEPrcCnCbicoDYUaqgA                     4 Digits
# 5103  spotify:album:5RnrEPrcCnCbicoDYUaqgA      Ty Dolla $ign Checks In
# 5104  spotify:album:5RnrEPrcCnCbicoDYUaqgA                         Deep
#
#      release_date  danceability  energy  key  loudness  mode  ...  liveness  \
# 0      2019-12-06         0.738   0.657    3    -8.737     0  ...    0.1630
# 1      2019-12-06         0.896   0.586   10    -6.687     0  ...    0.7900
# 2      2019-12-06         0.886   0.479    4    -8.054     0  ...    0.1350
# 3      2019-12-06         0.577   0.734    8    -8.484     0  ...    0.1200
# 4      2019-12-06         0.779   0.580    1    -7.594     0  ...    0.1500
# ...           ...           ...     ...  ...       ...   ...  ...       ...
# 5100   2014-08-11         0.796   0.566    0    -8.755     0  ...    0.1790
# 5101   2014-08-11         0.445   0.459   11   -13.081     0  ...    0.4630
# 5102   2014-08-11         0.647   0.345   10   -10.994     1  ...    0.0963
# 5103   2014-08-11         0.567   0.569    5   -13.167     1  ...    0.5350
# 5104   2014-08-11         0.685   0.303    0   -12.469     0  ...    0.1320
#
#       valence    tempo            type                      id  \
# 0       0.716  159.010  audio_features  7AOtINPzQ4N4JVXk7ygZZz
# 1       0.642  116.971  audio_features  0nbXyq5TXYPCO7pr3N8S4I
# 2       0.408  130.029  audio_features  7A20WnLkjtZU2d7hIB6Ziu
# 3       0.254   94.122  audio_features  6kiIVIbmwEw6JvIZc7UG0E
# 4       0.299  160.243  audio_features  33NoCir8q4WA4HNmyrD3fu
# ...       ...      ...             ...                     ...
# 5100    0.758   95.489  audio_features  5UHwKUzLGsve19xOrmPhLT
# 5101    0.620  185.477  audio_features  5okemX1yAFd7ScrQ4EJAOL
# 5102    0.259   95.561  audio_features  0WtHRqsj9cIjU0vNcX02W6
# 5103    0.908  130.868  audio_features  7bkQnIgUZ2q1MoGnCem1X0
# 5104    0.149   97.973  audio_features  4nks9GHKZ4Er3GnCqVNsRN
#
#                                        uri  \
# 0     spotify:track:7AOtINPzQ4N4JVXk7ygZZz
# 1     spotify:track:0nbXyq5TXYPCO7pr3N8S4I
# 2     spotify:track:7A20WnLkjtZU2d7hIB6Ziu
# 3     spotify:track:6kiIVIbmwEw6JvIZc7UG0E
# 4     spotify:track:33NoCir8q4WA4HNmyrD3fu
# ...                                    ...
# 5100  spotify:track:5UHwKUzLGsve19xOrmPhLT
# 5101  spotify:track:5okemX1yAFd7ScrQ4EJAOL
# 5102  spotify:track:0WtHRqsj9cIjU0vNcX02W6
# 5103  spotify:track:7bkQnIgUZ2q1MoGnCem1X0
# 5104  spotify:track:4nks9GHKZ4Er3GnCqVNsRN
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7AOtINPzQ4N4...
# 1     https://api.spotify.com/v1/tracks/0nbXyq5TXYPC...
# 2     https://api.spotify.com/v1/tracks/7A20WnLkjtZU...
# 3     https://api.spotify.com/v1/tracks/6kiIVIbmwEw6...
# 4     https://api.spotify.com/v1/tracks/33NoCir8q4WA...
# ...                                                 ...
# 5100  https://api.spotify.com/v1/tracks/5UHwKUzLGsve...
# 5101  https://api.spotify.com/v1/tracks/5okemX1yAFd7...
# 5102  https://api.spotify.com/v1/tracks/0WtHRqsj9cIj...
# 5103  https://api.spotify.com/v1/tracks/7bkQnIgUZ2q1...
# 5104  https://api.spotify.com/v1/tracks/4nks9GHKZ4Er...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7AOt...      135849
# 1     https://api.spotify.com/v1/audio-analysis/0nbX...      196653
# 2     https://api.spotify.com/v1/audio-analysis/7A20...      158692
# 3     https://api.spotify.com/v1/audio-analysis/6kiI...      142710
# 4     https://api.spotify.com/v1/audio-analysis/33No...      167851
# ...                                                 ...         ...
# 5100  https://api.spotify.com/v1/audio-analysis/5UHw...      191147
# 5101  https://api.spotify.com/v1/audio-analysis/5oke...      119160
# 5102  https://api.spotify.com/v1/audio-analysis/0WtH...      191413
# 5103  https://api.spotify.com/v1/audio-analysis/7bkQ...       68733
# 5104  https://api.spotify.com/v1/audio-analysis/4nks...      217173
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ...             ...
# 5100              4
# 5101              4
# 5102              4
# 5103              3
# 5104              4
#
# [5105 rows x 23 columns]

# %%
df['artist'].value_counts()
# Out:
# Maroon 5               761
# Future                 515
# Eminem                 480
# Ed Sheeran             480
# Justin Bieber          384
# The Black Eyed Peas    229
# Dua Lipa               208
# Selena Gomez           206
# The Weeknd             178
# Jonas Brothers         163
# Nicky Jam              161
# Post Malone            134
# Shawn Mendes           127
# J Balvin               117
# Roddy Ricch             90
# BROCKHAMPTON            88
# DaBaby                  80
# Halsey                  75
# Khalid                  62
# blackbear               62
# Doja Cat                57
# Lewis Capaldi           54
# Mustard                 46
# YNW Melly               45
# Joji                    44
# Billie Eilish           42
# Dalex                   37
# KAROL G                 29
# SAINt JHN               27
# Lil Mosey               26
# Camila Cabello          25
# Bad Bunny               23
# Harry Styles            22
# Anuel AA                12
# Ali Gatie                9
# Rauw Alejandro           7
# Name: artist, dtype: int64

# %%
df_artist = df.groupby('artist').mean()

# %%
df_artist
# Out:
#                      danceability    energy       key   loudness      mode  \
# artist
# Ali Gatie                0.618778  0.507889  7.555556  -7.497333  0.666667
# Anuel AA                 0.738750  0.728250  5.416667  -4.461500  0.833333
# BROCKHAMPTON             0.620477  0.567523  5.136364  -9.186011  0.670455
# Bad Bunny                0.724870  0.638565  4.521739  -6.389739  0.478261
# Billie Eilish            0.583786  0.281721  5.000000 -15.085071  0.714286
# Camila Cabello           0.619320  0.536280  4.960000  -6.122320  0.560000
# DaBaby                   0.789137  0.677550  4.912500  -5.688563  0.550000
# Dalex                    0.638892  0.677514  4.594595  -6.110919  0.486486
# Doja Cat                 0.721684  0.640158  4.561404  -5.728298  0.701754
# Dua Lipa                 0.644990  0.670913  5.826923  -5.411942  0.442308
# Ed Sheeran               0.701052  0.734983  5.602083  -5.837465  0.558333
# Eminem                   0.701052  0.734983  5.602083  -5.837465  0.558333
# Future                   0.722796  0.573123  5.135922  -7.883322  0.561165
# Halsey                   0.572040  0.626147  5.000000  -6.261613  0.360000
# Harry Styles             0.539455  0.586227  4.590909  -6.446955  0.727273
# J Balvin                 0.729424  0.723282  5.786325  -5.680085  0.418803
# Joji                     0.571227  0.458182  4.386364 -10.097432  0.750000
# Jonas Brothers           0.519503  0.810190  5.012270  -4.505779  0.852761
# Justin Bieber            0.614406  0.655418  4.885417  -6.245865  0.588542
# KAROL G                  0.747138  0.698793  6.034483  -5.284759  0.482759
# Khalid                   0.641613  0.488355  4.612903  -8.874161  0.516129
# Lewis Capaldi            0.586889  0.445222  5.925926  -6.629111  0.962963
# Lil Mosey                0.715385  0.600500  5.538462  -7.593654  0.653846
# Maroon 5                 0.641537  0.716104  5.265440  -5.920016  0.561104
# Mustard                  0.720978  0.546587  4.500000  -7.939652  0.586957
# Nicky Jam                0.746720  0.725727  5.869565  -5.943422  0.559006
# Post Malone              0.617612  0.619612  4.477612  -5.840463  0.597015
# Rauw Alejandro           0.775429  0.609286  6.142857  -5.835714  0.428571
# Roddy Ricch              0.779778  0.546156  5.333333  -8.466578  0.488889
# SAINt JHN                0.764407  0.602222  3.851852  -6.402852  0.555556
# Selena Gomez             0.643893  0.743563  5.611650  -5.194515  0.495146
# Shawn Mendes             0.575323  0.552638  6.275591  -7.008142  0.685039
# The Black Eyed Peas      0.776288  0.673336  5.716157  -6.500153  0.441048
# The Weeknd               0.573618  0.609522  5.247191  -7.571556  0.230337
# YNW Melly                0.721156  0.553578  5.133333  -8.174867  0.577778
# blackbear                0.699855  0.530468  5.258065  -7.805613  0.483871
#
#                      speechiness  acousticness  instrumentalness  liveness  \
# artist
# Ali Gatie               0.036800      0.485556      7.044444e-06  0.163600
# Anuel AA                0.115550      0.410583      1.101467e-03  0.146683
# BROCKHAMPTON            0.177314      0.372821      3.264731e-02  0.257175
# Bad Bunny               0.125652      0.213026      3.192174e-04  0.166952
# Billie Eilish           0.193086      0.656857      1.206927e-01  0.239307
# Camila Cabello          0.085424      0.329892      1.693564e-04  0.145332
# DaBaby                  0.228078      0.090121      1.383825e-05  0.186372
# Dalex                   0.192846      0.472203      2.836054e-05  0.299389
# Doja Cat                0.088316      0.159661      1.901324e-03  0.159854
# Dua Lipa                0.070889      0.097657      6.935192e-06  0.168674
# Ed Sheeran              0.305228      0.201312      1.506320e-02  0.316389
# Eminem                  0.305228      0.201312      1.506320e-02  0.316389
# Future                  0.220302      0.175965      2.282213e-02  0.214151
# Halsey                  0.061711      0.234530      9.331941e-03  0.174613
# Harry Styles            0.035232      0.279982      1.986473e-02  0.154836
# J Balvin                0.122668      0.208219      1.706329e-02  0.172926
# Joji                    0.075948      0.604136      3.498660e-01  0.170620
# Jonas Brothers          0.064992      0.069085      4.850081e-04  0.308577
# Justin Bieber           0.065054      0.226824      7.698221e-04  0.195309
# KAROL G                 0.101838      0.240823      7.526586e-05  0.157248
# Khalid                  0.095752      0.443577      1.098316e-01  0.159355
# Lewis Capaldi           0.043844      0.686741      7.370370e-08  0.127081
# Lil Mosey               0.069546      0.279623      9.767885e-05  0.146604
# Maroon 5                0.086896      0.137147      9.188681e-04  0.201312
# Mustard                 0.219996      0.174012      3.793891e-05  0.211152
# Nicky Jam               0.133012      0.211741      9.283683e-05  0.150687
# Post Malone             0.073096      0.306481      9.423138e-03  0.141563
# Rauw Alejandro          0.070100      0.312443      1.457143e-06  0.292214
# Roddy Ricch             0.242416      0.110605      1.110978e-05  0.181411
# SAINt JHN               0.084570      0.218489      1.185871e-02  0.158293
# Selena Gomez            0.091080      0.100845      5.348991e-04  0.192708
# Shawn Mendes            0.083095      0.350553      4.523150e-06  0.260710
# The Black Eyed Peas     0.165239      0.111602      8.134142e-03  0.249841
# The Weeknd              0.077430      0.275883      1.287730e-02  0.198827
# YNW Melly               0.197049      0.182116      2.345778e-06  0.184593
# blackbear               0.129189      0.220333      2.853790e-05  0.175027
#
#                       valence       tempo    duration_ms  time_signature
# artist
# Ali Gatie            0.343111  125.908667  173448.000000        3.666667
# Anuel AA             0.601083  139.951333  216206.833333        4.000000
# BROCKHAMPTON         0.469416  113.283920  188858.511364        3.920455
# Bad Bunny            0.441087  129.237261  221873.739130        4.000000
# Billie Eilish        0.288007  105.494286  183947.642857        3.571429
# Camila Cabello       0.420684  112.847280  201105.520000        3.960000
# DaBaby               0.524000  131.556588  155104.462500        3.962500
# Dalex                0.616027  135.314243  235816.081081        4.000000
# Doja Cat             0.398649  126.991421  209294.017544        4.017544
# Dua Lipa             0.447510  108.685798  214407.711538        4.038462
# Ed Sheeran           0.544493  111.498044  240201.727083        3.868750
# Eminem               0.544493  111.498044  240201.727083        3.868750
# Future               0.372776  130.013365  209120.871845        3.984466
# Halsey               0.369885  114.296800  192999.760000        3.920000
# Harry Styles         0.408877  114.690636  237592.772727        4.000000
# J Balvin             0.715841  132.459709  215498.162393        4.000000
# Joji                 0.280632  119.035318  195989.295455        3.795455
# Jonas Brothers       0.547920  126.493442  200060.687117        3.975460
# Justin Bieber        0.528143  116.225469  219359.291667        3.953125
# KAROL G              0.600793  122.639586  194043.724138        4.000000
# Khalid               0.385908  106.497710  207055.419355        3.951613
# Lewis Capaldi        0.343889  111.122185  212763.370370        3.962963
# Lil Mosey            0.534885  127.586615  152599.807692        4.000000
# Maroon 5             0.578441  117.831300  213688.315375        3.950066
# Mustard              0.432426  105.628326  201953.673913        3.891304
# Nicky Jam            0.688727  118.145478  187179.788820        4.012422
# Post Malone          0.347000  121.890940  209971.164179        4.014925
# Rauw Alejandro       0.380429  123.688143  248048.857143        4.000000
# Roddy Ricch          0.355631  130.301267  177773.555556        3.977778
# SAINt JHN            0.391885  121.044296  196996.333333        4.000000
# Selena Gomez         0.482608  117.073951  214565.883495        3.990291
# Shawn Mendes         0.469843  119.080165  217700.889764        3.881890
# The Black Eyed Peas  0.594096  110.026533  262453.951965        3.995633
# The Weeknd           0.321516  122.971854  291269.848315        3.949438
# YNW Melly            0.476956  133.742311  211149.977778        4.000000
# blackbear            0.495102  119.117581  191127.677419        3.983871

# %%
df_artist.drop(columns=['time_signature'],inplace=True)

# %%
df_artist
# Out:
#                      danceability    energy       key   loudness      mode  \
# artist
# Ali Gatie                0.618778  0.507889  7.555556  -7.497333  0.666667
# Anuel AA                 0.738750  0.728250  5.416667  -4.461500  0.833333
# BROCKHAMPTON             0.620477  0.567523  5.136364  -9.186011  0.670455
# Bad Bunny                0.724870  0.638565  4.521739  -6.389739  0.478261
# Billie Eilish            0.583786  0.281721  5.000000 -15.085071  0.714286
# Camila Cabello           0.619320  0.536280  4.960000  -6.122320  0.560000
# DaBaby                   0.789137  0.677550  4.912500  -5.688563  0.550000
# Dalex                    0.638892  0.677514  4.594595  -6.110919  0.486486
# Doja Cat                 0.721684  0.640158  4.561404  -5.728298  0.701754
# Dua Lipa                 0.644990  0.670913  5.826923  -5.411942  0.442308
# Ed Sheeran               0.701052  0.734983  5.602083  -5.837465  0.558333
# Eminem                   0.701052  0.734983  5.602083  -5.837465  0.558333
# Future                   0.722796  0.573123  5.135922  -7.883322  0.561165
# Halsey                   0.572040  0.626147  5.000000  -6.261613  0.360000
# Harry Styles             0.539455  0.586227  4.590909  -6.446955  0.727273
# J Balvin                 0.729424  0.723282  5.786325  -5.680085  0.418803
# Joji                     0.571227  0.458182  4.386364 -10.097432  0.750000
# Jonas Brothers           0.519503  0.810190  5.012270  -4.505779  0.852761
# Justin Bieber            0.614406  0.655418  4.885417  -6.245865  0.588542
# KAROL G                  0.747138  0.698793  6.034483  -5.284759  0.482759
# Khalid                   0.641613  0.488355  4.612903  -8.874161  0.516129
# Lewis Capaldi            0.586889  0.445222  5.925926  -6.629111  0.962963
# Lil Mosey                0.715385  0.600500  5.538462  -7.593654  0.653846
# Maroon 5                 0.641537  0.716104  5.265440  -5.920016  0.561104
# Mustard                  0.720978  0.546587  4.500000  -7.939652  0.586957
# Nicky Jam                0.746720  0.725727  5.869565  -5.943422  0.559006
# Post Malone              0.617612  0.619612  4.477612  -5.840463  0.597015
# Rauw Alejandro           0.775429  0.609286  6.142857  -5.835714  0.428571
# Roddy Ricch              0.779778  0.546156  5.333333  -8.466578  0.488889
# SAINt JHN                0.764407  0.602222  3.851852  -6.402852  0.555556
# Selena Gomez             0.643893  0.743563  5.611650  -5.194515  0.495146
# Shawn Mendes             0.575323  0.552638  6.275591  -7.008142  0.685039
# The Black Eyed Peas      0.776288  0.673336  5.716157  -6.500153  0.441048
# The Weeknd               0.573618  0.609522  5.247191  -7.571556  0.230337
# YNW Melly                0.721156  0.553578  5.133333  -8.174867  0.577778
# blackbear                0.699855  0.530468  5.258065  -7.805613  0.483871
#
#                      speechiness  acousticness  instrumentalness  liveness  \
# artist
# Ali Gatie               0.036800      0.485556      7.044444e-06  0.163600
# Anuel AA                0.115550      0.410583      1.101467e-03  0.146683
# BROCKHAMPTON            0.177314      0.372821      3.264731e-02  0.257175
# Bad Bunny               0.125652      0.213026      3.192174e-04  0.166952
# Billie Eilish           0.193086      0.656857      1.206927e-01  0.239307
# Camila Cabello          0.085424      0.329892      1.693564e-04  0.145332
# DaBaby                  0.228078      0.090121      1.383825e-05  0.186372
# Dalex                   0.192846      0.472203      2.836054e-05  0.299389
# Doja Cat                0.088316      0.159661      1.901324e-03  0.159854
# Dua Lipa                0.070889      0.097657      6.935192e-06  0.168674
# Ed Sheeran              0.305228      0.201312      1.506320e-02  0.316389
# Eminem                  0.305228      0.201312      1.506320e-02  0.316389
# Future                  0.220302      0.175965      2.282213e-02  0.214151
# Halsey                  0.061711      0.234530      9.331941e-03  0.174613
# Harry Styles            0.035232      0.279982      1.986473e-02  0.154836
# J Balvin                0.122668      0.208219      1.706329e-02  0.172926
# Joji                    0.075948      0.604136      3.498660e-01  0.170620
# Jonas Brothers          0.064992      0.069085      4.850081e-04  0.308577
# Justin Bieber           0.065054      0.226824      7.698221e-04  0.195309
# KAROL G                 0.101838      0.240823      7.526586e-05  0.157248
# Khalid                  0.095752      0.443577      1.098316e-01  0.159355
# Lewis Capaldi           0.043844      0.686741      7.370370e-08  0.127081
# Lil Mosey               0.069546      0.279623      9.767885e-05  0.146604
# Maroon 5                0.086896      0.137147      9.188681e-04  0.201312
# Mustard                 0.219996      0.174012      3.793891e-05  0.211152
# Nicky Jam               0.133012      0.211741      9.283683e-05  0.150687
# Post Malone             0.073096      0.306481      9.423138e-03  0.141563
# Rauw Alejandro          0.070100      0.312443      1.457143e-06  0.292214
# Roddy Ricch             0.242416      0.110605      1.110978e-05  0.181411
# SAINt JHN               0.084570      0.218489      1.185871e-02  0.158293
# Selena Gomez            0.091080      0.100845      5.348991e-04  0.192708
# Shawn Mendes            0.083095      0.350553      4.523150e-06  0.260710
# The Black Eyed Peas     0.165239      0.111602      8.134142e-03  0.249841
# The Weeknd              0.077430      0.275883      1.287730e-02  0.198827
# YNW Melly               0.197049      0.182116      2.345778e-06  0.184593
# blackbear               0.129189      0.220333      2.853790e-05  0.175027
#
#                       valence       tempo    duration_ms
# artist
# Ali Gatie            0.343111  125.908667  173448.000000
# Anuel AA             0.601083  139.951333  216206.833333
# BROCKHAMPTON         0.469416  113.283920  188858.511364
# Bad Bunny            0.441087  129.237261  221873.739130
# Billie Eilish        0.288007  105.494286  183947.642857
# Camila Cabello       0.420684  112.847280  201105.520000
# DaBaby               0.524000  131.556588  155104.462500
# Dalex                0.616027  135.314243  235816.081081
# Doja Cat             0.398649  126.991421  209294.017544
# Dua Lipa             0.447510  108.685798  214407.711538
# Ed Sheeran           0.544493  111.498044  240201.727083
# Eminem               0.544493  111.498044  240201.727083
# Future               0.372776  130.013365  209120.871845
# Halsey               0.369885  114.296800  192999.760000
# Harry Styles         0.408877  114.690636  237592.772727
# J Balvin             0.715841  132.459709  215498.162393
# Joji                 0.280632  119.035318  195989.295455
# Jonas Brothers       0.547920  126.493442  200060.687117
# Justin Bieber        0.528143  116.225469  219359.291667
# KAROL G              0.600793  122.639586  194043.724138
# Khalid               0.385908  106.497710  207055.419355
# Lewis Capaldi        0.343889  111.122185  212763.370370
# Lil Mosey            0.534885  127.586615  152599.807692
# Maroon 5             0.578441  117.831300  213688.315375
# Mustard              0.432426  105.628326  201953.673913
# Nicky Jam            0.688727  118.145478  187179.788820
# Post Malone          0.347000  121.890940  209971.164179
# Rauw Alejandro       0.380429  123.688143  248048.857143
# Roddy Ricch          0.355631  130.301267  177773.555556
# SAINt JHN            0.391885  121.044296  196996.333333
# Selena Gomez         0.482608  117.073951  214565.883495
# Shawn Mendes         0.469843  119.080165  217700.889764
# The Black Eyed Peas  0.594096  110.026533  262453.951965
# The Weeknd           0.321516  122.971854  291269.848315
# YNW Melly            0.476956  133.742311  211149.977778
# blackbear            0.495102  119.117581  191127.677419

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(df_artist)
y_kmeans = kmeans.predict(df_artist)

# %%
df_artist.to_csv('top50data')
