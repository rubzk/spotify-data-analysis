# %% [markdown]
# # Spotify Data Analysis

# %% [markdown]
# ### Auth

# %% [markdown]
# First, we need to save our credentials (client_id and client_secret) into a credentials.py in the same folder

# %%
import spotipy
import credentials
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3e93029ce54b> in <module>
# ----> 1 import spotipy
#       2 import credentials
#
# ModuleNotFoundError: No module named 'spotipy'

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=credentials.client_id,client_secret=credentials.client_secret)

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Gathering the data

# %% [markdown]
# Next, using the spotify API we need to gather the data about the artist we want to analyze

# %% [markdown]
# The following function returns all of the tracks of a list of artists

# %%
def get_artist_tracks(artists):
    tracks = []
    
    for artist in artists:
        
        # Get the artist URI (a unique ID)
        artist_uri = sp.search(artist)['tracks']['items'][0]['artists'][0]['uri']

        # Spotify has a lot of duplicate albums, but we'll cross-reference them with this list to avoid extra loops
        album_checker = []
        
        # The starting point of our loop of albums for those artists with more than 50
        n = 0
        
        # Note the album_type = 'album'. This discounts singles, compilations and collaborations
        while len(sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']) > 0:
            
            # Avoid overloading Spotify with requests by assigning the list of album dictionaries to a variable
            dict_list = sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']
            
            for i, album in list(enumerate(dict_list)):

                # Add the featured artists for the album in question to the checklist
                check_this_album = [j['name'] for j in dict_list[i]['artists']]
                # And the album name
                check_this_album.append(dict_list[i]['name'])
                # And its date
                check_this_album.append(dict_list[i]['release_date'])

                # Only continue looping if that album isn't in the checklist
                if check_this_album not in album_checker:
                    
                    # Add this album to the checker
                    album_checker.append(check_this_album)
                    # For every song on the album, get its descriptors and features in a list and add to the tracklist
                    tracks.extend([[artist, album['name'], album['uri'], song['name'],

                      album['release_date']] + list(sp.audio_features(song['uri'])[0].values()) 
                                   for song in sp.album_tracks(album['uri'])['items']])
            
            # Go through the next 50 albums (otherwise we'll get an infinite while loop)
            n += 50

    return tracks

# %% [markdown]
# So now we need to set our list of artists

# %% [markdown]
# We are going to use the Top Global Charts Playlist from spotify to extract the top 50 artists

# %%
top_50_global_chart = sp.playlist_tracks('37i9dQZEVXbMDoHDwVN2tF',market='AR')

# %%
list_top50 = list(top_50_global_chart['items'])

# %%
list_top50[0]['track']['artists'][0]['name']
# Out:
# 'The Weeknd'

# %%
top_artists = []
for artist in list_top50:
    print(artist['track']['artists'][0]['name'])
    top_artists.append(artist['track']['artists'][0]['name'])
# Out:
# The Weeknd
# Roddy Ricch
# Tones and I
# Dua Lipa
# Bad Bunny
# Justin Bieber
# Doja Cat
# Bad Bunny
# KAROL G
# Trevor Daniel
# Bad Bunny
# Arizona Zervas
# Bad Bunny
# Post Malone
# Lil Uzi Vert
# Lewis Capaldi
# Lil Uzi Vert
# Lil Uzi Vert
# SAINt JHN
# Bad Bunny
# Lil Mosey
# Surfaces
# Powfu
# Justin Bieber
# Future
# Maroon 5
# Bad Bunny
# Harry Styles
# Eminem
# Lady Gaga
# Billie Eilish
# Billie Eilish
# Lil Uzi Vert
# Bad Bunny
# Billie Eilish
# Dua Lipa
# Lewis Capaldi
# The Weeknd
# Lil Uzi Vert
# Halsey
# Shawn Mendes
# J Balvin
# Bad Bunny
# Dimelo Flow
# Black Eyed Peas
# BENEE
# Camila Cabello
# Lil Uzi Vert
# Ashe
# J Balvin

# %% [markdown]
# Now that we got our artist we are going to use the function prevously defined

# %%
## This line may take a while

# %%
tracks = get_artist_tracks(top_artists)

# %%
tracks
# Out:
# [['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Call Out My Name',
#   '2018-03-30',
#   0.461,
#   0.593,
#   1,
#   -4.954,
#   1,
#   0.0356,
#   0.17,
#   0,
#   0.307,
#   0.175,
#   134.17,
#   'audio_features',
#   '09mEdoA6zrmBPgTEN5qXmN',
#   'spotify:track:09mEdoA6zrmBPgTEN5qXmN',
#   'https://api.spotify.com/v1/tracks/09mEdoA6zrmBPgTEN5qXmN',
#   'https://api.spotify.com/v1/audio-analysis/09mEdoA6zrmBPgTEN5qXmN',
#   228373,
#   3],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Try Me',
#   '2018-03-30',
#   0.456,
#   0.679,
#   8,
#   -5.778,
#   0,
#   0.064,
#   0.596,
#   0.000573,
#   0.129,
#   0.107,
#   92.026,
#   'audio_features',
#   '4ppTAJUbNXELZcoUaL90wo',
#   'spotify:track:4ppTAJUbNXELZcoUaL90wo',
#   'https://api.spotify.com/v1/tracks/4ppTAJUbNXELZcoUaL90wo',
#   'https://api.spotify.com/v1/audio-analysis/4ppTAJUbNXELZcoUaL90wo',
#   221107,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Wasted Times',
#   '2018-03-30',
#   0.56,
#   0.678,
#   10,
#   -6.167,
#   0,
#   0.0581,
#   0.61,
#   1.42e-05,
#   0.111,
#   0.29,
#   122.585,
#   'audio_features',
#   '7DKS0rX27cCEPsK0R6tFWS',
#   'spotify:track:7DKS0rX27cCEPsK0R6tFWS',
#   'https://api.spotify.com/v1/tracks/7DKS0rX27cCEPsK0R6tFWS',
#   'https://api.spotify.com/v1/audio-analysis/7DKS0rX27cCEPsK0R6tFWS',
#   220293,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'I Was Never There',
#   '2018-03-30',
#   0.323,
#   0.737,
#   10,
#   -4.008,
#   1,
#   0.0338,
#   0.142,
#   0.000162,
#   0.163,
#   0.155,
#   113.26,
#   'audio_features',
#   '1cKHdTo9u0ZymJdPGSh6nq',
#   'spotify:track:1cKHdTo9u0ZymJdPGSh6nq',
#   'https://api.spotify.com/v1/tracks/1cKHdTo9u0ZymJdPGSh6nq',
#   'https://api.spotify.com/v1/audio-analysis/1cKHdTo9u0ZymJdPGSh6nq',
#   241067,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Hurt You',
#   '2018-03-30',
#   0.476,
#   0.718,
#   5,
#   -7.227,
#   0,
#   0.149,
#   0.263,
#   0.00261,
#   0.109,
#   0.361,
#   183.932,
#   'audio_features',
#   '6QdnKD1zwEgyOWtkrdzlOF',
#   'spotify:track:6QdnKD1zwEgyOWtkrdzlOF',
#   'https://api.spotify.com/v1/tracks/6QdnKD1zwEgyOWtkrdzlOF',
#   'https://api.spotify.com/v1/audio-analysis/6QdnKD1zwEgyOWtkrdzlOF',
#   230027,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Privilege',
#   '2018-03-30',
#   0.404,
#   0.564,
#   11,
#   -7.013,
#   0,
#   0.0344,
#   0.915,
#   0.00252,
#   0.134,
#   0.371,
#   93.631,
#   'audio_features',
#   '0Nwar8rweBUyfyuoyjjUvk',
#   'spotify:track:0Nwar8rweBUyfyuoyjjUvk',
#   'https://api.spotify.com/v1/tracks/0Nwar8rweBUyfyuoyjjUvk',
#   'https://api.spotify.com/v1/audio-analysis/0Nwar8rweBUyfyuoyjjUvk',
#   170573,
#   4],
#  ['The Weeknd',
#   'My Dear Melancholy,',
#   'spotify:album:4qZBW3f2Q8y0k1A84d4iAO',
#   'Call Out My Name - A Cappella',
#   '2018-03-30',
#   0.397,
#   0.339,
#   1,
#   -6.688,
#   1,
#   0.0361,
#   0.887,
#   0,
#   0.306,
#   0.459,
#   135.089,
#   'audio_features',
#   '5PTfZsGlsDDPH8i3PdQnXJ',
#   'spotify:track:5PTfZsGlsDDPH8i3PdQnXJ',
#   'https://api.spotify.com/v1/tracks/5PTfZsGlsDDPH8i3PdQnXJ',
#   'https://api.spotify.com/v1/audio-analysis/5PTfZsGlsDDPH8i3PdQnXJ',
#   224747,
#   3],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Starboy',
#   '2016-11-25',
#   0.678,
#   0.588,
#   7,
#   -7.015,
#   1,
#   0.276,
#   0.141,
#   6.35e-06,
#   0.137,
#   0.486,
#   186.005,
#   'audio_features',
#   '7MXVkk9YMctZqd1Srtv4MB',
#   'spotify:track:7MXVkk9YMctZqd1Srtv4MB',
#   'https://api.spotify.com/v1/tracks/7MXVkk9YMctZqd1Srtv4MB',
#   'https://api.spotify.com/v1/audio-analysis/7MXVkk9YMctZqd1Srtv4MB',
#   230453,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Party Monster',
#   '2016-11-25',
#   0.572,
#   0.631,
#   1,
#   -8.389,
#   1,
#   0.104,
#   0.188,
#   2.31e-05,
#   0.259,
#   0.219,
#   77.519,
#   'audio_features',
#   '4F7A0DXBrmUAkp32uenhZt',
#   'spotify:track:4F7A0DXBrmUAkp32uenhZt',
#   'https://api.spotify.com/v1/tracks/4F7A0DXBrmUAkp32uenhZt',
#   'https://api.spotify.com/v1/audio-analysis/4F7A0DXBrmUAkp32uenhZt',
#   249213,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'False Alarm',
#   '2016-11-25',
#   0.518,
#   0.676,
#   8,
#   -6.373,
#   0,
#   0.0744,
#   0.0324,
#   3.62e-05,
#   0.189,
#   0.197,
#   173.998,
#   'audio_features',
#   '4oeaIftdpT3JuZLcCkKmVE',
#   'spotify:track:4oeaIftdpT3JuZLcCkKmVE',
#   'https://api.spotify.com/v1/tracks/4oeaIftdpT3JuZLcCkKmVE',
#   'https://api.spotify.com/v1/audio-analysis/4oeaIftdpT3JuZLcCkKmVE',
#   220307,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Reminder',
#   '2016-11-25',
#   0.705,
#   0.505,
#   8,
#   -6.923,
#   1,
#   0.192,
#   0.142,
#   0,
#   0.164,
#   0.391,
#   160.043,
#   'audio_features',
#   '37F0uwRSrdzkBiuj0D5UHI',
#   'spotify:track:37F0uwRSrdzkBiuj0D5UHI',
#   'https://api.spotify.com/v1/tracks/37F0uwRSrdzkBiuj0D5UHI',
#   'https://api.spotify.com/v1/audio-analysis/37F0uwRSrdzkBiuj0D5UHI',
#   218880,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Rockin’',
#   '2016-11-25',
#   0.737,
#   0.885,
#   9,
#   -5.547,
#   0,
#   0.206,
#   0.0132,
#   0,
#   0.0821,
#   0.752,
#   112.877,
#   'audio_features',
#   '36YCdzT57us0LhDmCYtrNE',
#   'spotify:track:36YCdzT57us0LhDmCYtrNE',
#   'https://api.spotify.com/v1/tracks/36YCdzT57us0LhDmCYtrNE',
#   'https://api.spotify.com/v1/audio-analysis/36YCdzT57us0LhDmCYtrNE',
#   232880,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Secrets',
#   '2016-11-25',
#   0.665,
#   0.771,
#   0,
#   -5.779,
#   1,
#   0.0533,
#   0.0155,
#   9.6e-06,
#   0.46,
#   0.764,
#   109.945,
#   'audio_features',
#   '00NAQYOP4AmWR549nnYJZu',
#   'spotify:track:00NAQYOP4AmWR549nnYJZu',
#   'https://api.spotify.com/v1/tracks/00NAQYOP4AmWR549nnYJZu',
#   'https://api.spotify.com/v1/audio-analysis/00NAQYOP4AmWR549nnYJZu',
#   265600,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'True Colors',
#   '2016-11-25',
#   0.624,
#   0.424,
#   1,
#   -8.237,
#   1,
#   0.24,
#   0.284,
#   0,
#   0.173,
#   0.584,
#   76.669,
#   'audio_features',
#   '1oGdVdYjeQvojGKDddxLQQ',
#   'spotify:track:1oGdVdYjeQvojGKDddxLQQ',
#   'https://api.spotify.com/v1/tracks/1oGdVdYjeQvojGKDddxLQQ',
#   'https://api.spotify.com/v1/audio-analysis/1oGdVdYjeQvojGKDddxLQQ',
#   206013,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Stargirl Interlude',
#   '2016-11-25',
#   0.638,
#   0.47,
#   5,
#   -12.697,
#   0,
#   0.132,
#   0.344,
#   0.193,
#   0.105,
#   0.442,
#   179.818,
#   'audio_features',
#   '4EDijkJdHBZZ0GwJ12iTAj',
#   'spotify:track:4EDijkJdHBZZ0GwJ12iTAj',
#   'https://api.spotify.com/v1/tracks/4EDijkJdHBZZ0GwJ12iTAj',
#   'https://api.spotify.com/v1/audio-analysis/4EDijkJdHBZZ0GwJ12iTAj',
#   111640,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Sidewalks',
#   '2016-11-25',
#   0.542,
#   0.721,
#   1,
#   -5.136,
#   0,
#   0.0625,
#   0.147,
#   0,
#   0.348,
#   0.623,
#   149.831,
#   'audio_features',
#   '4h90qkbnW1Qq6pBhoPvwko',
#   'spotify:track:4h90qkbnW1Qq6pBhoPvwko',
#   'https://api.spotify.com/v1/tracks/4h90qkbnW1Qq6pBhoPvwko',
#   'https://api.spotify.com/v1/audio-analysis/4h90qkbnW1Qq6pBhoPvwko',
#   231360,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Six Feet Under',
#   '2016-11-25',
#   0.772,
#   0.504,
#   6,
#   -8.219,
#   0,
#   0.0761,
#   0.129,
#   0,
#   0.125,
#   0.244,
#   140.035,
#   'audio_features',
#   '4mU5iXHeLgbR94siF7p1sY',
#   'spotify:track:4mU5iXHeLgbR94siF7p1sY',
#   'https://api.spotify.com/v1/tracks/4mU5iXHeLgbR94siF7p1sY',
#   'https://api.spotify.com/v1/audio-analysis/4mU5iXHeLgbR94siF7p1sY',
#   237573,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Love To Lay',
#   '2016-11-25',
#   0.711,
#   0.807,
#   7,
#   -5.053,
#   0,
#   0.0608,
#   0.0519,
#   0,
#   0.214,
#   0.699,
#   116.971,
#   'audio_features',
#   '27BgDmciSjoxTG0almHTpZ',
#   'spotify:track:27BgDmciSjoxTG0almHTpZ',
#   'https://api.spotify.com/v1/tracks/27BgDmciSjoxTG0almHTpZ',
#   'https://api.spotify.com/v1/audio-analysis/27BgDmciSjoxTG0almHTpZ',
#   223293,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'A Lonely Night',
#   '2016-11-25',
#   0.853,
#   0.663,
#   7,
#   -6.955,
#   0,
#   0.0755,
#   0.0431,
#   8.65e-06,
#   0.0891,
#   0.864,
#   113.999,
#   'audio_features',
#   '0ifooM33X1iBxVYyOkSbXW',
#   'spotify:track:0ifooM33X1iBxVYyOkSbXW',
#   'https://api.spotify.com/v1/tracks/0ifooM33X1iBxVYyOkSbXW',
#   'https://api.spotify.com/v1/audio-analysis/0ifooM33X1iBxVYyOkSbXW',
#   220173,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Attention',
#   '2016-11-25',
#   0.671,
#   0.428,
#   4,
#   -7.054,
#   0,
#   0.124,
#   0.682,
#   0.0002,
#   0.121,
#   0.36,
#   148.041,
#   'audio_features',
#   '6pDVjCUA3B1vg9waKutAsv',
#   'spotify:track:6pDVjCUA3B1vg9waKutAsv',
#   'https://api.spotify.com/v1/tracks/6pDVjCUA3B1vg9waKutAsv',
#   'https://api.spotify.com/v1/audio-analysis/6pDVjCUA3B1vg9waKutAsv',
#   197653,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Ordinary Life',
#   '2016-11-25',
#   0.544,
#   0.586,
#   7,
#   -7.486,
#   0,
#   0.0794,
#   0.0276,
#   0,
#   0.0961,
#   0.361,
#   149.882,
#   'audio_features',
#   '15k2nBQJ0teDmPZHrOXL2N',
#   'spotify:track:15k2nBQJ0teDmPZHrOXL2N',
#   'https://api.spotify.com/v1/tracks/15k2nBQJ0teDmPZHrOXL2N',
#   'https://api.spotify.com/v1/audio-analysis/15k2nBQJ0teDmPZHrOXL2N',
#   221920,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Nothing Without You',
#   '2016-11-25',
#   0.599,
#   0.635,
#   1,
#   -8.101,
#   1,
#   0.0679,
#   0.064,
#   0,
#   0.0878,
#   0.194,
#   109.919,
#   'audio_features',
#   '57qiTKh8bVX0VtfUNTQqhw',
#   'spotify:track:57qiTKh8bVX0VtfUNTQqhw',
#   'https://api.spotify.com/v1/tracks/57qiTKh8bVX0VtfUNTQqhw',
#   'https://api.spotify.com/v1/audio-analysis/57qiTKh8bVX0VtfUNTQqhw',
#   198653,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'All I Know',
#   '2016-11-25',
#   0.469,
#   0.417,
#   8,
#   -10.614,
#   0,
#   0.0704,
#   0.418,
#   0.000189,
#   0.102,
#   0.175,
#   120.012,
#   'audio_features',
#   '0NWqNXBJTpXbkI5rPWNy3p',
#   'spotify:track:0NWqNXBJTpXbkI5rPWNy3p',
#   'https://api.spotify.com/v1/tracks/0NWqNXBJTpXbkI5rPWNy3p',
#   'https://api.spotify.com/v1/audio-analysis/0NWqNXBJTpXbkI5rPWNy3p',
#   321027,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'Die For You',
#   '2016-11-25',
#   0.586,
#   0.525,
#   1,
#   -7.163,
#   0,
#   0.0615,
#   0.111,
#   0,
#   0.134,
#   0.508,
#   133.629,
#   'audio_features',
#   '2Ch7LmS7r2Gy2kc64wv3Bz',
#   'spotify:track:2Ch7LmS7r2Gy2kc64wv3Bz',
#   'https://api.spotify.com/v1/tracks/2Ch7LmS7r2Gy2kc64wv3Bz',
#   'https://api.spotify.com/v1/audio-analysis/2Ch7LmS7r2Gy2kc64wv3Bz',
#   260253,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:2ODvWsOgouMbaA5xf0RkJe',
#   'I Feel It Coming',
#   '2016-11-25',
#   0.773,
#   0.819,
#   0,
#   -5.946,
#   0,
#   0.118,
#   0.426,
#   0,
#   0.0679,
#   0.585,
#   92.99,
#   'audio_features',
#   '3dhjNA0jGA8vHBQ1VdD6vV',
#   'spotify:track:3dhjNA0jGA8vHBQ1VdD6vV',
#   'https://api.spotify.com/v1/tracks/3dhjNA0jGA8vHBQ1VdD6vV',
#   'https://api.spotify.com/v1/audio-analysis/3dhjNA0jGA8vHBQ1VdD6vV',
#   269187,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Starboy',
#   '2016-11-24',
#   0.677,
#   0.592,
#   7,
#   -7.108,
#   1,
#   0.281,
#   0.134,
#   3.86e-06,
#   0.175,
#   0.528,
#   186.038,
#   'audio_features',
#   '7HtPBwBoCBDy1tpstag7HL',
#   'spotify:track:7HtPBwBoCBDy1tpstag7HL',
#   'https://api.spotify.com/v1/tracks/7HtPBwBoCBDy1tpstag7HL',
#   'https://api.spotify.com/v1/audio-analysis/7HtPBwBoCBDy1tpstag7HL',
#   230453,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Party Monster',
#   '2016-11-24',
#   0.588,
#   0.635,
#   1,
#   -8.417,
#   1,
#   0.0531,
#   0.191,
#   1.24e-05,
#   0.259,
#   0.208,
#   77.486,
#   'audio_features',
#   '2dNVHgOx99fv4oSVF9GN1Y',
#   'spotify:track:2dNVHgOx99fv4oSVF9GN1Y',
#   'https://api.spotify.com/v1/tracks/2dNVHgOx99fv4oSVF9GN1Y',
#   'https://api.spotify.com/v1/audio-analysis/2dNVHgOx99fv4oSVF9GN1Y',
#   249213,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'False Alarm',
#   '2016-11-24',
#   0.518,
#   0.676,
#   8,
#   -6.373,
#   0,
#   0.0744,
#   0.0324,
#   3.62e-05,
#   0.189,
#   0.197,
#   173.998,
#   'audio_features',
#   '32lgtADX2cB9I4KFs1Y1py',
#   'spotify:track:32lgtADX2cB9I4KFs1Y1py',
#   'https://api.spotify.com/v1/tracks/32lgtADX2cB9I4KFs1Y1py',
#   'https://api.spotify.com/v1/audio-analysis/32lgtADX2cB9I4KFs1Y1py',
#   220307,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Reminder',
#   '2016-11-24',
#   0.744,
#   0.496,
#   8,
#   -6.931,
#   1,
#   0.0804,
#   0.16,
#   1.72e-06,
#   0.164,
#   0.446,
#   80.031,
#   'audio_features',
#   '31F83eeeh5Sz6g616t13DW',
#   'spotify:track:31F83eeeh5Sz6g616t13DW',
#   'https://api.spotify.com/v1/tracks/31F83eeeh5Sz6g616t13DW',
#   'https://api.spotify.com/v1/audio-analysis/31F83eeeh5Sz6g616t13DW',
#   218880,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Rockin’',
#   '2016-11-24',
#   0.736,
#   0.883,
#   9,
#   -5.595,
#   0,
#   0.214,
#   0.0117,
#   0,
#   0.0734,
#   0.797,
#   112.92,
#   'audio_features',
#   '02V0fopGouDF5GbDHftv4S',
#   'spotify:track:02V0fopGouDF5GbDHftv4S',
#   'https://api.spotify.com/v1/tracks/02V0fopGouDF5GbDHftv4S',
#   'https://api.spotify.com/v1/audio-analysis/02V0fopGouDF5GbDHftv4S',
#   232880,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Secrets',
#   '2016-11-24',
#   0.665,
#   0.771,
#   0,
#   -5.779,
#   1,
#   0.0533,
#   0.0155,
#   9.6e-06,
#   0.46,
#   0.764,
#   109.948,
#   'audio_features',
#   '3DX4Y0egvc0slLcLl31h2p',
#   'spotify:track:3DX4Y0egvc0slLcLl31h2p',
#   'https://api.spotify.com/v1/tracks/3DX4Y0egvc0slLcLl31h2p',
#   'https://api.spotify.com/v1/audio-analysis/3DX4Y0egvc0slLcLl31h2p',
#   265600,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'True Colors',
#   '2016-11-24',
#   0.616,
#   0.424,
#   1,
#   -8.237,
#   1,
#   0.251,
#   0.284,
#   0,
#   0.173,
#   0.582,
#   76.676,
#   'audio_features',
#   '6i759FCuKx713ZnYjtpQGU',
#   'spotify:track:6i759FCuKx713ZnYjtpQGU',
#   'https://api.spotify.com/v1/tracks/6i759FCuKx713ZnYjtpQGU',
#   'https://api.spotify.com/v1/audio-analysis/6i759FCuKx713ZnYjtpQGU',
#   206027,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Stargirl Interlude',
#   '2016-11-24',
#   0.715,
#   0.47,
#   5,
#   -12.638,
#   0,
#   0.0772,
#   0.353,
#   0.0923,
#   0.104,
#   0.426,
#   89.965,
#   'audio_features',
#   '5gDWsRxpJ2lZAffh5p7K0w',
#   'spotify:track:5gDWsRxpJ2lZAffh5p7K0w',
#   'https://api.spotify.com/v1/tracks/5gDWsRxpJ2lZAffh5p7K0w',
#   'https://api.spotify.com/v1/audio-analysis/5gDWsRxpJ2lZAffh5p7K0w',
#   111627,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Sidewalks',
#   '2016-11-24',
#   0.536,
#   0.721,
#   1,
#   -5.144,
#   0,
#   0.0649,
#   0.15,
#   0,
#   0.348,
#   0.612,
#   149.839,
#   'audio_features',
#   '2Eomvb6YHo8lhfleLufuca',
#   'spotify:track:2Eomvb6YHo8lhfleLufuca',
#   'https://api.spotify.com/v1/tracks/2Eomvb6YHo8lhfleLufuca',
#   'https://api.spotify.com/v1/audio-analysis/2Eomvb6YHo8lhfleLufuca',
#   231360,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Six Feet Under',
#   '2016-11-24',
#   0.776,
#   0.483,
#   6,
#   -8.262,
#   0,
#   0.0784,
#   0.121,
#   0,
#   0.118,
#   0.24,
#   140.005,
#   'audio_features',
#   '2QErvFddvI9I4QokOsQXdC',
#   'spotify:track:2QErvFddvI9I4QokOsQXdC',
#   'https://api.spotify.com/v1/tracks/2QErvFddvI9I4QokOsQXdC',
#   'https://api.spotify.com/v1/audio-analysis/2QErvFddvI9I4QokOsQXdC',
#   237573,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Love To Lay',
#   '2016-11-24',
#   0.711,
#   0.807,
#   7,
#   -5.053,
#   0,
#   0.0608,
#   0.0519,
#   0,
#   0.214,
#   0.699,
#   116.971,
#   'audio_features',
#   '1E43TJhKcM8hXgM958ROQ1',
#   'spotify:track:1E43TJhKcM8hXgM958ROQ1',
#   'https://api.spotify.com/v1/tracks/1E43TJhKcM8hXgM958ROQ1',
#   'https://api.spotify.com/v1/audio-analysis/1E43TJhKcM8hXgM958ROQ1',
#   223293,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'A Lonely Night',
#   '2016-11-24',
#   0.853,
#   0.663,
#   7,
#   -6.955,
#   0,
#   0.0755,
#   0.0431,
#   8.65e-06,
#   0.0891,
#   0.864,
#   113.999,
#   'audio_features',
#   '4UknpXoLjlB7Mao4UWcJ2o',
#   'spotify:track:4UknpXoLjlB7Mao4UWcJ2o',
#   'https://api.spotify.com/v1/tracks/4UknpXoLjlB7Mao4UWcJ2o',
#   'https://api.spotify.com/v1/audio-analysis/4UknpXoLjlB7Mao4UWcJ2o',
#   220173,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Attention',
#   '2016-11-24',
#   0.668,
#   0.435,
#   4,
#   -7.115,
#   0,
#   0.117,
#   0.726,
#   8.17e-05,
#   0.117,
#   0.361,
#   148.069,
#   'audio_features',
#   '0HlIziU2FZ7BjiQDt8Zost',
#   'spotify:track:0HlIziU2FZ7BjiQDt8Zost',
#   'https://api.spotify.com/v1/tracks/0HlIziU2FZ7BjiQDt8Zost',
#   'https://api.spotify.com/v1/audio-analysis/0HlIziU2FZ7BjiQDt8Zost',
#   197653,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Ordinary Life',
#   '2016-11-24',
#   0.544,
#   0.586,
#   7,
#   -7.486,
#   0,
#   0.0794,
#   0.0276,
#   0,
#   0.0962,
#   0.361,
#   149.882,
#   'audio_features',
#   '7lsYGc5H5DHktxO7gbB8bN',
#   'spotify:track:7lsYGc5H5DHktxO7gbB8bN',
#   'https://api.spotify.com/v1/tracks/7lsYGc5H5DHktxO7gbB8bN',
#   'https://api.spotify.com/v1/audio-analysis/7lsYGc5H5DHktxO7gbB8bN',
#   221920,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Nothing Without You',
#   '2016-11-24',
#   0.599,
#   0.635,
#   1,
#   -8.101,
#   1,
#   0.0679,
#   0.064,
#   0,
#   0.0878,
#   0.194,
#   109.919,
#   'audio_features',
#   '3Te3gG6MPEDNqLGzWrjKC3',
#   'spotify:track:3Te3gG6MPEDNqLGzWrjKC3',
#   'https://api.spotify.com/v1/tracks/3Te3gG6MPEDNqLGzWrjKC3',
#   'https://api.spotify.com/v1/audio-analysis/3Te3gG6MPEDNqLGzWrjKC3',
#   198653,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'All I Know',
#   '2016-11-24',
#   0.636,
#   0.402,
#   8,
#   -10.746,
#   0,
#   0.0559,
#   0.461,
#   0.00112,
#   0.101,
#   0.194,
#   120.02,
#   'audio_features',
#   '4MBGysmc3qsFY3jYEgYfHe',
#   'spotify:track:4MBGysmc3qsFY3jYEgYfHe',
#   'https://api.spotify.com/v1/tracks/4MBGysmc3qsFY3jYEgYfHe',
#   'https://api.spotify.com/v1/audio-analysis/4MBGysmc3qsFY3jYEgYfHe',
#   321027,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'Die For You',
#   '2016-11-24',
#   0.586,
#   0.525,
#   1,
#   -7.163,
#   0,
#   0.0615,
#   0.111,
#   0,
#   0.134,
#   0.508,
#   133.629,
#   'audio_features',
#   '2LBqCSwhJGcFQeTHMVGwy3',
#   'spotify:track:2LBqCSwhJGcFQeTHMVGwy3',
#   'https://api.spotify.com/v1/tracks/2LBqCSwhJGcFQeTHMVGwy3',
#   'https://api.spotify.com/v1/audio-analysis/2LBqCSwhJGcFQeTHMVGwy3',
#   260253,
#   4],
#  ['The Weeknd',
#   'Starboy',
#   'spotify:album:4AdZV63ycxFLF6Hcol0QnB',
#   'I Feel It Coming',
#   '2016-11-24',
#   0.773,
#   0.819,
#   0,
#   -5.946,
#   0,
#   0.118,
#   0.426,
#   0,
#   0.0679,
#   0.585,
#   92.99,
#   'audio_features',
#   '5GXAXm5YOmYT0kL5jHvYBt',
#   'spotify:track:5GXAXm5YOmYT0kL5jHvYBt',
#   'https://api.spotify.com/v1/tracks/5GXAXm5YOmYT0kL5jHvYBt',
#   'https://api.spotify.com/v1/audio-analysis/5GXAXm5YOmYT0kL5jHvYBt',
#   269187,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Real Life',
#   '2016-03-16',
#   0.58,
#   0.653,
#   11,
#   -5.04,
#   0,
#   0.0506,
#   0.438,
#   0,
#   0.351,
#   0.346,
#   90.726,
#   'audio_features',
#   '60jW6P7AGw2FozTaqctJ4i',
#   'spotify:track:60jW6P7AGw2FozTaqctJ4i',
#   'https://api.spotify.com/v1/tracks/60jW6P7AGw2FozTaqctJ4i',
#   'https://api.spotify.com/v1/audio-analysis/60jW6P7AGw2FozTaqctJ4i',
#   223347,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Losers',
#   '2016-03-16',
#   0.661,
#   0.483,
#   0,
#   -9.793,
#   0,
#   0.0496,
#   0.0309,
#   0.000801,
#   0.507,
#   0.296,
#   90.994,
#   'audio_features',
#   '2bWO9puW3hXQcZZsehDRCo',
#   'spotify:track:2bWO9puW3hXQcZZsehDRCo',
#   'https://api.spotify.com/v1/tracks/2bWO9puW3hXQcZZsehDRCo',
#   'https://api.spotify.com/v1/audio-analysis/2bWO9puW3hXQcZZsehDRCo',
#   281173,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Tell Your Friends',
#   '2016-03-16',
#   0.565,
#   0.454,
#   1,
#   -11.091,
#   0,
#   0.0461,
#   0.265,
#   0,
#   0.181,
#   0.312,
#   74.809,
#   'audio_features',
#   '4cgDltqQz6YKPotLNbfGDn',
#   'spotify:track:4cgDltqQz6YKPotLNbfGDn',
#   'https://api.spotify.com/v1/tracks/4cgDltqQz6YKPotLNbfGDn',
#   'https://api.spotify.com/v1/audio-analysis/4cgDltqQz6YKPotLNbfGDn',
#   334200,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Often',
#   '2016-03-16',
#   0.567,
#   0.622,
#   7,
#   -9.821,
#   0,
#   0.046,
#   0.248,
#   0,
#   0.139,
#   0.0751,
#   133.984,
#   'audio_features',
#   '3Hf7SsKqVeZ0uW164edrJl',
#   'spotify:track:3Hf7SsKqVeZ0uW164edrJl',
#   'https://api.spotify.com/v1/tracks/3Hf7SsKqVeZ0uW164edrJl',
#   'https://api.spotify.com/v1/audio-analysis/3Hf7SsKqVeZ0uW164edrJl',
#   249107,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'The Hills',
#   '2016-03-16',
#   0.374,
#   0.55,
#   0,
#   -7.007,
#   0,
#   0.0848,
#   0.0841,
#   0,
#   0.139,
#   0.124,
#   112.912,
#   'audio_features',
#   '7H5EBs3aGqRPZaGEvU6y6F',
#   'spotify:track:7H5EBs3aGqRPZaGEvU6y6F',
#   'https://api.spotify.com/v1/tracks/7H5EBs3aGqRPZaGEvU6y6F',
#   'https://api.spotify.com/v1/audio-analysis/7H5EBs3aGqRPZaGEvU6y6F',
#   242280,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Acquainted',
#   '2016-03-16',
#   0.485,
#   0.481,
#   7,
#   -9.858,
#   0,
#   0.051,
#   0.437,
#   0,
#   0.0861,
#   0.233,
#   105.934,
#   'audio_features',
#   '5OejsjQoFVXniKLsXYs7G4',
#   'spotify:track:5OejsjQoFVXniKLsXYs7G4',
#   'https://api.spotify.com/v1/tracks/5OejsjQoFVXniKLsXYs7G4',
#   'https://api.spotify.com/v1/audio-analysis/5OejsjQoFVXniKLsXYs7G4',
#   348893,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   "Can't Feel My Face",
#   '2016-03-16',
#   0.705,
#   0.769,
#   9,
#   -5.526,
#   0,
#   0.0426,
#   0.112,
#   0,
#   0.105,
#   0.59,
#   107.939,
#   'audio_features',
#   '64bYIchESwtANfBlwJoK1e',
#   'spotify:track:64bYIchESwtANfBlwJoK1e',
#   'https://api.spotify.com/v1/tracks/64bYIchESwtANfBlwJoK1e',
#   'https://api.spotify.com/v1/audio-analysis/64bYIchESwtANfBlwJoK1e',
#   213520,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Shameless',
#   '2016-03-16',
#   0.603,
#   0.562,
#   6,
#   -8.311,
#   1,
#   0.0267,
#   0.146,
#   0,
#   0.109,
#   0.244,
#   100.038,
#   'audio_features',
#   '7MMQME7nvRBZ1ru82bJ9of',
#   'spotify:track:7MMQME7nvRBZ1ru82bJ9of',
#   'https://api.spotify.com/v1/tracks/7MMQME7nvRBZ1ru82bJ9of',
#   'https://api.spotify.com/v1/audio-analysis/7MMQME7nvRBZ1ru82bJ9of',
#   253507,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Earned It (Fifty Shades Of Grey)',
#   '2016-03-16',
#   0.647,
#   0.291,
#   2,
#   -8.275,
#   0,
#   0.0363,
#   0.408,
#   0,
#   0.0772,
#   0.4,
#   119.839,
#   'audio_features',
#   '7ID2dydg1QFuWObmdhwzfm',
#   'spotify:track:7ID2dydg1QFuWObmdhwzfm',
#   'https://api.spotify.com/v1/tracks/7ID2dydg1QFuWObmdhwzfm',
#   'https://api.spotify.com/v1/audio-analysis/7ID2dydg1QFuWObmdhwzfm',
#   277707,
#   3],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'In The Night',
#   '2016-03-16',
#   0.4,
#   0.673,
#   7,
#   -4.967,
#   1,
#   0.125,
#   0.0803,
#   0,
#   0.0484,
#   0.508,
#   112.122,
#   'audio_features',
#   '17ghHlAfjnAIEpYGTlX4GL',
#   'spotify:track:17ghHlAfjnAIEpYGTlX4GL',
#   'https://api.spotify.com/v1/tracks/17ghHlAfjnAIEpYGTlX4GL',
#   'https://api.spotify.com/v1/audio-analysis/17ghHlAfjnAIEpYGTlX4GL',
#   235627,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'As You Are',
#   '2016-03-16',
#   0.371,
#   0.329,
#   0,
#   -9.667,
#   0,
#   0.0574,
#   0.131,
#   0.00625,
#   0.279,
#   0.0539,
#   173.661,
#   'audio_features',
#   '2d1ogCmohNk5jsRTk0eCNs',
#   'spotify:track:2d1ogCmohNk5jsRTk0eCNs',
#   'https://api.spotify.com/v1/tracks/2d1ogCmohNk5jsRTk0eCNs',
#   'https://api.spotify.com/v1/audio-analysis/2d1ogCmohNk5jsRTk0eCNs',
#   340493,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Dark Times',
#   '2016-03-16',
#   0.501,
#   0.403,
#   9,
#   -9.607,
#   0,
#   0.0752,
#   0.114,
#   1.1e-05,
#   0.124,
#   0.27,
#   132.608,
#   'audio_features',
#   '3JOh1LxSDVjTLF5DAB8R5M',
#   'spotify:track:3JOh1LxSDVjTLF5DAB8R5M',
#   'https://api.spotify.com/v1/tracks/3JOh1LxSDVjTLF5DAB8R5M',
#   'https://api.spotify.com/v1/audio-analysis/3JOh1LxSDVjTLF5DAB8R5M',
#   260640,
#   3],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Prisoner',
#   '2016-03-16',
#   0.55,
#   0.404,
#   0,
#   -12.755,
#   0,
#   0.0398,
#   0.441,
#   0.00022,
#   0.11,
#   0.329,
#   135.016,
#   'audio_features',
#   '3q3INoUz56tAaKXZSkONon',
#   'spotify:track:3q3INoUz56tAaKXZSkONon',
#   'https://api.spotify.com/v1/tracks/3q3INoUz56tAaKXZSkONon',
#   'https://api.spotify.com/v1/audio-analysis/3q3INoUz56tAaKXZSkONon',
#   274960,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'Angel',
#   '2016-03-16',
#   0.626,
#   0.583,
#   10,
#   -7.574,
#   0,
#   0.0435,
#   0.105,
#   0,
#   0.115,
#   0.335,
#   127.956,
#   'audio_features',
#   '2qHMUxqGht8K1wNjXG40wH',
#   'spotify:track:2qHMUxqGht8K1wNjXG40wH',
#   'https://api.spotify.com/v1/tracks/2qHMUxqGht8K1wNjXG40wH',
#   'https://api.spotify.com/v1/audio-analysis/2qHMUxqGht8K1wNjXG40wH',
#   377627,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   "Can't Feel My Face - Martin Garrix Remix",
#   '2016-03-16',
#   0.605,
#   0.714,
#   9,
#   -5.432,
#   0,
#   0.101,
#   0.0104,
#   2.35e-05,
#   0.324,
#   0.136,
#   128.025,
#   'audio_features',
#   '5KIfOGEy5DM2TaT0ph5nYM',
#   'spotify:track:5KIfOGEy5DM2TaT0ph5nYM',
#   'https://api.spotify.com/v1/tracks/5KIfOGEy5DM2TaT0ph5nYM',
#   'https://api.spotify.com/v1/audio-analysis/5KIfOGEy5DM2TaT0ph5nYM',
#   253933,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'The Hills - Remix',
#   '2016-03-16',
#   0.65,
#   0.632,
#   0,
#   -6.672,
#   0,
#   0.184,
#   0.0681,
#   0,
#   0.0875,
#   0.33,
#   112.927,
#   'audio_features',
#   '2jpBr2dJrIgrpkqorINSAa',
#   'spotify:track:2jpBr2dJrIgrpkqorINSAa',
#   'https://api.spotify.com/v1/tracks/2jpBr2dJrIgrpkqorINSAa',
#   'https://api.spotify.com/v1/audio-analysis/2jpBr2dJrIgrpkqorINSAa',
#   263960,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:36yJ6fcaSCVsK1tybnNizj',
#   'The Hills - Remix',
#   '2016-03-16',
#   0.409,
#   0.602,
#   0,
#   -7.025,
#   0,
#   0.108,
#   0.0974,
#   0,
#   0.107,
#   0.186,
#   110.463,
#   'audio_features',
#   '019FM2BxcPE2vyGWeOWhvS',
#   'spotify:track:019FM2BxcPE2vyGWeOWhvS',
#   'https://api.spotify.com/v1/tracks/019FM2BxcPE2vyGWeOWhvS',
#   'https://api.spotify.com/v1/audio-analysis/019FM2BxcPE2vyGWeOWhvS',
#   243493,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Real Life',
#   '2015-08-28',
#   0.581,
#   0.653,
#   11,
#   -5.04,
#   0,
#   0.0506,
#   0.438,
#   0,
#   0.351,
#   0.346,
#   90.726,
#   'audio_features',
#   '03j354P848KtNU2FVSwkDG',
#   'spotify:track:03j354P848KtNU2FVSwkDG',
#   'https://api.spotify.com/v1/tracks/03j354P848KtNU2FVSwkDG',
#   'https://api.spotify.com/v1/audio-analysis/03j354P848KtNU2FVSwkDG',
#   223373,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Losers',
#   '2015-08-28',
#   0.666,
#   0.485,
#   0,
#   -9.85,
#   0,
#   0.0527,
#   0.0355,
#   0.000603,
#   0.504,
#   0.288,
#   91.009,
#   'audio_features',
#   '1bAvtmTl0F9loyz9AwPwp7',
#   'spotify:track:1bAvtmTl0F9loyz9AwPwp7',
#   'https://api.spotify.com/v1/tracks/1bAvtmTl0F9loyz9AwPwp7',
#   'https://api.spotify.com/v1/audio-analysis/1bAvtmTl0F9loyz9AwPwp7',
#   281147,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Tell Your Friends',
#   '2015-08-28',
#   0.565,
#   0.454,
#   1,
#   -11.091,
#   0,
#   0.0461,
#   0.265,
#   0,
#   0.181,
#   0.312,
#   74.809,
#   'audio_features',
#   '1mhVXWduD8ReDwusfaHNwU',
#   'spotify:track:1mhVXWduD8ReDwusfaHNwU',
#   'https://api.spotify.com/v1/tracks/1mhVXWduD8ReDwusfaHNwU',
#   'https://api.spotify.com/v1/audio-analysis/1mhVXWduD8ReDwusfaHNwU',
#   334333,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Often',
#   '2015-08-28',
#   0.569,
#   0.629,
#   7,
#   -9.837,
#   0,
#   0.0485,
#   0.218,
#   0,
#   0.135,
#   0.0726,
#   134.035,
#   'audio_features',
#   '4PhsKqMdgMEUSstTDAmMpg',
#   'spotify:track:4PhsKqMdgMEUSstTDAmMpg',
#   'https://api.spotify.com/v1/tracks/4PhsKqMdgMEUSstTDAmMpg',
#   'https://api.spotify.com/v1/audio-analysis/4PhsKqMdgMEUSstTDAmMpg',
#   249040,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'The Hills',
#   '2015-08-28',
#   0.58,
#   0.565,
#   0,
#   -7.065,
#   0,
#   0.0488,
#   0.0671,
#   0,
#   0.135,
#   0.138,
#   112.986,
#   'audio_features',
#   '7fBv7CLKzipRk6EC6TWHOB',
#   'spotify:track:7fBv7CLKzipRk6EC6TWHOB',
#   'https://api.spotify.com/v1/tracks/7fBv7CLKzipRk6EC6TWHOB',
#   'https://api.spotify.com/v1/audio-analysis/7fBv7CLKzipRk6EC6TWHOB',
#   242253,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Acquainted',
#   '2015-08-28',
#   0.372,
#   0.477,
#   7,
#   -9.838,
#   0,
#   0.0497,
#   0.484,
#   0,
#   0.0844,
#   0.254,
#   101.097,
#   'audio_features',
#   '7uJH0YdSZL6psjxI6Xy08b',
#   'spotify:track:7uJH0YdSZL6psjxI6Xy08b',
#   'https://api.spotify.com/v1/tracks/7uJH0YdSZL6psjxI6Xy08b',
#   'https://api.spotify.com/v1/audio-analysis/7uJH0YdSZL6psjxI6Xy08b',
#   348853,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   "Can't Feel My Face",
#   '2015-08-28',
#   0.705,
#   0.769,
#   9,
#   -5.526,
#   0,
#   0.0426,
#   0.112,
#   0,
#   0.105,
#   0.59,
#   107.939,
#   'audio_features',
#   '22VdIZQfgXJea34mQxlt81',
#   'spotify:track:22VdIZQfgXJea34mQxlt81',
#   'https://api.spotify.com/v1/tracks/22VdIZQfgXJea34mQxlt81',
#   'https://api.spotify.com/v1/audio-analysis/22VdIZQfgXJea34mQxlt81',
#   213520,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Shameless',
#   '2015-08-28',
#   0.603,
#   0.562,
#   6,
#   -8.311,
#   1,
#   0.0267,
#   0.146,
#   0,
#   0.109,
#   0.244,
#   100.038,
#   'audio_features',
#   '6C6fHTuFUxVtJpBOOaMvJr',
#   'spotify:track:6C6fHTuFUxVtJpBOOaMvJr',
#   'https://api.spotify.com/v1/tracks/6C6fHTuFUxVtJpBOOaMvJr',
#   'https://api.spotify.com/v1/audio-analysis/6C6fHTuFUxVtJpBOOaMvJr',
#   253507,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Earned It (Fifty Shades Of Grey)',
#   '2015-08-28',
#   0.647,
#   0.291,
#   2,
#   -8.275,
#   0,
#   0.0363,
#   0.408,
#   0,
#   0.0771,
#   0.4,
#   119.839,
#   'audio_features',
#   '4frLb7nWtsz2ymBE6k2GRP',
#   'spotify:track:4frLb7nWtsz2ymBE6k2GRP',
#   'https://api.spotify.com/v1/tracks/4frLb7nWtsz2ymBE6k2GRP',
#   'https://api.spotify.com/v1/audio-analysis/4frLb7nWtsz2ymBE6k2GRP',
#   277680,
#   3],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'In The Night',
#   '2015-08-28',
#   0.505,
#   0.68,
#   7,
#   -4.99,
#   1,
#   0.0713,
#   0.0796,
#   0,
#   0.0465,
#   0.539,
#   168.021,
#   'audio_features',
#   '25KybV9BOUlvcnv7nN3Pyo',
#   'spotify:track:25KybV9BOUlvcnv7nN3Pyo',
#   'https://api.spotify.com/v1/tracks/25KybV9BOUlvcnv7nN3Pyo',
#   'https://api.spotify.com/v1/audio-analysis/25KybV9BOUlvcnv7nN3Pyo',
#   235653,
#   3],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'As You Are',
#   '2015-08-28',
#   0.371,
#   0.329,
#   0,
#   -9.667,
#   0,
#   0.0574,
#   0.131,
#   0.00625,
#   0.279,
#   0.0539,
#   173.661,
#   'audio_features',
#   '3H3qBumaYj67PT3aMEBvAP',
#   'spotify:track:3H3qBumaYj67PT3aMEBvAP',
#   'https://api.spotify.com/v1/tracks/3H3qBumaYj67PT3aMEBvAP',
#   'https://api.spotify.com/v1/audio-analysis/3H3qBumaYj67PT3aMEBvAP',
#   340493,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Dark Times',
#   '2015-08-28',
#   0.501,
#   0.403,
#   9,
#   -9.607,
#   0,
#   0.0752,
#   0.114,
#   1.1e-05,
#   0.124,
#   0.27,
#   132.608,
#   'audio_features',
#   '6J7PIkhtHwmFjPLq0SyuPj',
#   'spotify:track:6J7PIkhtHwmFjPLq0SyuPj',
#   'https://api.spotify.com/v1/tracks/6J7PIkhtHwmFjPLq0SyuPj',
#   'https://api.spotify.com/v1/audio-analysis/6J7PIkhtHwmFjPLq0SyuPj',
#   260640,
#   3],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Prisoner',
#   '2015-08-28',
#   0.55,
#   0.404,
#   0,
#   -12.755,
#   0,
#   0.0398,
#   0.441,
#   0.00022,
#   0.11,
#   0.329,
#   135.016,
#   'audio_features',
#   '1gZADNt16Oh23jWyMYRk4p',
#   'spotify:track:1gZADNt16Oh23jWyMYRk4p',
#   'https://api.spotify.com/v1/tracks/1gZADNt16Oh23jWyMYRk4p',
#   'https://api.spotify.com/v1/audio-analysis/1gZADNt16Oh23jWyMYRk4p',
#   274960,
#   4],
#  ['The Weeknd',
#   'Beauty Behind The Madness',
#   'spotify:album:0P3oVJBFOv3TDXlYRhGL7s',
#   'Angel',
#   '2015-08-28',
#   0.626,
#   0.583,
#   10,
#   -7.574,
#   0,
#   0.0435,
#   0.105,
#   0,
#   0.115,
#   0.335,
#   127.956,
#   'audio_features',
#   '0wzPHTgOtFIDhk2rD3Au4x',
#   'spotify:track:0wzPHTgOtFIDhk2rD3Au4x',
#   'https://api.spotify.com/v1/tracks/0wzPHTgOtFIDhk2rD3Au4x',
#   'https://api.spotify.com/v1/audio-analysis/0wzPHTgOtFIDhk2rD3Au4x',
#   377347,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Professional',
#   '2013-09-10',
#   0.405,
#   0.619,
#   11,
#   -8.92,
#   0,
#   0.0615,
#   0.162,
#   0.000334,
#   0.0788,
#   0.234,
#   120.092,
#   'audio_features',
#   '7gSjRw3wKuTeDdM0lwp9rv',
#   'spotify:track:7gSjRw3wKuTeDdM0lwp9rv',
#   'https://api.spotify.com/v1/tracks/7gSjRw3wKuTeDdM0lwp9rv',
#   'https://api.spotify.com/v1/audio-analysis/7gSjRw3wKuTeDdM0lwp9rv',
#   368720,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'The Town',
#   '2013-09-10',
#   0.625,
#   0.524,
#   1,
#   -8.227,
#   0,
#   0.0369,
#   0.361,
#   2.67e-06,
#   0.0826,
#   0.191,
#   139.968,
#   'audio_features',
#   '3lcEVP5beEkAFiFIG5D0QF',
#   'spotify:track:3lcEVP5beEkAFiFIG5D0QF',
#   'https://api.spotify.com/v1/tracks/3lcEVP5beEkAFiFIG5D0QF',
#   'https://api.spotify.com/v1/audio-analysis/3lcEVP5beEkAFiFIG5D0QF',
#   307347,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Adaptation',
#   '2013-09-10',
#   0.642,
#   0.79,
#   11,
#   -6.8,
#   0,
#   0.0681,
#   0.151,
#   0.000583,
#   0.305,
#   0.613,
#   114.96,
#   'audio_features',
#   '3FvDYk5IC5Um84kK5FbJGR',
#   'spotify:track:3FvDYk5IC5Um84kK5FbJGR',
#   'https://api.spotify.com/v1/tracks/3FvDYk5IC5Um84kK5FbJGR',
#   'https://api.spotify.com/v1/audio-analysis/3FvDYk5IC5Um84kK5FbJGR',
#   283933,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Love In The Sky',
#   '2013-09-10',
#   0.644,
#   0.736,
#   9,
#   -6.862,
#   0,
#   0.0514,
#   0.16,
#   0.000156,
#   0.6,
#   0.347,
#   115.032,
#   'audio_features',
#   '5vjgyZm1Zhtg4RptN4evNQ',
#   'spotify:track:5vjgyZm1Zhtg4RptN4evNQ',
#   'https://api.spotify.com/v1/tracks/5vjgyZm1Zhtg4RptN4evNQ',
#   'https://api.spotify.com/v1/audio-analysis/5vjgyZm1Zhtg4RptN4evNQ',
#   267920,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Belong To The World',
#   '2013-09-10',
#   0.501,
#   0.858,
#   5,
#   -6.27,
#   0,
#   0.0578,
#   0.00392,
#   0,
#   0.119,
#   0.361,
#   121.018,
#   'audio_features',
#   '4w1dIZxwO83XpKo5wgLhkk',
#   'spotify:track:4w1dIZxwO83XpKo5wgLhkk',
#   'https://api.spotify.com/v1/tracks/4w1dIZxwO83XpKo5wgLhkk',
#   'https://api.spotify.com/v1/audio-analysis/4w1dIZxwO83XpKo5wgLhkk',
#   307173,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Live For',
#   '2013-09-10',
#   0.626,
#   0.68,
#   0,
#   -7.64,
#   1,
#   0.112,
#   0.517,
#   0,
#   0.114,
#   0.227,
#   75.978,
#   'audio_features',
#   '4ER9305DBAmJqj2P96TfBr',
#   'spotify:track:4ER9305DBAmJqj2P96TfBr',
#   'https://api.spotify.com/v1/tracks/4ER9305DBAmJqj2P96TfBr',
#   'https://api.spotify.com/v1/audio-analysis/4ER9305DBAmJqj2P96TfBr',
#   222667,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Wanderlust',
#   '2013-09-10',
#   0.637,
#   0.652,
#   1,
#   -5.237,
#   0,
#   0.0435,
#   0.0668,
#   0.175,
#   0.0714,
#   0.0725,
#   115.924,
#   'audio_features',
#   '5OmX5lXxZ5sQgPuSHDn293',
#   'spotify:track:5OmX5lXxZ5sQgPuSHDn293',
#   'https://api.spotify.com/v1/tracks/5OmX5lXxZ5sQgPuSHDn293',
#   'https://api.spotify.com/v1/audio-analysis/5OmX5lXxZ5sQgPuSHDn293',
#   306773,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Kiss Land',
#   '2013-09-10',
#   0.324,
#   0.852,
#   11,
#   -6.675,
#   0,
#   0.109,
#   0.0415,
#   0,
#   0.061,
#   0.4,
#   121.881,
#   'audio_features',
#   '5FUn6vN4PDHXxqnb5LQhJQ',
#   'spotify:track:5FUn6vN4PDHXxqnb5LQhJQ',
#   'https://api.spotify.com/v1/tracks/5FUn6vN4PDHXxqnb5LQhJQ',
#   'https://api.spotify.com/v1/audio-analysis/5FUn6vN4PDHXxqnb5LQhJQ',
#   455333,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Pretty',
#   '2013-09-10',
#   0.58,
#   0.685,
#   11,
#   -6.829,
#   0,
#   0.0394,
#   0.0355,
#   3.42e-05,
#   0.315,
#   0.331,
#   125.968,
#   'audio_features',
#   '3ZhnXFSunfOPWSqfLLQA9W',
#   'spotify:track:3ZhnXFSunfOPWSqfLLQA9W',
#   'https://api.spotify.com/v1/tracks/3ZhnXFSunfOPWSqfLLQA9W',
#   'https://api.spotify.com/v1/audio-analysis/3ZhnXFSunfOPWSqfLLQA9W',
#   375400,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Tears In The Rain',
#   '2013-09-10',
#   0.655,
#   0.636,
#   1,
#   -7.84,
#   1,
#   0.0453,
#   0.109,
#   0.237,
#   0.0842,
#   0.185,
#   160.01,
#   'audio_features',
#   '7FeSiBUEyqxlKvjGbfwKku',
#   'spotify:track:7FeSiBUEyqxlKvjGbfwKku',
#   'https://api.spotify.com/v1/tracks/7FeSiBUEyqxlKvjGbfwKku',
#   'https://api.spotify.com/v1/audio-analysis/7FeSiBUEyqxlKvjGbfwKku',
#   444653,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Wanderlust',
#   '2013-09-10',
#   0.744,
#   0.598,
#   1,
#   -7.475,
#   0,
#   0.0402,
#   0.101,
#   0.00174,
#   0.104,
#   0.479,
#   116.007,
#   'audio_features',
#   '14p9UeyB3zxuo62wRjk5iR',
#   'spotify:track:14p9UeyB3zxuo62wRjk5iR',
#   'https://api.spotify.com/v1/tracks/14p9UeyB3zxuo62wRjk5iR',
#   'https://api.spotify.com/v1/audio-analysis/14p9UeyB3zxuo62wRjk5iR',
#   305693,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe)',
#   'spotify:album:6wRev1uYL0JsMsWqktJuVi',
#   'Odd Look',
#   '2013-09-10',
#   0.626,
#   0.897,
#   10,
#   -3.647,
#   0,
#   0.0508,
#   0.244,
#   0,
#   0.117,
#   0.256,
#   104.964,
#   'audio_features',
#   '7xcqbjV2NfxlnJzqdRuO7E',
#   'spotify:track:7xcqbjV2NfxlnJzqdRuO7E',
#   'https://api.spotify.com/v1/tracks/7xcqbjV2NfxlnJzqdRuO7E',
#   'https://api.spotify.com/v1/audio-analysis/7xcqbjV2NfxlnJzqdRuO7E',
#   252853,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Professional',
#   '2013-09-09',
#   0.405,
#   0.619,
#   11,
#   -8.92,
#   0,
#   0.0615,
#   0.162,
#   0.000334,
#   0.0788,
#   0.234,
#   120.092,
#   'audio_features',
#   '4HOCKlxanIZAYvi6xlLZwR',
#   'spotify:track:4HOCKlxanIZAYvi6xlLZwR',
#   'https://api.spotify.com/v1/tracks/4HOCKlxanIZAYvi6xlLZwR',
#   'https://api.spotify.com/v1/audio-analysis/4HOCKlxanIZAYvi6xlLZwR',
#   368720,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'The Town',
#   '2013-09-09',
#   0.625,
#   0.524,
#   1,
#   -8.227,
#   0,
#   0.0369,
#   0.361,
#   2.67e-06,
#   0.0826,
#   0.191,
#   139.968,
#   'audio_features',
#   '2K73sh2Kyr0bisUUe67rO0',
#   'spotify:track:2K73sh2Kyr0bisUUe67rO0',
#   'https://api.spotify.com/v1/tracks/2K73sh2Kyr0bisUUe67rO0',
#   'https://api.spotify.com/v1/audio-analysis/2K73sh2Kyr0bisUUe67rO0',
#   307347,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Adaptation',
#   '2013-09-09',
#   0.642,
#   0.79,
#   11,
#   -6.8,
#   0,
#   0.0681,
#   0.151,
#   0.000583,
#   0.305,
#   0.613,
#   114.96,
#   'audio_features',
#   '5f3h1UdxL3A9sDRAJbdfYo',
#   'spotify:track:5f3h1UdxL3A9sDRAJbdfYo',
#   'https://api.spotify.com/v1/tracks/5f3h1UdxL3A9sDRAJbdfYo',
#   'https://api.spotify.com/v1/audio-analysis/5f3h1UdxL3A9sDRAJbdfYo',
#   283933,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Love In The Sky',
#   '2013-09-09',
#   0.634,
#   0.735,
#   9,
#   -6.906,
#   0,
#   0.0513,
#   0.196,
#   0.000508,
#   0.637,
#   0.366,
#   115.049,
#   'audio_features',
#   '2QM7GceiaeVC4eH5uApBmx',
#   'spotify:track:2QM7GceiaeVC4eH5uApBmx',
#   'https://api.spotify.com/v1/tracks/2QM7GceiaeVC4eH5uApBmx',
#   'https://api.spotify.com/v1/audio-analysis/2QM7GceiaeVC4eH5uApBmx',
#   267920,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Belong To The World',
#   '2013-09-09',
#   0.501,
#   0.858,
#   5,
#   -6.27,
#   0,
#   0.0578,
#   0.00392,
#   0,
#   0.119,
#   0.361,
#   121.018,
#   'audio_features',
#   '1HwHhPU5jAkTAzoVhppuex',
#   'spotify:track:1HwHhPU5jAkTAzoVhppuex',
#   'https://api.spotify.com/v1/tracks/1HwHhPU5jAkTAzoVhppuex',
#   'https://api.spotify.com/v1/audio-analysis/1HwHhPU5jAkTAzoVhppuex',
#   307147,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Live For',
#   '2013-09-09',
#   0.572,
#   0.671,
#   9,
#   -7.865,
#   0,
#   0.229,
#   0.562,
#   0,
#   0.116,
#   0.201,
#   151.929,
#   'audio_features',
#   '5Hegrok6kmVN7uXVWkvgDz',
#   'spotify:track:5Hegrok6kmVN7uXVWkvgDz',
#   'https://api.spotify.com/v1/tracks/5Hegrok6kmVN7uXVWkvgDz',
#   'https://api.spotify.com/v1/audio-analysis/5Hegrok6kmVN7uXVWkvgDz',
#   222693,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Wanderlust',
#   '2013-09-09',
#   0.63,
#   0.654,
#   1,
#   -5.253,
#   0,
#   0.0413,
#   0.0671,
#   0.194,
#   0.0672,
#   0.0774,
#   115.956,
#   'audio_features',
#   '5bFmHEQgR9UCTwPer3tWft',
#   'spotify:track:5bFmHEQgR9UCTwPer3tWft',
#   'https://api.spotify.com/v1/tracks/5bFmHEQgR9UCTwPer3tWft',
#   'https://api.spotify.com/v1/audio-analysis/5bFmHEQgR9UCTwPer3tWft',
#   306693,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Kiss Land',
#   '2013-09-09',
#   0.212,
#   0.847,
#   7,
#   -6.674,
#   1,
#   0.237,
#   0.0446,
#   0,
#   0.0594,
#   0.386,
#   64.993,
#   'audio_features',
#   '0sC1e2vvXn6usfpgXVhevu',
#   'spotify:track:0sC1e2vvXn6usfpgXVhevu',
#   'https://api.spotify.com/v1/tracks/0sC1e2vvXn6usfpgXVhevu',
#   'https://api.spotify.com/v1/audio-analysis/0sC1e2vvXn6usfpgXVhevu',
#   455387,
#   3],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Pretty',
#   '2013-09-09',
#   0.57,
#   0.641,
#   11,
#   -7.708,
#   0,
#   0.0405,
#   0.0306,
#   3.24e-05,
#   0.309,
#   0.339,
#   125.961,
#   'audio_features',
#   '5TGCPGkIgNGNz1BjWl2j5J',
#   'spotify:track:5TGCPGkIgNGNz1BjWl2j5J',
#   'https://api.spotify.com/v1/tracks/5TGCPGkIgNGNz1BjWl2j5J',
#   'https://api.spotify.com/v1/audio-analysis/5TGCPGkIgNGNz1BjWl2j5J',
#   375400,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Tears In The Rain',
#   '2013-09-09',
#   0.655,
#   0.636,
#   1,
#   -7.811,
#   1,
#   0.0454,
#   0.108,
#   0.236,
#   0.0846,
#   0.184,
#   160.01,
#   'audio_features',
#   '6mUWMlWX86Mn9kYwSTZqaI',
#   'spotify:track:6mUWMlWX86Mn9kYwSTZqaI',
#   'https://api.spotify.com/v1/tracks/6mUWMlWX86Mn9kYwSTZqaI',
#   'https://api.spotify.com/v1/audio-analysis/6mUWMlWX86Mn9kYwSTZqaI',
#   444653,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Wanderlust',
#   '2013-09-09',
#   0.744,
#   0.598,
#   1,
#   -7.475,
#   0,
#   0.0402,
#   0.101,
#   0.00174,
#   0.104,
#   0.479,
#   116.007,
#   'audio_features',
#   '2jYDC9fMp3FD6TZx3IRI9J',
#   'spotify:track:2jYDC9fMp3FD6TZx3IRI9J',
#   'https://api.spotify.com/v1/tracks/2jYDC9fMp3FD6TZx3IRI9J',
#   'https://api.spotify.com/v1/audio-analysis/2jYDC9fMp3FD6TZx3IRI9J',
#   305693,
#   4],
#  ['The Weeknd',
#   'Kiss Land (Deluxe MENA Version)',
#   'spotify:album:0a6nvQQ7hqmFbqAZVUanDW',
#   'Odd Look',
#   '2013-09-09',
#   0.588,
#   0.848,
#   10,
#   -5.869,
#   0,
#   0.0639,
#   0.218,
#   0,
#   0.116,
#   0.266,
#   104.938,
#   'audio_features',
#   '5NWZKYemdvViFPnwmOcl3M',
#   'spotify:track:5NWZKYemdvViFPnwmOcl3M',
#   'https://api.spotify.com/v1/tracks/5NWZKYemdvViFPnwmOcl3M',
#   'https://api.spotify.com/v1/audio-analysis/5NWZKYemdvViFPnwmOcl3M',
#   252493,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Professional',
#   '2013-09-09',
#   0.405,
#   0.619,
#   11,
#   -8.92,
#   0,
#   0.0615,
#   0.162,
#   0.000334,
#   0.0788,
#   0.234,
#   120.092,
#   'audio_features',
#   '70tFoT5H39JlmOfW7vPX8b',
#   'spotify:track:70tFoT5H39JlmOfW7vPX8b',
#   'https://api.spotify.com/v1/tracks/70tFoT5H39JlmOfW7vPX8b',
#   'https://api.spotify.com/v1/audio-analysis/70tFoT5H39JlmOfW7vPX8b',
#   368720,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'The Town',
#   '2013-09-09',
#   0.625,
#   0.524,
#   1,
#   -8.227,
#   0,
#   0.0369,
#   0.361,
#   2.67e-06,
#   0.0826,
#   0.191,
#   139.968,
#   'audio_features',
#   '6LGIIPmpZa33ybzpd2Adam',
#   'spotify:track:6LGIIPmpZa33ybzpd2Adam',
#   'https://api.spotify.com/v1/tracks/6LGIIPmpZa33ybzpd2Adam',
#   'https://api.spotify.com/v1/audio-analysis/6LGIIPmpZa33ybzpd2Adam',
#   307347,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Adaptation',
#   '2013-09-09',
#   0.642,
#   0.79,
#   11,
#   -6.8,
#   0,
#   0.0681,
#   0.151,
#   0.000583,
#   0.305,
#   0.613,
#   114.96,
#   'audio_features',
#   '0daEzpe5LSCEdFwnGqvbeS',
#   'spotify:track:0daEzpe5LSCEdFwnGqvbeS',
#   'https://api.spotify.com/v1/tracks/0daEzpe5LSCEdFwnGqvbeS',
#   'https://api.spotify.com/v1/audio-analysis/0daEzpe5LSCEdFwnGqvbeS',
#   283933,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Love In The Sky',
#   '2013-09-09',
#   0.634,
#   0.735,
#   9,
#   -6.906,
#   0,
#   0.0513,
#   0.196,
#   0.000508,
#   0.637,
#   0.366,
#   115.049,
#   'audio_features',
#   '5bsI6Vg18pW3ScGVubieZM',
#   'spotify:track:5bsI6Vg18pW3ScGVubieZM',
#   'https://api.spotify.com/v1/tracks/5bsI6Vg18pW3ScGVubieZM',
#   'https://api.spotify.com/v1/audio-analysis/5bsI6Vg18pW3ScGVubieZM',
#   267920,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Belong To The World',
#   '2013-09-09',
#   0.501,
#   0.858,
#   5,
#   -6.27,
#   0,
#   0.0578,
#   0.00392,
#   0,
#   0.119,
#   0.361,
#   121.018,
#   'audio_features',
#   '057XK1XG1whkOE20P1eB3y',
#   'spotify:track:057XK1XG1whkOE20P1eB3y',
#   'https://api.spotify.com/v1/tracks/057XK1XG1whkOE20P1eB3y',
#   'https://api.spotify.com/v1/audio-analysis/057XK1XG1whkOE20P1eB3y',
#   307147,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Live For',
#   '2013-09-09',
#   0.572,
#   0.671,
#   9,
#   -7.865,
#   0,
#   0.229,
#   0.562,
#   0,
#   0.116,
#   0.201,
#   151.929,
#   'audio_features',
#   '4nYZsbdPt2nozYtWtsV9LM',
#   'spotify:track:4nYZsbdPt2nozYtWtsV9LM',
#   'https://api.spotify.com/v1/tracks/4nYZsbdPt2nozYtWtsV9LM',
#   'https://api.spotify.com/v1/audio-analysis/4nYZsbdPt2nozYtWtsV9LM',
#   222693,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Wanderlust',
#   '2013-09-09',
#   0.63,
#   0.654,
#   1,
#   -5.253,
#   0,
#   0.0413,
#   0.0671,
#   0.194,
#   0.0672,
#   0.0774,
#   115.956,
#   'audio_features',
#   '5yutcoI992KTkdRTvc92g6',
#   'spotify:track:5yutcoI992KTkdRTvc92g6',
#   'https://api.spotify.com/v1/tracks/5yutcoI992KTkdRTvc92g6',
#   'https://api.spotify.com/v1/audio-analysis/5yutcoI992KTkdRTvc92g6',
#   306693,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Kiss Land',
#   '2013-09-09',
#   0.212,
#   0.847,
#   7,
#   -6.674,
#   1,
#   0.237,
#   0.0446,
#   0,
#   0.0594,
#   0.386,
#   64.993,
#   'audio_features',
#   '0DP450nbMWazF8TIkzL1ms',
#   'spotify:track:0DP450nbMWazF8TIkzL1ms',
#   'https://api.spotify.com/v1/tracks/0DP450nbMWazF8TIkzL1ms',
#   'https://api.spotify.com/v1/audio-analysis/0DP450nbMWazF8TIkzL1ms',
#   455387,
#   3],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Pretty',
#   '2013-09-09',
#   0.57,
#   0.641,
#   11,
#   -7.708,
#   0,
#   0.0405,
#   0.0306,
#   3.24e-05,
#   0.309,
#   0.339,
#   125.961,
#   'audio_features',
#   '06iCqHBiXigDk456S5L11y',
#   'spotify:track:06iCqHBiXigDk456S5L11y',
#   'https://api.spotify.com/v1/tracks/06iCqHBiXigDk456S5L11y',
#   'https://api.spotify.com/v1/audio-analysis/06iCqHBiXigDk456S5L11y',
#   375400,
#   4],
#  ['The Weeknd',
#   'Kiss Land',
#   'spotify:album:522VpsDblCDf3rMSnDU4tZ',
#   'Tears In The Rain',
#   '2013-09-09',
#   0.655,
#   0.636,
#   1,
#   -7.811,
#   1,
#   0.0454,
#   0.108,
#   0.236,
# ...
#   '6ekzaErm5a1JZcQKj1lXAA',
#   'spotify:track:6ekzaErm5a1JZcQKj1lXAA',
#   'https://api.spotify.com/v1/tracks/6ekzaErm5a1JZcQKj1lXAA',
#   'https://api.spotify.com/v1/audio-analysis/6ekzaErm5a1JZcQKj1lXAA',
#   210333,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'Forever',
#   '2019-11-22',
#   0.644,
#   0.355,
#   1,
#   -7.126,
#   1,
#   0.0262,
#   0.866,
#   0,
#   0.115,
#   0.391,
#   84.999,
#   'audio_features',
#   '5ZF6BpIQZ08CybU5vnwSFq',
#   'spotify:track:5ZF6BpIQZ08CybU5vnwSFq',
#   'https://api.spotify.com/v1/tracks/5ZF6BpIQZ08CybU5vnwSFq',
#   'https://api.spotify.com/v1/audio-analysis/5ZF6BpIQZ08CybU5vnwSFq',
#   210600,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'One',
#   '2019-11-22',
#   0.692,
#   0.352,
#   9,
#   -7.136,
#   1,
#   0.0428,
#   0.82,
#   0,
#   0.145,
#   0.429,
#   118.097,
#   'audio_features',
#   '67xoaMhFu7ZfgzrsCwJYAi',
#   'spotify:track:67xoaMhFu7ZfgzrsCwJYAi',
#   'https://api.spotify.com/v1/tracks/67xoaMhFu7ZfgzrsCwJYAi',
#   'https://api.spotify.com/v1/audio-analysis/67xoaMhFu7ZfgzrsCwJYAi',
#   180173,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   "Don't Get Me Wrong",
#   '2019-11-22',
#   0.447,
#   0.321,
#   4,
#   -7.853,
#   1,
#   0.044,
#   0.826,
#   0,
#   0.108,
#   0.14,
#   67.615,
#   'audio_features',
#   '1zhHn56H5hCPop18Brf4fz',
#   'spotify:track:1zhHn56H5hCPop18Brf4fz',
#   'https://api.spotify.com/v1/tracks/1zhHn56H5hCPop18Brf4fz',
#   'https://api.spotify.com/v1/audio-analysis/1zhHn56H5hCPop18Brf4fz',
#   213093,
#   5],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'Hollywood',
#   '2019-11-22',
#   0.721,
#   0.664,
#   10,
#   -4.906,
#   1,
#   0.0557,
#   0.504,
#   0,
#   0.0958,
#   0.682,
#   124.953,
#   'audio_features',
#   '61hxvsSGZOmFpqjvX0iHJE',
#   'spotify:track:61hxvsSGZOmFpqjvX0iHJE',
#   'https://api.spotify.com/v1/tracks/61hxvsSGZOmFpqjvX0iHJE',
#   'https://api.spotify.com/v1/audio-analysis/61hxvsSGZOmFpqjvX0iHJE',
#   191840,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'Lost On You',
#   '2019-11-22',
#   0.614,
#   0.279,
#   10,
#   -8.244,
#   1,
#   0.0535,
#   0.881,
#   0,
#   0.0934,
#   0.373,
#   125.798,
#   'audio_features',
#   '2kK6G89TrCH0SZOoxe0Nol',
#   'spotify:track:2kK6G89TrCH0SZOoxe0Nol',
#   'https://api.spotify.com/v1/tracks/2kK6G89TrCH0SZOoxe0Nol',
#   'https://api.spotify.com/v1/audio-analysis/2kK6G89TrCH0SZOoxe0Nol',
#   197173,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'Fade',
#   '2019-11-22',
#   0.431,
#   0.492,
#   7,
#   -7.705,
#   1,
#   0.0464,
#   0.362,
#   0,
#   0.0962,
#   0.119,
#   138.445,
#   'audio_features',
#   '5vb911FNE2t5YSFxIVSXWj',
#   'spotify:track:5vb911FNE2t5YSFxIVSXWj',
#   'https://api.spotify.com/v1/tracks/5vb911FNE2t5YSFxIVSXWj',
#   'https://api.spotify.com/v1/audio-analysis/5vb911FNE2t5YSFxIVSXWj',
#   246053,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'Headspace',
#   '2019-11-22',
#   0.379,
#   0.222,
#   11,
#   -9.242,
#   1,
#   0.0332,
#   0.866,
#   0,
#   0.111,
#   0.199,
#   146.856,
#   'audio_features',
#   '2V01LRRv9xyIdLH6K4pM6v',
#   'spotify:track:2V01LRRv9xyIdLH6K4pM6v',
#   'https://api.spotify.com/v1/tracks/2V01LRRv9xyIdLH6K4pM6v',
#   'https://api.spotify.com/v1/audio-analysis/2V01LRRv9xyIdLH6K4pM6v',
#   306733,
#   3],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'Before You Go',
#   '2019-11-22',
#   0.459,
#   0.575,
#   3,
#   -4.858,
#   1,
#   0.0573,
#   0.604,
#   0,
#   0.0885,
#   0.183,
#   111.881,
#   'audio_features',
#   '2gMXnyrvIjhVBUZwvLZDMP',
#   'spotify:track:2gMXnyrvIjhVBUZwvLZDMP',
#   'https://api.spotify.com/v1/tracks/2gMXnyrvIjhVBUZwvLZDMP',
#   'https://api.spotify.com/v1/audio-analysis/2gMXnyrvIjhVBUZwvLZDMP',
#   215107,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'Leaving My Love Behind',
#   '2019-11-22',
#   0.409,
#   0.446,
#   2,
#   -4.836,
#   1,
#   0.0317,
#   0.65,
#   0,
#   0.0862,
#   0.135,
#   75.638,
#   'audio_features',
#   '1NxHgM5nOnmqi3KUVLbaIw',
#   'spotify:track:1NxHgM5nOnmqi3KUVLbaIw',
#   'https://api.spotify.com/v1/tracks/1NxHgM5nOnmqi3KUVLbaIw',
#   'https://api.spotify.com/v1/audio-analysis/1NxHgM5nOnmqi3KUVLbaIw',
#   210213,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'spotify:album:2wiPF3m0ylst0JSk1IvZL8',
#   'Let It Roll',
#   '2019-11-22',
#   0.616,
#   0.715,
#   6,
#   -4.174,
#   1,
#   0.0345,
#   0.523,
#   0,
#   0.0947,
#   0.634,
#   100.098,
#   'audio_features',
#   '4lRSeOZ97LHOFDk5A0opcq',
#   'spotify:track:4lRSeOZ97LHOFDk5A0opcq',
#   'https://api.spotify.com/v1/tracks/4lRSeOZ97LHOFDk5A0opcq',
#   'https://api.spotify.com/v1/audio-analysis/4lRSeOZ97LHOFDk5A0opcq',
#   219693,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Grace',
#   '2019-05-17',
#   0.722,
#   0.565,
#   4,
#   -5.848,
#   1,
#   0.0335,
#   0.435,
#   0,
#   0.165,
#   0.488,
#   104.483,
#   'audio_features',
#   '0pEkK8MqbmGSX7fT8WLMbR',
#   'spotify:track:0pEkK8MqbmGSX7fT8WLMbR',
#   'https://api.spotify.com/v1/tracks/0pEkK8MqbmGSX7fT8WLMbR',
#   'https://api.spotify.com/v1/audio-analysis/0pEkK8MqbmGSX7fT8WLMbR',
#   185658,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Bruises',
#   '2019-05-17',
#   0.736,
#   0.308,
#   4,
#   -7.83,
#   1,
#   0.0677,
#   0.946,
#   0,
#   0.186,
#   0.361,
#   111.202,
#   'audio_features',
#   '4Of7rzpRpV1mWRbhp5rAqG',
#   'spotify:track:4Of7rzpRpV1mWRbhp5rAqG',
#   'https://api.spotify.com/v1/tracks/4Of7rzpRpV1mWRbhp5rAqG',
#   'https://api.spotify.com/v1/audio-analysis/4Of7rzpRpV1mWRbhp5rAqG',
#   220492,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Hold Me While You Wait',
#   '2019-05-17',
#   0.688,
#   0.53,
#   11,
#   -5.507,
#   1,
#   0.0333,
#   0.443,
#   0,
#   0.0995,
#   0.162,
#   106.958,
#   'audio_features',
#   '60iSKGrGazRzICtMjADNSM',
#   'spotify:track:60iSKGrGazRzICtMjADNSM',
#   'https://api.spotify.com/v1/tracks/60iSKGrGazRzICtMjADNSM',
#   'https://api.spotify.com/v1/audio-analysis/60iSKGrGazRzICtMjADNSM',
#   205687,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Someone You Loved',
#   '2019-05-17',
#   0.501,
#   0.405,
#   1,
#   -5.679,
#   1,
#   0.0319,
#   0.751,
#   0,
#   0.105,
#   0.446,
#   109.891,
#   'audio_features',
#   '7qEHsqek33rTcFNT9PFqLf',
#   'spotify:track:7qEHsqek33rTcFNT9PFqLf',
#   'https://api.spotify.com/v1/tracks/7qEHsqek33rTcFNT9PFqLf',
#   'https://api.spotify.com/v1/audio-analysis/7qEHsqek33rTcFNT9PFqLf',
#   182161,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Maybe',
#   '2019-05-17',
#   0.681,
#   0.636,
#   4,
#   -5.485,
#   1,
#   0.0409,
#   0.65,
#   0,
#   0.258,
#   0.341,
#   96.966,
#   'audio_features',
#   '5HU2B0yEnvg5EUB8FWeoda',
#   'spotify:track:5HU2B0yEnvg5EUB8FWeoda',
#   'https://api.spotify.com/v1/tracks/5HU2B0yEnvg5EUB8FWeoda',
#   'https://api.spotify.com/v1/audio-analysis/5HU2B0yEnvg5EUB8FWeoda',
#   210116,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Forever',
#   '2019-05-17',
#   0.646,
#   0.355,
#   1,
#   -7.119,
#   1,
#   0.0263,
#   0.873,
#   0,
#   0.115,
#   0.364,
#   84.988,
#   'audio_features',
#   '12OLyHDxt6dqlAybSPFBK3',
#   'spotify:track:12OLyHDxt6dqlAybSPFBK3',
#   'https://api.spotify.com/v1/tracks/12OLyHDxt6dqlAybSPFBK3',
#   'https://api.spotify.com/v1/audio-analysis/12OLyHDxt6dqlAybSPFBK3',
#   210863,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'One',
#   '2019-05-17',
#   0.708,
#   0.339,
#   9,
#   -7.085,
#   1,
#   0.0409,
#   0.834,
#   0,
#   0.128,
#   0.512,
#   117.995,
#   'audio_features',
#   '5C1TucCRf4Vjjree1OItyv',
#   'spotify:track:5C1TucCRf4Vjjree1OItyv',
#   'https://api.spotify.com/v1/tracks/5C1TucCRf4Vjjree1OItyv',
#   'https://api.spotify.com/v1/audio-analysis/5C1TucCRf4Vjjree1OItyv',
#   179908,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   "Don't Get Me Wrong",
#   '2019-05-17',
#   0.57,
#   0.324,
#   4,
#   -7.866,
#   1,
#   0.0374,
#   0.837,
#   0,
#   0.109,
#   0.137,
#   79.858,
#   'audio_features',
#   '4QGHin0gSqzPrPJhPU5gWn',
#   'spotify:track:4QGHin0gSqzPrPJhPU5gWn',
#   'https://api.spotify.com/v1/tracks/4QGHin0gSqzPrPJhPU5gWn',
#   'https://api.spotify.com/v1/audio-analysis/4QGHin0gSqzPrPJhPU5gWn',
#   213091,
#   3],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Hollywood',
#   '2019-05-17',
#   0.723,
#   0.669,
#   10,
#   -4.897,
#   1,
#   0.0527,
#   0.553,
#   0,
#   0.0959,
#   0.732,
#   125.038,
#   'audio_features',
#   '5uGjeXi3epIE8N2ITkxIQ5',
#   'spotify:track:5uGjeXi3epIE8N2ITkxIQ5',
#   'https://api.spotify.com/v1/tracks/5uGjeXi3epIE8N2ITkxIQ5',
#   'https://api.spotify.com/v1/audio-analysis/5uGjeXi3epIE8N2ITkxIQ5',
#   191844,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Lost On You',
#   '2019-05-17',
#   0.555,
#   0.282,
#   10,
#   -8.228,
#   1,
#   0.0612,
#   0.889,
#   0,
#   0.0927,
#   0.382,
#   125.522,
#   'audio_features',
#   '6glNKSv2aUtfQhe1SJBZZt',
#   'spotify:track:6glNKSv2aUtfQhe1SJBZZt',
#   'https://api.spotify.com/v1/tracks/6glNKSv2aUtfQhe1SJBZZt',
#   'https://api.spotify.com/v1/audio-analysis/6glNKSv2aUtfQhe1SJBZZt',
#   197179,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Fade',
#   '2019-05-17',
#   0.41,
#   0.487,
#   7,
#   -7.663,
#   1,
#   0.0449,
#   0.328,
#   0,
#   0.0953,
#   0.126,
#   138.46,
#   'audio_features',
#   '6r2tV58enH9E8hj2oqoJNK',
#   'spotify:track:6r2tV58enH9E8hj2oqoJNK',
#   'https://api.spotify.com/v1/tracks/6r2tV58enH9E8hj2oqoJNK',
#   'https://api.spotify.com/v1/audio-analysis/6r2tV58enH9E8hj2oqoJNK',
#   246054,
#   4],
#  ['Lewis Capaldi',
#   'Divinely Uninspired To A Hellish Extent',
#   'spotify:album:5658aM19fA3JVwTK6eQX70',
#   'Headspace',
#   '2019-05-17',
#   0.368,
#   0.228,
#   11,
#   -9.183,
#   1,
#   0.0335,
#   0.865,
#   1.99e-06,
#   0.111,
#   0.194,
#   146.881,
#   'audio_features',
#   '4RtlhOoWNO5ReUwdmTdTcG',
#   'spotify:track:4RtlhOoWNO5ReUwdmTdTcG',
#   'https://api.spotify.com/v1/tracks/4RtlhOoWNO5ReUwdmTdTcG',
#   'https://api.spotify.com/v1/audio-analysis/4RtlhOoWNO5ReUwdmTdTcG',
#   306801,
#   3],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Baby Pluto',
#   '2020-03-06',
#   0.772,
#   0.634,
#   10,
#   -6.101,
#   0,
#   0.212,
#   0.135,
#   0,
#   0.432,
#   0.671,
#   160.052,
#   'audio_features',
#   '7hav1MHURQf5SAoPk0egqh',
#   'spotify:track:7hav1MHURQf5SAoPk0egqh',
#   'https://api.spotify.com/v1/tracks/7hav1MHURQf5SAoPk0egqh',
#   'https://api.spotify.com/v1/audio-analysis/7hav1MHURQf5SAoPk0egqh',
#   210261,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Lo Mein',
#   '2020-03-06',
#   0.855,
#   0.676,
#   1,
#   -5.736,
#   1,
#   0.325,
#   0.0888,
#   0,
#   0.144,
#   0.509,
#   133.081,
#   'audio_features',
#   '6CUP2khYzdphXebxVTfPE3',
#   'spotify:track:6CUP2khYzdphXebxVTfPE3',
#   'https://api.spotify.com/v1/tracks/6CUP2khYzdphXebxVTfPE3',
#   'https://api.spotify.com/v1/audio-analysis/6CUP2khYzdphXebxVTfPE3',
#   195299,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Silly Watch',
#   '2020-03-06',
#   0.903,
#   0.535,
#   8,
#   -6.238,
#   1,
#   0.286,
#   0.0296,
#   0,
#   0.0851,
#   0.157,
#   130.117,
#   'audio_features',
#   '5egD7A5x9AHdVO2fMo3Wbo',
#   'spotify:track:5egD7A5x9AHdVO2fMo3Wbo',
#   'https://api.spotify.com/v1/tracks/5egD7A5x9AHdVO2fMo3Wbo',
#   'https://api.spotify.com/v1/audio-analysis/5egD7A5x9AHdVO2fMo3Wbo',
#   195692,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'POP',
#   '2020-03-06',
#   0.742,
#   0.6,
#   1,
#   -6.668,
#   0,
#   0.418,
#   0.00948,
#   0,
#   0.785,
#   0.272,
#   139.888,
#   'audio_features',
#   '1jDbQz6tr52WgScCTXMnaN',
#   'spotify:track:1jDbQz6tr52WgScCTXMnaN',
#   'https://api.spotify.com/v1/tracks/1jDbQz6tr52WgScCTXMnaN',
#   'https://api.spotify.com/v1/audio-analysis/1jDbQz6tr52WgScCTXMnaN',
#   227474,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'You Better Move',
#   '2020-03-06',
#   0.842,
#   0.556,
#   8,
#   -6.793,
#   1,
#   0.442,
#   0.159,
#   0,
#   0.204,
#   0.306,
#   118.836,
#   'audio_features',
#   '6YAxCn4juTWn5hWl2hzHGw',
#   'spotify:track:6YAxCn4juTWn5hWl2hzHGw',
#   'https://api.spotify.com/v1/tracks/6YAxCn4juTWn5hWl2hzHGw',
#   'https://api.spotify.com/v1/audio-analysis/6YAxCn4juTWn5hWl2hzHGw',
#   196639,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Homecoming',
#   '2020-03-06',
#   0.929,
#   0.563,
#   9,
#   -7.428,
#   1,
#   0.49,
#   0.000592,
#   0,
#   0.244,
#   0.354,
#   129.957,
#   'audio_features',
#   '6vxU64pcIuQ38O015Zy4qj',
#   'spotify:track:6vxU64pcIuQ38O015Zy4qj',
#   'https://api.spotify.com/v1/tracks/6vxU64pcIuQ38O015Zy4qj',
#   'https://api.spotify.com/v1/audio-analysis/6vxU64pcIuQ38O015Zy4qj',
#   213885,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   "I'm Sorry",
#   '2020-03-06',
#   0.858,
#   0.547,
#   1,
#   -5.822,
#   1,
#   0.29,
#   0.213,
#   0,
#   0.104,
#   0.304,
#   128.02,
#   'audio_features',
#   '1xcOYJxDa5pObgxY1r0I9c',
#   'spotify:track:1xcOYJxDa5pObgxY1r0I9c',
#   'https://api.spotify.com/v1/tracks/1xcOYJxDa5pObgxY1r0I9c',
#   'https://api.spotify.com/v1/audio-analysis/1xcOYJxDa5pObgxY1r0I9c',
#   211883,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Celebration Station',
#   '2020-03-06',
#   0.748,
#   0.771,
#   6,
#   -4.156,
#   1,
#   0.15,
#   0.101,
#   0,
#   0.135,
#   0.792,
#   142.087,
#   'audio_features',
#   '25B5fGr9K0VdZJiRFsnMO4',
#   'spotify:track:25B5fGr9K0VdZJiRFsnMO4',
#   'https://api.spotify.com/v1/tracks/25B5fGr9K0VdZJiRFsnMO4',
#   'https://api.spotify.com/v1/audio-analysis/25B5fGr9K0VdZJiRFsnMO4',
#   195058,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Bigger Than Life',
#   '2020-03-06',
#   0.776,
#   0.752,
#   8,
#   -4.711,
#   0,
#   0.194,
#   0.325,
#   0,
#   0.33,
#   0.716,
#   140.008,
#   'audio_features',
#   '2oHDJHNondITqbl8xZ9vPn',
#   'spotify:track:2oHDJHNondITqbl8xZ9vPn',
#   'https://api.spotify.com/v1/tracks/2oHDJHNondITqbl8xZ9vPn',
#   'https://api.spotify.com/v1/audio-analysis/2oHDJHNondITqbl8xZ9vPn',
#   192705,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Chrome Heart Tags',
#   '2020-03-06',
#   0.703,
#   0.768,
#   0,
#   -4.055,
#   1,
#   0.0655,
#   0.541,
#   0,
#   0.105,
#   0.572,
#   70.055,
#   'audio_features',
#   '46mT9NR7N9Zf5MolcrBgE3',
#   'spotify:track:46mT9NR7N9Zf5MolcrBgE3',
#   'https://api.spotify.com/v1/tracks/46mT9NR7N9Zf5MolcrBgE3',
#   'https://api.spotify.com/v1/audio-analysis/46mT9NR7N9Zf5MolcrBgE3',
#   212821,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Bust Me',
#   '2020-03-06',
#   0.736,
#   0.703,
#   11,
#   -6.256,
#   1,
#   0.364,
#   0.237,
#   1.88e-06,
#   0.413,
#   0.614,
#   151.886,
#   'audio_features',
#   '4wBcaYqLPm7EtDVoJQORU4',
#   'spotify:track:4wBcaYqLPm7EtDVoJQORU4',
#   'https://api.spotify.com/v1/tracks/4wBcaYqLPm7EtDVoJQORU4',
#   'https://api.spotify.com/v1/audio-analysis/4wBcaYqLPm7EtDVoJQORU4',
#   194452,
#   4],
#  ['Lil Uzi Vert',
#   'Eternal Atake',
#   'spotify:album:7IyoGB8J31fvQDwGtHAq9m',
#   'Prices',
#   '2020-03-06',
#   0.786,
#   0.684,
#   7,
#   -5.397,
#   1,
#   0.205,
#   0.172,
#   0,
#   0.706,
#   0.563,
#   126.002,
#   'audio_features',
#   '4YcWzLSnGqLjSCycuSMHnn',
#   'spotify:track:4YcWzLSnGqLjSCycuSMHnn',
#   'https://api.spotify.com/v1/tracks/4YcWzLSnGqLjSCycuSMHnn',
#   'https://api.spotify.com/v1/audio-analysis/4YcWzLSnGqLjSCycuSMHnn',
#   233333,
#   4],
#  ...]

# %%
len(tracks)
# Out:
# 5437

# %%
audio_ft = list(sp.audio_features('7tr2za8SQg2CI8EDgrdtNl')[0].keys())

# %%
df_columns = ['artist','album_name','album_uri','track','release_date'] + audio_ft

df_columns
# Out:
# ['artist',
#  'album_name',
#  'album_uri',
#  'track',
#  'release_date',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'type',
#  'id',
#  'uri',
#  'track_href',
#  'analysis_url',
#  'duration_ms',
#  'time_signature']

# %%
import pandas as pd

df = pd.DataFrame(tracks, columns=df_columns)

# %%
df
# Out:
#           artist           album_name                             album_uri  \
# 0     The Weeknd  My Dear Melancholy,  spotify:album:4qZBW3f2Q8y0k1A84d4iAO
# 1     The Weeknd  My Dear Melancholy,  spotify:album:4qZBW3f2Q8y0k1A84d4iAO
# 2     The Weeknd  My Dear Melancholy,  spotify:album:4qZBW3f2Q8y0k1A84d4iAO
# 3     The Weeknd  My Dear Melancholy,  spotify:album:4qZBW3f2Q8y0k1A84d4iAO
# 4     The Weeknd  My Dear Melancholy,  spotify:album:4qZBW3f2Q8y0k1A84d4iAO
# ...          ...                  ...                                   ...
# 5432    J Balvin     Behind The Front  spotify:album:6bwBeiWNQu2g3yaa3yNpgz
# 5433    J Balvin     Behind The Front  spotify:album:6bwBeiWNQu2g3yaa3yNpgz
# 5434    J Balvin     Behind The Front  spotify:album:6bwBeiWNQu2g3yaa3yNpgz
# 5435    J Balvin     Behind The Front  spotify:album:6bwBeiWNQu2g3yaa3yNpgz
# 5436    J Balvin     Behind The Front  spotify:album:6bwBeiWNQu2g3yaa3yNpgz
#
#                   track release_date  danceability  energy  key  loudness  \
# 0      Call Out My Name   2018-03-30         0.461   0.593    1    -4.954
# 1                Try Me   2018-03-30         0.456   0.679    8    -5.778
# 2          Wasted Times   2018-03-30         0.560   0.678   10    -6.167
# 3     I Was Never There   2018-03-30         0.323   0.737   10    -4.008
# 4              Hurt You   2018-03-30         0.476   0.718    5    -7.227
# ...                 ...          ...           ...     ...  ...       ...
# 5432        ?Que Dices?         1998         0.876   0.548    7    -6.360
# 5433                 A8         1998         0.821   0.663    6    -6.715
# 5434    Love Won't Wait         1998         0.824   0.562    7    -7.723
# 5435          Head Bobs         1998         0.893   0.480    9    -7.077
# 5436         Positivity         1998         0.515   0.711   10    -7.039
#
#       mode  ...  liveness  valence    tempo            type  \
# 0        1  ...    0.3070    0.175  134.170  audio_features
# 1        0  ...    0.1290    0.107   92.026  audio_features
# 2        0  ...    0.1110    0.290  122.585  audio_features
# 3        1  ...    0.1630    0.155  113.260  audio_features
# 4        0  ...    0.1090    0.361  183.932  audio_features
# ...    ...  ...       ...      ...      ...             ...
# 5432     1  ...    0.2100    0.582   97.004  audio_features
# 5433     0  ...    0.1540    0.746   97.901  audio_features
# 5434     1  ...    0.4380    0.637  102.947  audio_features
# 5435     0  ...    0.0715    0.553   98.647  audio_features
# 5436     0  ...    0.2130    0.781   84.976  audio_features
#
#                           id                                   uri  \
# 0     09mEdoA6zrmBPgTEN5qXmN  spotify:track:09mEdoA6zrmBPgTEN5qXmN
# 1     4ppTAJUbNXELZcoUaL90wo  spotify:track:4ppTAJUbNXELZcoUaL90wo
# 2     7DKS0rX27cCEPsK0R6tFWS  spotify:track:7DKS0rX27cCEPsK0R6tFWS
# 3     1cKHdTo9u0ZymJdPGSh6nq  spotify:track:1cKHdTo9u0ZymJdPGSh6nq
# 4     6QdnKD1zwEgyOWtkrdzlOF  spotify:track:6QdnKD1zwEgyOWtkrdzlOF
# ...                      ...                                   ...
# 5432  4B3HAYISsvpYVoYfcTUIRT  spotify:track:4B3HAYISsvpYVoYfcTUIRT
# 5433  2oLE9LW7QKBBufjYrq0hWz  spotify:track:2oLE9LW7QKBBufjYrq0hWz
# 5434  2pcdcgju5vLavQUhPECggi  spotify:track:2pcdcgju5vLavQUhPECggi
# 5435  17w3O9BmmpQa4xi018f55F  spotify:track:17w3O9BmmpQa4xi018f55F
# 5436  0mEQEebRFuHDBirUn8Dh3V  spotify:track:0mEQEebRFuHDBirUn8Dh3V
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/09mEdoA6zrmB...
# 1     https://api.spotify.com/v1/tracks/4ppTAJUbNXEL...
# 2     https://api.spotify.com/v1/tracks/7DKS0rX27cCE...
# 3     https://api.spotify.com/v1/tracks/1cKHdTo9u0Zy...
# 4     https://api.spotify.com/v1/tracks/6QdnKD1zwEgy...
# ...                                                 ...
# 5432  https://api.spotify.com/v1/tracks/4B3HAYISsvpY...
# 5433  https://api.spotify.com/v1/tracks/2oLE9LW7QKBB...
# 5434  https://api.spotify.com/v1/tracks/2pcdcgju5vLa...
# 5435  https://api.spotify.com/v1/tracks/17w3O9BmmpQa...
# 5436  https://api.spotify.com/v1/tracks/0mEQEebRFuHD...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/09mE...      228373
# 1     https://api.spotify.com/v1/audio-analysis/4ppT...      221107
# 2     https://api.spotify.com/v1/audio-analysis/7DKS...      220293
# 3     https://api.spotify.com/v1/audio-analysis/1cKH...      241067
# 4     https://api.spotify.com/v1/audio-analysis/6Qdn...      230027
# ...                                                 ...         ...
# 5432  https://api.spotify.com/v1/audio-analysis/4B3H...      241573
# 5433  https://api.spotify.com/v1/audio-analysis/2oLE...      232227
# 5434  https://api.spotify.com/v1/audio-analysis/2pcd...      214973
# 5435  https://api.spotify.com/v1/audio-analysis/17w3...      254667
# 5436  https://api.spotify.com/v1/audio-analysis/0mEQ...      485360
#
#      time_signature
# 0                 3
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ...             ...
# 5432              4
# 5433              4
# 5434              4
# 5435              4
# 5436              4
#
# [5437 rows x 23 columns]

# %%
df['artist'].value_counts()
# Out:
# Maroon 5           761
# Lil Uzi Vert       606
# Future             515
# Eminem             480
# J Balvin           458
# Lady Gaga          420
# Justin Bieber      416
# The Weeknd         356
# Bad Bunny          344
# Black Eyed Peas    229
# Dua Lipa           208
# Shawn Mendes       127
# Halsey              75
# Post Malone         67
# Doja Cat            57
# Lewis Capaldi       54
# Roddy Ricch         45
# Billie Eilish       42
# Lil Mosey           41
# Surfaces            33
# KAROL G             29
# SAINt JHN           27
# Camila Cabello      25
# Harry Styles        22
# Name: artist, dtype: int64

# %%
df_artist = df.groupby('artist').mean()

# %%
df_artist
# Out:
#                  danceability    energy       key   loudness      mode  \
# artist
# Bad Bunny            0.746023  0.679419  4.627907  -5.783140  0.511628
# Billie Eilish        0.583786  0.281721  5.000000 -15.085071  0.714286
# Black Eyed Peas      0.777581  0.673301  5.764192  -6.489314  0.441048
# Camila Cabello       0.619320  0.536280  4.960000  -6.122320  0.560000
# Doja Cat             0.721684  0.640158  4.561404  -5.728298  0.701754
# Dua Lipa             0.645000  0.671183  5.826923  -5.400837  0.442308
# Eminem               0.701052  0.734983  5.602083  -5.837465  0.558333
# Future               0.722796  0.573123  5.135922  -7.883322  0.561165
# Halsey               0.572040  0.626147  5.000000  -6.261613  0.360000
# Harry Styles         0.539455  0.586227  4.590909  -6.446955  0.727273
# J Balvin             0.777581  0.673301  5.764192  -6.489314  0.441048
# Justin Bieber        0.617082  0.642482  5.076923  -6.309644  0.581731
# KAROL G              0.747138  0.698793  6.034483  -5.284759  0.482759
# Lady Gaga            0.638712  0.705765  4.980952  -6.228338  0.607143
# Lewis Capaldi        0.586889  0.445222  5.925926  -6.629111  0.962963
# Lil Mosey            0.717585  0.602537  5.390244  -7.710829  0.707317
# Lil Uzi Vert         0.723297  0.630287  5.316832  -6.169386  0.574257
# Maroon 5             0.641537  0.716104  5.265440  -5.920016  0.561104
# Post Malone          0.617612  0.619612  4.477612  -5.840463  0.597015
# Roddy Ricch          0.779778  0.546156  5.333333  -8.466578  0.488889
# SAINt JHN            0.764407  0.602222  3.851852  -6.402852  0.555556
# Shawn Mendes         0.575323  0.552638  6.275591  -7.008142  0.685039
# Surfaces             0.657576  0.560121  5.333333  -7.907364  0.848485
# The Weeknd           0.573618  0.609522  5.247191  -7.571556  0.230337
#
#                  speechiness  acousticness  instrumentalness  liveness  \
# artist
# Bad Bunny           0.119923      0.195063      1.811956e-04  0.154300
# Billie Eilish       0.193086      0.656857      1.206927e-01  0.239307
# Black Eyed Peas     0.166291      0.106052      8.263059e-03  0.246169
# Camila Cabello      0.085424      0.329892      1.693564e-04  0.145332
# Doja Cat            0.088316      0.159661      1.901324e-03  0.159854
# Dua Lipa            0.070798      0.097686      6.891923e-06  0.168250
# Eminem              0.305228      0.201312      1.506320e-02  0.316389
# Future              0.220302      0.175965      2.282213e-02  0.214151
# Halsey              0.061711      0.234530      9.331941e-03  0.174613
# Harry Styles        0.035232      0.279982      1.986473e-02  0.154836
# J Balvin            0.166291      0.106052      8.263059e-03  0.246169
# Justin Bieber       0.064890      0.242578      3.578216e-03  0.187972
# KAROL G             0.101838      0.240823      7.526586e-05  0.157248
# Lady Gaga           0.075394      0.156507      1.889046e-02  0.240109
# Lewis Capaldi       0.043844      0.686741      7.370370e-08  0.127081
# Lil Mosey           0.069712      0.285785      7.263049e-05  0.151027
# Lil Uzi Vert        0.203908      0.191402      9.561386e-07  0.206109
# Maroon 5            0.086896      0.137147      9.188681e-04  0.201312
# Post Malone         0.073096      0.306481      9.423138e-03  0.141563
# Roddy Ricch         0.242416      0.110605      1.110978e-05  0.181411
# SAINt JHN           0.084570      0.218489      1.185871e-02  0.158293
# Shawn Mendes        0.083095      0.350553      4.523150e-06  0.260710
# Surfaces            0.081121      0.389864      1.213148e-01  0.209842
# The Weeknd          0.077430      0.275883      1.287730e-02  0.198827
#
#                   valence       tempo    duration_ms  time_signature
# artist
# Bad Bunny        0.523581  121.808558  210723.976744        4.000000
# Billie Eilish    0.288007  105.494286  183947.642857        3.571429
# Black Eyed Peas  0.592969  110.402162  261998.930131        3.995633
# Camila Cabello   0.420684  112.847280  201105.520000        3.960000
# Doja Cat         0.398649  126.991421  209294.017544        4.017544
# Dua Lipa         0.447500  108.685269  214435.653846        4.038462
# Eminem           0.544493  111.498044  240201.727083        3.868750
# Future           0.372776  130.013365  209120.871845        3.984466
# Halsey           0.369885  114.296800  192999.760000        3.920000
# Harry Styles     0.408877  114.690636  237592.772727        4.000000
# J Balvin         0.592969  110.402162  261998.930131        3.995633
# Justin Bieber    0.535468  117.375250  217341.072115        3.947115
# KAROL G          0.600793  122.639586  194043.724138        4.000000
# Lady Gaga        0.524393  118.486979  229294.466667        3.916667
# Lewis Capaldi    0.343889  111.122185  212763.370370        3.962963
# Lil Mosey        0.549756  127.196585  152458.756098        4.000000
# Lil Uzi Vert     0.412369  128.246248  210377.039604        4.009901
# Maroon 5         0.578441  117.831300  213688.315375        3.950066
# Post Malone      0.347000  121.890940  209971.164179        4.014925
# Roddy Ricch      0.355631  130.301267  177773.555556        3.977778
# SAINt JHN        0.391885  121.044296  196996.333333        4.000000
# Shawn Mendes     0.469843  119.080165  217700.889764        3.881890
# Surfaces         0.487185  116.004576  176826.484848        4.000000
# The Weeknd       0.321516  122.971854  291269.848315        3.949438

# %%
df_artist.drop(columns=['time_signature'],inplace=True)

# %%
df_artist
# Out:
#                  danceability    energy       key   loudness      mode  \
# artist
# Bad Bunny            0.746023  0.679419  4.627907  -5.783140  0.511628
# Billie Eilish        0.583786  0.281721  5.000000 -15.085071  0.714286
# Black Eyed Peas      0.777581  0.673301  5.764192  -6.489314  0.441048
# Camila Cabello       0.619320  0.536280  4.960000  -6.122320  0.560000
# Doja Cat             0.721684  0.640158  4.561404  -5.728298  0.701754
# Dua Lipa             0.645000  0.671183  5.826923  -5.400837  0.442308
# Eminem               0.701052  0.734983  5.602083  -5.837465  0.558333
# Future               0.722796  0.573123  5.135922  -7.883322  0.561165
# Halsey               0.572040  0.626147  5.000000  -6.261613  0.360000
# Harry Styles         0.539455  0.586227  4.590909  -6.446955  0.727273
# J Balvin             0.777581  0.673301  5.764192  -6.489314  0.441048
# Justin Bieber        0.617082  0.642482  5.076923  -6.309644  0.581731
# KAROL G              0.747138  0.698793  6.034483  -5.284759  0.482759
# Lady Gaga            0.638712  0.705765  4.980952  -6.228338  0.607143
# Lewis Capaldi        0.586889  0.445222  5.925926  -6.629111  0.962963
# Lil Mosey            0.717585  0.602537  5.390244  -7.710829  0.707317
# Lil Uzi Vert         0.723297  0.630287  5.316832  -6.169386  0.574257
# Maroon 5             0.641537  0.716104  5.265440  -5.920016  0.561104
# Post Malone          0.617612  0.619612  4.477612  -5.840463  0.597015
# Roddy Ricch          0.779778  0.546156  5.333333  -8.466578  0.488889
# SAINt JHN            0.764407  0.602222  3.851852  -6.402852  0.555556
# Shawn Mendes         0.575323  0.552638  6.275591  -7.008142  0.685039
# Surfaces             0.657576  0.560121  5.333333  -7.907364  0.848485
# The Weeknd           0.573618  0.609522  5.247191  -7.571556  0.230337
#
#                  speechiness  acousticness  instrumentalness  liveness  \
# artist
# Bad Bunny           0.119923      0.195063      1.811956e-04  0.154300
# Billie Eilish       0.193086      0.656857      1.206927e-01  0.239307
# Black Eyed Peas     0.166291      0.106052      8.263059e-03  0.246169
# Camila Cabello      0.085424      0.329892      1.693564e-04  0.145332
# Doja Cat            0.088316      0.159661      1.901324e-03  0.159854
# Dua Lipa            0.070798      0.097686      6.891923e-06  0.168250
# Eminem              0.305228      0.201312      1.506320e-02  0.316389
# Future              0.220302      0.175965      2.282213e-02  0.214151
# Halsey              0.061711      0.234530      9.331941e-03  0.174613
# Harry Styles        0.035232      0.279982      1.986473e-02  0.154836
# J Balvin            0.166291      0.106052      8.263059e-03  0.246169
# Justin Bieber       0.064890      0.242578      3.578216e-03  0.187972
# KAROL G             0.101838      0.240823      7.526586e-05  0.157248
# Lady Gaga           0.075394      0.156507      1.889046e-02  0.240109
# Lewis Capaldi       0.043844      0.686741      7.370370e-08  0.127081
# Lil Mosey           0.069712      0.285785      7.263049e-05  0.151027
# Lil Uzi Vert        0.203908      0.191402      9.561386e-07  0.206109
# Maroon 5            0.086896      0.137147      9.188681e-04  0.201312
# Post Malone         0.073096      0.306481      9.423138e-03  0.141563
# Roddy Ricch         0.242416      0.110605      1.110978e-05  0.181411
# SAINt JHN           0.084570      0.218489      1.185871e-02  0.158293
# Shawn Mendes        0.083095      0.350553      4.523150e-06  0.260710
# Surfaces            0.081121      0.389864      1.213148e-01  0.209842
# The Weeknd          0.077430      0.275883      1.287730e-02  0.198827
#
#                   valence       tempo    duration_ms
# artist
# Bad Bunny        0.523581  121.808558  210723.976744
# Billie Eilish    0.288007  105.494286  183947.642857
# Black Eyed Peas  0.592969  110.402162  261998.930131
# Camila Cabello   0.420684  112.847280  201105.520000
# Doja Cat         0.398649  126.991421  209294.017544
# Dua Lipa         0.447500  108.685269  214435.653846
# Eminem           0.544493  111.498044  240201.727083
# Future           0.372776  130.013365  209120.871845
# Halsey           0.369885  114.296800  192999.760000
# Harry Styles     0.408877  114.690636  237592.772727
# J Balvin         0.592969  110.402162  261998.930131
# Justin Bieber    0.535468  117.375250  217341.072115
# KAROL G          0.600793  122.639586  194043.724138
# Lady Gaga        0.524393  118.486979  229294.466667
# Lewis Capaldi    0.343889  111.122185  212763.370370
# Lil Mosey        0.549756  127.196585  152458.756098
# Lil Uzi Vert     0.412369  128.246248  210377.039604
# Maroon 5         0.578441  117.831300  213688.315375
# Post Malone      0.347000  121.890940  209971.164179
# Roddy Ricch      0.355631  130.301267  177773.555556
# SAINt JHN        0.391885  121.044296  196996.333333
# Shawn Mendes     0.469843  119.080165  217700.889764
# Surfaces         0.487185  116.004576  176826.484848
# The Weeknd       0.321516  122.971854  291269.848315

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
import pandas as pd

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(df_artist)
y_kmeans = kmeans.predict(df_artist)

# %%
df_artist.to_csv('top50data.csv')

# %%
df_artist = pd.read_csv('top50data.csv')

# %%
df_artist.head()
# Out:
#             artist  danceability    energy       key   loudness      mode  \
# 0        Bad Bunny      0.746023  0.679419  4.627907  -5.783140  0.511628
# 1    Billie Eilish      0.583786  0.281721  5.000000 -15.085071  0.714286
# 2  Black Eyed Peas      0.777581  0.673301  5.764192  -6.489314  0.441048
# 3   Camila Cabello      0.619320  0.536280  4.960000  -6.122320  0.560000
# 4         Doja Cat      0.721684  0.640158  4.561404  -5.728298  0.701754
#
#    speechiness  acousticness  instrumentalness  liveness   valence  \
# 0     0.119923      0.195063          0.000181  0.154300  0.523581
# 1     0.193086      0.656857          0.120693  0.239307  0.288007
# 2     0.166291      0.106052          0.008263  0.246169  0.592969
# 3     0.085424      0.329892          0.000169  0.145332  0.420684
# 4     0.088316      0.159661          0.001901  0.159854  0.398649
#
#         tempo    duration_ms
# 0  121.808558  210723.976744
# 1  105.494286  183947.642857
# 2  110.402162  261998.930131
# 3  112.847280  201105.520000
# 4  126.991421  209294.017544

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
 X = ohe.fit_transform(df_artist)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4).fit(X)

# %%
centroids = kmeans.cluster_centers_

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd = TruncatedSVD(n_components=3)

# %%
X_reduced = svd.fit_transform(X)
X_reduced
# Out:
# array([[-0.09434   , -0.18281484,  0.54972775],
#        [-0.03476138, -0.86219827,  2.33393395],
#        [ 2.9793451 ,  0.06259456,  0.01550852],
#        [-0.06505809,  0.25772116,  0.83996746],
#        [ 0.1168513 ,  0.55810917, -0.22713152],
#        [-0.00547921, -0.14273707, -0.76131886],
#        [ 0.0412454 ,  0.03036632,  0.38782297],
#        [ 0.14961885,  0.61088148, -0.79988586],
#        [ 0.26173024, -0.26710366,  1.89130606],
#        [-0.08550297, -0.27607754,  0.05623742],
#        [ 2.97527459, -0.01275729, -0.05729417],
#        [ 0.0209598 ,  0.19658357, -0.06683624],
#        [-0.11886653,  0.39727955,  0.21105611],
#        [-0.01232441,  0.0680633 , -0.23806927],
#        [-0.0275293 , -0.6788591 , -0.0802307 ],
#        [-0.01600353, -0.03712791,  0.08189948],
#        [ 0.07076291, -0.16276651, -0.72734846],
#        [ 0.12370113,  0.37114286, -0.01739594],
#        [-0.05710958, -0.20135268,  0.2126116 ],
#        [-0.08830841,  2.29123076,  0.48267207],
#        [ 0.05186706, -0.28478078, -0.15770362],
#        [ 0.10737311,  0.22950823,  0.82219356],
#        [-0.0584    ,  2.38451869,  0.48412982],
#        [-0.04626275, -0.41402515, -0.58280416]])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4).fit(X_reduced)

# %%
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[ 0.00855018  0.01883967 -0.02762268]
#  [ 2.97730985  0.02491863 -0.02089282]
#  [ 0.11348443 -0.56465097  2.11262   ]
#  [-0.0733542   2.33787473  0.48340095]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
 
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %%
# Predicting the clusters
labels = kmeans.predict(X_reduced)
#Getting the cluster centers

C = kmeans.cluster_centers_
colores=['red','green','blue','cyan']
asignar=[]
for row in labels:
    asignar.append(colores[row])

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X_reduced[:,0],X_reduced[:,1],X_reduced[:,2], c=asignar, s=60)
ax.scatter(C[:,0],C[:,1],C[:,2], marker='*', c=colores, s=1000)
